# %% [markdown]
# ## System Setup

# %%
# Find CPU info
# !grep -m1 'model name' /proc/cpuinfo | awk -F": " '{print $2}'
# !grep 'cpu cores' /proc/cpuinfo | awk -F": " '{a[cores]+=$2}END{print "CPU cores: " a[cores]}'
# Out:
# Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU cores: 8

# %%
# Find Ram Info
# !grep MemTotal /proc/meminfo | awk '{printf "%.1fGB RAM", $2 / 1024 / 1024}'
# Out:
# 25.5GB RAM

# %%
# !python3 --version
# Out:
# Python 3.10.6

# %%
# !nvidia-smi
# Out:
# Thu Jul 20 17:52:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install pyBKTR
# Out:
# Collecting pyBKTR
#   Downloading pyBKTR-0.1.1-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (1.22.4)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (1.5.3)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (5.13.1)
# Collecting formulaic>=0.5.2 (from pyBKTR)
#   Downloading formulaic-0.6.4-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 8.1 MB/s eta 0:00:00
# Collecting astor>=0.8 (from formulaic>=0.5.2->pyBKTR)
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.5.2->pyBKTR)
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (4.7.1)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->pyBKTR) (8.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->pyBKTR) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->pyBKTR) (16.0.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4.2->pyBKTR) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->pyBKTR) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.1->pyBKTR) (1.3.0)
# Installing collected packages: interface-meta, astor, formulaic, pyBKTR
# Successfully installed astor-0.8.1 formulaic-0.6.4 interface-meta-1.3.0 pyBKTR-0.1.1

# %% [markdown]
# ## Simulation Interpolation (Python)

# %%
from pyBKTR.bktr import BKTRRegressor
from pyBKTR.kernels import KernelMatern, KernelParameter,KernelSE
from pyBKTR.tensor_ops import TSR

import numpy as np
import pandas as pd

from pyBKTR.utils import simulate_spatiotemporal_data
TSR.set_params('float32', 'cuda', 1)

res_colnames = ['Dataset_Type', 'Lengthscale', 'Iter', 'B_MAE', 'B_RMSE', 'Y_MAE', 'Y_RMSE']
nb_res_cols = len(res_colnames)

nb_aside_locs = 4
nb_aside_times = 6

df_res_arr = []

for ds_type in ['Smaller', 'Larger']:
    for len_scale in [3, 6]:
        for i in range(1, 11):
            matern_lengthscale = KernelParameter(value = len_scale)
            se_lengthscale = KernelParameter(value = len_scale)
            spatial_kernel = KernelMatern(lengthscale = matern_lengthscale, smoothness_factor = 5)
            temporal_kernel = KernelSE(lengthscale = se_lengthscale)

            nb_locs = 20 if ds_type == 'Smaller' else 100
            nb_times = 30 if ds_type == 'Smaller' else 150
            spa_cov_means = [0, 2] if ds_type == 'Smaller' else [0, 2, 4]
            tem_cov_means = [1] if ds_type == 'Smaller' else [1, 3]

            simu_data = simulate_spatiotemporal_data(
                nb_locations=nb_locs,
                nb_time_points=nb_times,
                nb_spatial_dimensions=2,
                spatial_scale=10,
                time_scale=10,
                spatial_covariates_means=spa_cov_means,
                temporal_covariates_means=tem_cov_means,
                spatial_kernel=spatial_kernel,
                temporal_kernel=temporal_kernel,
                noise_variance_scale=1
            )

            data_df = simu_data['data_df'].copy()
            spatial_positions_df = simu_data['spatial_positions_df']
            temporal_positions_df = simu_data['temporal_positions_df']

            obs_nb_locs = nb_locs - nb_aside_locs
            obs_nb_times = nb_times - nb_aside_times

            all_locs = data_df.index.get_level_values(0).unique().to_list()
            all_times = data_df.index.get_level_values(1).unique().to_list()

            locs_indx_sample = list(TSR.rand_choice(TSR.tensor(range(1, len(all_locs) + 1)), obs_nb_locs).cpu().numpy())
            obs_locs = [all_locs[int(i) - 1] for i in locs_indx_sample]
            new_locs = list(set(all_locs) - set(obs_locs))

            times_indx_sample = list(TSR.rand_choice(TSR.tensor(range(1, len(all_times) + 1)), obs_nb_times).cpu().numpy())
            obs_times = [all_times[int(i) - 1] for i in times_indx_sample]
            new_times = list(set(all_times) - set(obs_times))

            obs_data_df = data_df.drop(index=new_locs, level='location')
            obs_data_df = obs_data_df.drop(index=new_times, level='time')
            obs_spatial_pos_df = spatial_positions_df.drop(index=new_locs,)
            obs_temporal_pos_df = temporal_positions_df.drop(index=new_times,)

            new_data_df = data_df[
                (data_df.index.get_level_values(0).isin(new_locs)) |
                (data_df.index.get_level_values(1).isin(new_times))
            ]
            new_beta_data_df = simu_data['beta_df'].copy()
            new_beta_data_df = new_beta_data_df[
                (new_beta_data_df.index.get_level_values(0).isin(new_locs)) |
                (new_beta_data_df.index.get_level_values(1).isin(new_times))
            ]
            new_spatial_pos_df = spatial_positions_df[spatial_positions_df.index.isin(new_locs)]
            new_temporal_pos_df = temporal_positions_df[temporal_positions_df.index.isin(new_times)]


            bktr_regressor = BKTRRegressor(
                data_df = obs_data_df,
                rank_decomp = 10,
                burn_in_iter = 500,
                sampling_iter = 500,
                spatial_kernel = KernelMatern(smoothness_factor = 5),
                spatial_positions_df = obs_spatial_pos_df,
                temporal_kernel = KernelSE(),
                temporal_positions_df = obs_temporal_pos_df,
                has_geo_coords = False
            )
            bktr_regressor.mcmc_sampling()

            preds_y_df, preds_beta_df = bktr_regressor.predict(new_data_df, new_spatial_pos_df, new_temporal_pos_df)

            preds_y_df.sort_index(inplace=True)
            new_data_df.sort_index(inplace=True)
            preds_beta_df.sort_index(inplace=True)
            new_beta_data_df.sort_index(inplace=True)
            preds_y_err = new_data_df['y'].to_numpy() - preds_y_df['y'].to_numpy()
            preds_beta_err = new_beta_data_df.to_numpy() - preds_beta_df.to_numpy()
            df_res_arr.append([
                ds_type,
                len_scale,
                i,
                np.mean(np.abs(preds_beta_err)),
                np.sqrt(np.mean(np.square(preds_beta_err))),
                np.mean(np.abs(preds_y_err)),
                np.sqrt(np.mean(np.square(preds_y_err))),
            ])
            df_res = pd.DataFrame(df_res_arr, columns=res_colnames)
            print(df_res)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/distributions/wishart.py:253: UserWarning: Singular sample detected.
#   warnings.warn("Singular sample detected.")
# * Iter 1     | Elapsed     0.40s | MAE  0.7274 | RMSE  0.9429 *
# * Iter 2     | Elapsed     0.04s | MAE  0.7697 | RMSE  0.9582 *
# * Iter 3     | Elapsed     0.03s | MAE  0.7709 | RMSE  0.9493 *
# * Iter 4     | Elapsed     0.02s | MAE  0.7790 | RMSE  0.9841 *
# * Iter 5     | Elapsed     0.03s | MAE  0.7863 | RMSE  0.9883 *
# * Iter 6     | Elapsed     0.03s | MAE  0.8384 | RMSE  1.0489 *
# * Iter 7     | Elapsed     0.02s | MAE  0.8317 | RMSE  1.0445 *
# * Iter 8     | Elapsed     0.04s | MAE  0.7776 | RMSE  0.9827 *
# * Iter 9     | Elapsed     0.04s | MAE  0.7873 | RMSE  1.0046 *
# * Iter 10    | Elapsed     0.03s | MAE  0.7926 | RMSE  1.0019 *
# * Iter 11    | Elapsed     0.02s | MAE  0.8028 | RMSE  1.0282 *
# * Iter 12    | Elapsed     0.03s | MAE  0.7687 | RMSE  0.9995 *
# * Iter 13    | Elapsed     0.03s | MAE  0.8273 | RMSE  1.0452 *
# * Iter 14    | Elapsed     0.04s | MAE  0.7863 | RMSE  0.9884 *
# * Iter 15    | Elapsed     0.06s | MAE  0.7688 | RMSE  0.9865 *
# * Iter 16    | Elapsed     0.03s | MAE  0.7816 | RMSE  0.9675 *
# * Iter 17    | Elapsed     0.03s | MAE  0.7796 | RMSE  0.9882 *
# * Iter 18    | Elapsed     0.04s | MAE  0.7855 | RMSE  0.9891 *
# * Iter 19    | Elapsed     0.03s | MAE  0.7899 | RMSE  1.0098 *
# * Iter 20    | Elapsed     0.03s | MAE  0.7931 | RMSE  0.9791 *
# * Iter 21    | Elapsed     0.03s | MAE  0.8162 | RMSE  1.0082 *
# * Iter 22    | Elapsed     0.04s | MAE  0.7789 | RMSE  0.9715 *
# * Iter 23    | Elapsed     0.02s | MAE  0.7625 | RMSE  0.9530 *
# * Iter 24    | Elapsed     0.04s | MAE  0.7786 | RMSE  0.9850 *
# * Iter 25    | Elapsed     0.03s | MAE  0.8006 | RMSE  0.9997 *
# * Iter 26    | Elapsed     0.04s | MAE  0.7754 | RMSE  0.9795 *
# * Iter 27    | Elapsed     0.05s | MAE  0.7718 | RMSE  0.9831 *
# * Iter 28    | Elapsed     0.03s | MAE  0.8003 | RMSE  1.0283 *
# * Iter 29    | Elapsed     0.03s | MAE  0.7768 | RMSE  0.9891 *
# * Iter 30    | Elapsed     0.03s | MAE  0.8109 | RMSE  1.0201 *
# * Iter 31    | Elapsed     0.02s | MAE  0.7897 | RMSE  1.0121 *
# * Iter 32    | Elapsed     0.03s | MAE  0.8099 | RMSE  1.0227 *
# * Iter 33    | Elapsed     0.02s | MAE  0.8297 | RMSE  1.0379 *
# * Iter 34    | Elapsed     0.02s | MAE  0.8242 | RMSE  1.0302 *
# * Iter 35    | Elapsed     0.03s | MAE  0.7724 | RMSE  0.9786 *
# * Iter 36    | Elapsed     0.03s | MAE  0.8276 | RMSE  1.0248 *
# * Iter 37    | Elapsed     0.04s | MAE  0.7980 | RMSE  1.0002 *
# * Iter 38    | Elapsed     0.02s | MAE  0.8188 | RMSE  1.0282 *
# * Iter 39    | Elapsed     0.02s | MAE  0.8118 | RMSE  1.0225 *
# * Iter 40    | Elapsed     0.04s | MAE  0.8076 | RMSE  1.0140 *
# * Iter 41    | Elapsed     0.03s | MAE  0.8092 | RMSE  1.0076 *
# * Iter 42    | Elapsed     0.02s | MAE  0.8084 | RMSE  1.0181 *
# * Iter 43    | Elapsed     0.03s | MAE  0.7990 | RMSE  0.9910 *
# * Iter 44    | Elapsed     0.04s | MAE  0.7719 | RMSE  0.9652 *
# * Iter 45    | Elapsed     0.03s | MAE  0.7983 | RMSE  0.9945 *
# * Iter 46    | Elapsed     0.03s | MAE  0.7902 | RMSE  1.0118 *
# * Iter 47    | Elapsed     0.04s | MAE  0.8343 | RMSE  1.0295 *
# * Iter 48    | Elapsed     0.03s | MAE  0.8189 | RMSE  1.0132 *
# * Iter 49    | Elapsed     0.04s | MAE  0.7963 | RMSE  0.9920 *
# * Iter 50    | Elapsed     0.03s | MAE  0.8006 | RMSE  1.0161 *
# * Iter 51    | Elapsed     0.06s | MAE  0.7762 | RMSE  0.9877 *
# * Iter 52    | Elapsed     0.02s | MAE  0.7769 | RMSE  0.9857 *
# * Iter 53    | Elapsed     0.03s | MAE  0.8167 | RMSE  1.0231 *
# * Iter 54    | Elapsed     0.04s | MAE  0.7933 | RMSE  1.0233 *
# * Iter 55    | Elapsed     0.04s | MAE  0.7873 | RMSE  0.9960 *
# * Iter 56    | Elapsed     0.03s | MAE  0.8135 | RMSE  1.0044 *
# * Iter 57    | Elapsed     0.03s | MAE  0.7853 | RMSE  0.9960 *
# * Iter 58    | Elapsed     0.03s | MAE  0.8012 | RMSE  1.0061 *
# * Iter 59    | Elapsed     0.03s | MAE  0.7901 | RMSE  0.9808 *
# * Iter 60    | Elapsed     0.04s | MAE  0.7603 | RMSE  0.9579 *
# * Iter 61    | Elapsed     0.03s | MAE  0.7492 | RMSE  0.9505 *
# * Iter 62    | Elapsed     0.03s | MAE  0.7662 | RMSE  0.9716 *
# * Iter 63    | Elapsed     0.04s | MAE  0.8091 | RMSE  1.0241 *
# * Iter 64    | Elapsed     0.04s | MAE  0.7862 | RMSE  0.9994 *
# * Iter 65    | Elapsed     0.02s | MAE  0.7814 | RMSE  0.9913 *
# * Iter 66    | Elapsed     0.04s | MAE  0.7967 | RMSE  0.9988 *
# * Iter 67    | Elapsed     0.03s | MAE  0.7894 | RMSE  0.9906 *
# * Iter 68    | Elapsed     0.02s | MAE  0.8055 | RMSE  0.9992 *
# * Iter 69    | Elapsed     0.02s | MAE  0.7853 | RMSE  0.9911 *
# * Iter 70    | Elapsed     0.01s | MAE  0.8203 | RMSE  1.0291 *
# * Iter 71    | Elapsed     0.03s | MAE  0.7936 | RMSE  1.0008 *
# * Iter 72    | Elapsed     0.03s | MAE  0.8039 | RMSE  1.0045 *
# * Iter 73    | Elapsed     0.04s | MAE  0.7722 | RMSE  0.9698 *
# * Iter 74    | Elapsed     0.02s | MAE  0.8051 | RMSE  1.0126 *
# * Iter 75    | Elapsed     0.04s | MAE  0.8008 | RMSE  1.0035 *
# * Iter 76    | Elapsed     0.03s | MAE  0.7801 | RMSE  0.9879 *
# * Iter 77    | Elapsed     0.04s | MAE  0.7956 | RMSE  0.9975 *
# * Iter 78    | Elapsed     0.02s | MAE  0.8076 | RMSE  1.0004 *
# * Iter 79    | Elapsed     0.02s | MAE  0.7984 | RMSE  0.9957 *
# * Iter 80    | Elapsed     0.05s | MAE  0.7821 | RMSE  0.9963 *
# * Iter 81    | Elapsed     0.03s | MAE  0.7821 | RMSE  0.9907 *
# * Iter 82    | Elapsed     0.06s | MAE  0.7790 | RMSE  0.9898 *
# * Iter 83    | Elapsed     0.03s | MAE  0.8053 | RMSE  1.0075 *
# * Iter 84    | Elapsed     0.02s | MAE  0.8070 | RMSE  0.9987 *
# * Iter 85    | Elapsed     0.02s | MAE  0.8041 | RMSE  1.0053 *
# * Iter 86    | Elapsed     0.02s | MAE  0.7997 | RMSE  1.0085 *
# * Iter 87    | Elapsed     0.03s | MAE  0.8083 | RMSE  0.9955 *
# * Iter 88    | Elapsed     0.03s | MAE  0.7921 | RMSE  0.9945 *
# * Iter 89    | Elapsed     0.03s | MAE  0.8169 | RMSE  0.9923 *
# * Iter 90    | Elapsed     0.03s | MAE  0.7830 | RMSE  0.9931 *
# * Iter 91    | Elapsed     0.04s | MAE  0.7721 | RMSE  0.9801 *
# * Iter 92    | Elapsed     0.03s | MAE  0.7932 | RMSE  1.0010 *
# * Iter 93    | Elapsed     0.02s | MAE  0.7843 | RMSE  0.9960 *
# * Iter 94    | Elapsed     0.04s | MAE  0.7790 | RMSE  0.9802 *
# * Iter 95    | Elapsed     0.02s | MAE  0.7793 | RMSE  0.9875 *
# * Iter 96    | Elapsed     0.02s | MAE  0.7940 | RMSE  1.0165 *
# * Iter 97    | Elapsed     0.03s | MAE  0.7708 | RMSE  0.9913 *
# * Iter 98    | Elapsed     0.02s | MAE  0.7970 | RMSE  0.9999 *
# * Iter 99    | Elapsed     0.04s | MAE  0.7730 | RMSE  0.9769 *
# * Iter 100   | Elapsed     0.04s | MAE  0.8320 | RMSE  1.0311 *
# * Iter 101   | Elapsed     0.04s | MAE  0.7974 | RMSE  0.9942 *
# * Iter 102   | Elapsed     0.02s | MAE  0.8049 | RMSE  1.0096 *
# * Iter 103   | Elapsed     0.03s | MAE  0.7886 | RMSE  0.9891 *
# * Iter 104   | Elapsed     0.03s | MAE  0.7897 | RMSE  0.9909 *
# * Iter 105   | Elapsed     0.03s | MAE  0.7944 | RMSE  0.9937 *
# * Iter 106   | Elapsed     0.02s | MAE  0.7760 | RMSE  0.9784 *
# * Iter 107   | Elapsed     0.02s | MAE  0.8200 | RMSE  1.0069 *
# * Iter 108   | Elapsed     0.02s | MAE  0.7930 | RMSE  0.9842 *
# * Iter 109   | Elapsed     0.05s | MAE  0.7743 | RMSE  0.9755 *
# * Iter 110   | Elapsed     0.03s | MAE  0.7319 | RMSE  0.9329 *
# * Iter 111   | Elapsed     0.03s | MAE  0.7365 | RMSE  0.9376 *
# * Iter 112   | Elapsed     0.03s | MAE  0.7453 | RMSE  0.9510 *
# * Iter 113   | Elapsed     0.04s | MAE  0.7570 | RMSE  0.9713 *
# * Iter 114   | Elapsed     0.02s | MAE  0.7881 | RMSE  0.9857 *
# * Iter 115   | Elapsed     0.04s | MAE  0.8080 | RMSE  1.0179 *
# * Iter 116   | Elapsed     0.04s | MAE  0.7770 | RMSE  0.9732 *
# * Iter 117   | Elapsed     0.04s | MAE  0.8146 | RMSE  1.0086 *
# * Iter 118   | Elapsed     0.03s | MAE  0.8203 | RMSE  1.0226 *
# * Iter 119   | Elapsed     0.04s | MAE  0.7927 | RMSE  0.9920 *
# * Iter 120   | Elapsed     0.03s | MAE  0.7636 | RMSE  0.9646 *
# * Iter 121   | Elapsed     0.04s | MAE  0.8052 | RMSE  1.0020 *
# * Iter 122   | Elapsed     0.02s | MAE  0.7884 | RMSE  1.0061 *
# * Iter 123   | Elapsed     0.04s | MAE  0.8072 | RMSE  1.0221 *
# * Iter 124   | Elapsed     0.03s | MAE  0.7997 | RMSE  1.0086 *
# * Iter 125   | Elapsed     0.03s | MAE  0.7924 | RMSE  0.9980 *
# * Iter 126   | Elapsed     0.03s | MAE  0.7905 | RMSE  1.0113 *
# * Iter 127   | Elapsed     0.03s | MAE  0.8338 | RMSE  1.0540 *
# * Iter 128   | Elapsed     0.03s | MAE  0.8330 | RMSE  1.0409 *
# * Iter 129   | Elapsed     0.02s | MAE  0.8027 | RMSE  1.0070 *
# * Iter 130   | Elapsed     0.02s | MAE  0.8048 | RMSE  1.0169 *
# * Iter 131   | Elapsed     0.02s | MAE  0.8145 | RMSE  1.0243 *
# * Iter 132   | Elapsed     0.03s | MAE  0.8246 | RMSE  1.0172 *
# * Iter 133   | Elapsed     0.03s | MAE  0.8216 | RMSE  1.0113 *
# * Iter 134   | Elapsed     0.03s | MAE  0.8009 | RMSE  1.0112 *
# * Iter 135   | Elapsed     0.03s | MAE  0.7913 | RMSE  0.9871 *
# * Iter 136   | Elapsed     0.02s | MAE  0.7721 | RMSE  0.9747 *
# * Iter 137   | Elapsed     0.02s | MAE  0.7808 | RMSE  0.9824 *
# * Iter 138   | Elapsed     0.02s | MAE  0.8081 | RMSE  1.0117 *
# * Iter 139   | Elapsed     0.02s | MAE  0.7921 | RMSE  0.9946 *
# * Iter 140   | Elapsed     0.03s | MAE  0.7932 | RMSE  0.9869 *
# * Iter 141   | Elapsed     0.03s | MAE  0.7968 | RMSE  1.0194 *
# * Iter 142   | Elapsed     0.04s | MAE  0.7952 | RMSE  1.0026 *
# * Iter 143   | Elapsed     0.03s | MAE  0.7819 | RMSE  0.9870 *
# * Iter 144   | Elapsed     0.03s | MAE  0.7840 | RMSE  0.9819 *
# * Iter 145   | Elapsed     0.04s | MAE  0.8019 | RMSE  1.0118 *
# * Iter 146   | Elapsed     0.04s | MAE  0.7984 | RMSE  1.0175 *
# * Iter 147   | Elapsed     0.04s | MAE  0.8076 | RMSE  1.0105 *
# * Iter 148   | Elapsed     0.02s | MAE  0.7768 | RMSE  0.9940 *
# * Iter 149   | Elapsed     0.04s | MAE  0.8143 | RMSE  1.0249 *
# * Iter 150   | Elapsed     0.03s | MAE  0.8216 | RMSE  1.0229 *
# * Iter 151   | Elapsed     0.03s | MAE  0.8191 | RMSE  1.0265 *
# * Iter 152   | Elapsed     0.02s | MAE  0.8298 | RMSE  1.0518 *
# * Iter 153   | Elapsed     0.02s | MAE  0.8179 | RMSE  1.0333 *
# * Iter 154   | Elapsed     0.02s | MAE  0.8314 | RMSE  1.0463 *
# * Iter 155   | Elapsed     0.02s | MAE  0.7979 | RMSE  1.0039 *
# * Iter 156   | Elapsed     0.02s | MAE  0.8072 | RMSE  1.0088 *
# * Iter 157   | Elapsed     0.03s | MAE  0.8167 | RMSE  1.0229 *
# * Iter 158   | Elapsed     0.02s | MAE  0.7910 | RMSE  0.9973 *
# * Iter 159   | Elapsed     0.02s | MAE  0.7885 | RMSE  0.9890 *
# * Iter 160   | Elapsed     0.02s | MAE  0.7948 | RMSE  1.0041 *
# * Iter 161   | Elapsed     0.03s | MAE  0.8094 | RMSE  1.0117 *
# * Iter 162   | Elapsed     0.03s | MAE  0.7986 | RMSE  1.0056 *
# * Iter 163   | Elapsed     0.02s | MAE  0.8123 | RMSE  1.0297 *
# * Iter 164   | Elapsed     0.02s | MAE  0.7885 | RMSE  0.9976 *
# * Iter 165   | Elapsed     0.03s | MAE  0.7933 | RMSE  1.0010 *
# * Iter 166   | Elapsed     0.03s | MAE  0.8158 | RMSE  1.0323 *
# * Iter 167   | Elapsed     0.03s | MAE  0.8033 | RMSE  1.0004 *
# * Iter 168   | Elapsed     0.03s | MAE  0.7982 | RMSE  0.9921 *
# * Iter 169   | Elapsed     0.02s | MAE  0.8140 | RMSE  1.0285 *
# * Iter 170   | Elapsed     0.02s | MAE  0.8122 | RMSE  1.0319 *
# * Iter 171   | Elapsed     0.01s | MAE  0.8356 | RMSE  1.0351 *
# * Iter 172   | Elapsed     0.02s | MAE  0.8286 | RMSE  1.0089 *
# * Iter 173   | Elapsed     0.03s | MAE  0.8131 | RMSE  1.0284 *
# * Iter 174   | Elapsed     0.03s | MAE  0.8155 | RMSE  1.0279 *
# * Iter 175   | Elapsed     0.03s | MAE  0.7803 | RMSE  0.9986 *
# * Iter 176   | Elapsed     0.04s | MAE  0.7874 | RMSE  1.0138 *
# * Iter 177   | Elapsed     0.02s | MAE  0.8085 | RMSE  1.0003 *
# * Iter 178   | Elapsed     0.03s | MAE  0.7940 | RMSE  1.0029 *
# * Iter 179   | Elapsed     0.02s | MAE  0.8147 | RMSE  1.0153 *
# * Iter 180   | Elapsed     0.03s | MAE  0.8226 | RMSE  1.0201 *
# * Iter 181   | Elapsed     0.02s | MAE  0.7961 | RMSE  1.0184 *
# * Iter 182   | Elapsed     0.03s | MAE  0.7862 | RMSE  0.9875 *
# * Iter 183   | Elapsed     0.02s | MAE  0.8140 | RMSE  1.0180 *
# * Iter 184   | Elapsed     0.02s | MAE  0.8119 | RMSE  1.0366 *
# * Iter 185   | Elapsed     0.03s | MAE  0.7794 | RMSE  0.9944 *
# * Iter 186   | Elapsed     0.01s | MAE  0.7706 | RMSE  0.9673 *
# * Iter 187   | Elapsed     0.02s | MAE  0.7630 | RMSE  0.9643 *
# * Iter 188   | Elapsed     0.02s | MAE  0.7737 | RMSE  0.9746 *
# * Iter 189   | Elapsed     0.03s | MAE  0.8188 | RMSE  1.0118 *
# * Iter 190   | Elapsed     0.03s | MAE  0.7753 | RMSE  0.9832 *
# * Iter 191   | Elapsed     0.03s | MAE  0.8006 | RMSE  1.0195 *
# * Iter 192   | Elapsed     0.03s | MAE  0.7721 | RMSE  0.9958 *
# * Iter 193   | Elapsed     0.03s | MAE  0.7658 | RMSE  0.9708 *
# * Iter 194   | Elapsed     0.03s | MAE  0.7901 | RMSE  1.0069 *
# * Iter 195   | Elapsed     0.02s | MAE  0.7748 | RMSE  0.9815 *
# * Iter 196   | Elapsed     0.02s | MAE  0.8002 | RMSE  1.0238 *
# * Iter 197   | Elapsed     0.02s | MAE  0.8307 | RMSE  1.0265 *
# * Iter 198   | Elapsed     0.03s | MAE  0.8027 | RMSE  1.0031 *
# * Iter 199   | Elapsed     0.02s | MAE  0.8180 | RMSE  1.0089 *
# * Iter 200   | Elapsed     0.03s | MAE  0.8194 | RMSE  1.0437 *
# * Iter 201   | Elapsed     0.03s | MAE  0.8288 | RMSE  1.0337 *
# * Iter 202   | Elapsed     0.02s | MAE  0.8757 | RMSE  1.0754 *
# * Iter 203   | Elapsed     0.02s | MAE  0.8402 | RMSE  1.0498 *
# * Iter 204   | Elapsed     0.03s | MAE  0.8332 | RMSE  1.0398 *
# * Iter 205   | Elapsed     0.02s | MAE  0.7862 | RMSE  0.9904 *
# * Iter 206   | Elapsed     0.02s | MAE  0.8077 | RMSE  0.9959 *
# * Iter 207   | Elapsed     0.03s | MAE  0.7859 | RMSE  0.9999 *
# * Iter 208   | Elapsed     0.03s | MAE  0.7846 | RMSE  0.9875 *
# * Iter 209   | Elapsed     0.03s | MAE  0.7981 | RMSE  1.0027 *
# * Iter 210   | Elapsed     0.02s | MAE  0.7803 | RMSE  0.9800 *
# * Iter 211   | Elapsed     0.03s | MAE  0.7834 | RMSE  1.0099 *
# * Iter 212   | Elapsed     0.03s | MAE  0.7844 | RMSE  0.9895 *
# * Iter 213   | Elapsed     0.03s | MAE  0.8027 | RMSE  1.0101 *
# * Iter 214   | Elapsed     0.03s | MAE  0.8203 | RMSE  1.0191 *
# * Iter 215   | Elapsed     0.03s | MAE  0.7796 | RMSE  0.9972 *
# * Iter 216   | Elapsed     0.03s | MAE  0.7864 | RMSE  0.9938 *
# * Iter 217   | Elapsed     0.03s | MAE  0.7951 | RMSE  1.0043 *
# * Iter 218   | Elapsed     0.02s | MAE  0.7589 | RMSE  0.9660 *
# * Iter 219   | Elapsed     0.03s | MAE  0.8004 | RMSE  1.0097 *
# * Iter 220   | Elapsed     0.02s | MAE  0.7693 | RMSE  0.9765 *
# * Iter 221   | Elapsed     0.02s | MAE  0.8405 | RMSE  1.0411 *
# * Iter 222   | Elapsed     0.03s | MAE  0.8349 | RMSE  1.0506 *
# * Iter 223   | Elapsed     0.03s | MAE  0.8237 | RMSE  1.0279 *
# * Iter 224   | Elapsed     0.03s | MAE  0.8159 | RMSE  1.0241 *
# * Iter 225   | Elapsed     0.02s | MAE  0.8142 | RMSE  0.9959 *
# * Iter 226   | Elapsed     0.03s | MAE  0.7994 | RMSE  1.0203 *
# * Iter 227   | Elapsed     0.02s | MAE  0.7938 | RMSE  0.9887 *
# * Iter 228   | Elapsed     0.02s | MAE  0.7858 | RMSE  0.9861 *
# * Iter 229   | Elapsed     0.02s | MAE  0.8032 | RMSE  0.9813 *
# * Iter 230   | Elapsed     0.03s | MAE  0.8095 | RMSE  1.0034 *
# * Iter 231   | Elapsed     0.03s | MAE  0.8010 | RMSE  0.9977 *
# * Iter 232   | Elapsed     0.02s | MAE  0.7903 | RMSE  1.0049 *
# * Iter 233   | Elapsed     0.02s | MAE  0.7795 | RMSE  0.9818 *
# * Iter 234   | Elapsed     0.02s | MAE  0.8065 | RMSE  1.0080 *
# * Iter 235   | Elapsed     0.03s | MAE  0.8100 | RMSE  1.0139 *
# * Iter 236   | Elapsed     0.02s | MAE  0.8138 | RMSE  1.0098 *
# * Iter 237   | Elapsed     0.02s | MAE  0.8504 | RMSE  1.0583 *
# * Iter 238   | Elapsed     0.02s | MAE  0.7855 | RMSE  0.9873 *
# * Iter 239   | Elapsed     0.02s | MAE  0.8007 | RMSE  1.0156 *
# * Iter 240   | Elapsed     0.03s | MAE  0.8289 | RMSE  1.0449 *
# * Iter 241   | Elapsed     0.02s | MAE  0.8030 | RMSE  1.0081 *
# * Iter 242   | Elapsed     0.02s | MAE  0.8120 | RMSE  1.0184 *
# * Iter 243   | Elapsed     0.02s | MAE  0.7974 | RMSE  0.9951 *
# * Iter 244   | Elapsed     0.03s | MAE  0.8095 | RMSE  1.0093 *
# * Iter 245   | Elapsed     0.02s | MAE  0.7593 | RMSE  0.9652 *
# * Iter 246   | Elapsed     0.02s | MAE  0.7575 | RMSE  0.9602 *
# * Iter 247   | Elapsed     0.02s | MAE  0.7603 | RMSE  0.9739 *
# * Iter 248   | Elapsed     0.03s | MAE  0.8021 | RMSE  1.0090 *
# * Iter 249   | Elapsed     0.02s | MAE  0.7599 | RMSE  0.9717 *
# * Iter 250   | Elapsed     0.02s | MAE  0.7896 | RMSE  0.9998 *
# * Iter 251   | Elapsed     0.03s | MAE  0.8196 | RMSE  1.0111 *
# * Iter 252   | Elapsed     0.02s | MAE  0.8007 | RMSE  1.0041 *
# * Iter 253   | Elapsed     0.02s | MAE  0.7825 | RMSE  0.9973 *
# * Iter 254   | Elapsed     0.02s | MAE  0.7840 | RMSE  0.9786 *
# * Iter 255   | Elapsed     0.02s | MAE  0.8066 | RMSE  1.0096 *
# * Iter 256   | Elapsed     0.04s | MAE  0.7785 | RMSE  0.9670 *
# * Iter 257   | Elapsed     0.02s | MAE  0.7882 | RMSE  0.9875 *
# * Iter 258   | Elapsed     0.02s | MAE  0.7904 | RMSE  0.9968 *
# * Iter 259   | Elapsed     0.03s | MAE  0.8028 | RMSE  1.0136 *
# * Iter 260   | Elapsed     0.02s | MAE  0.7985 | RMSE  0.9813 *
# * Iter 261   | Elapsed     0.03s | MAE  0.8263 | RMSE  1.0352 *
# * Iter 262   | Elapsed     0.03s | MAE  0.8332 | RMSE  1.0237 *
# * Iter 263   | Elapsed     0.02s | MAE  0.8035 | RMSE  1.0193 *
# * Iter 264   | Elapsed     0.03s | MAE  0.8021 | RMSE  1.0072 *
# * Iter 265   | Elapsed     0.02s | MAE  0.8007 | RMSE  1.0097 *
# * Iter 266   | Elapsed     0.03s | MAE  0.8114 | RMSE  1.0274 *
# * Iter 267   | Elapsed     0.03s | MAE  0.7918 | RMSE  0.9710 *
# * Iter 268   | Elapsed     0.03s | MAE  0.7618 | RMSE  0.9704 *
# * Iter 269   | Elapsed     0.03s | MAE  0.7922 | RMSE  0.9888 *
# * Iter 270   | Elapsed     0.02s | MAE  0.8240 | RMSE  1.0491 *
# * Iter 271   | Elapsed     0.02s | MAE  0.8590 | RMSE  1.0960 *
# * Iter 272   | Elapsed     0.02s | MAE  0.8206 | RMSE  1.0487 *
# * Iter 273   | Elapsed     0.02s | MAE  0.8083 | RMSE  1.0316 *
# * Iter 274   | Elapsed     0.03s | MAE  0.8088 | RMSE  1.0122 *
# * Iter 275   | Elapsed     0.03s | MAE  0.8240 | RMSE  1.0240 *
# * Iter 276   | Elapsed     0.03s | MAE  0.8024 | RMSE  1.0033 *
# * Iter 277   | Elapsed     0.03s | MAE  0.8099 | RMSE  1.0071 *
# * Iter 278   | Elapsed     0.03s | MAE  0.7826 | RMSE  0.9773 *
# * Iter 279   | Elapsed     0.02s | MAE  0.8057 | RMSE  1.0066 *
# * Iter 280   | Elapsed     0.02s | MAE  0.7874 | RMSE  0.9888 *
# * Iter 281   | Elapsed     0.03s | MAE  0.7827 | RMSE  0.9795 *
# * Iter 282   | Elapsed     0.02s | MAE  0.7913 | RMSE  0.9989 *
# * Iter 283   | Elapsed     0.02s | MAE  0.8182 | RMSE  1.0462 *
# * Iter 284   | Elapsed     0.01s | MAE  0.7841 | RMSE  0.9709 *
# * Iter 285   | Elapsed     0.02s | MAE  0.8061 | RMSE  0.9875 *
# * Iter 286   | Elapsed     0.02s | MAE  0.7892 | RMSE  1.0071 *
# * Iter 287   | Elapsed     0.02s | MAE  0.8089 | RMSE  1.0124 *
# * Iter 288   | Elapsed     0.02s | MAE  0.7892 | RMSE  0.9951 *
# * Iter 289   | Elapsed     0.02s | MAE  0.7974 | RMSE  1.0088 *
# * Iter 290   | Elapsed     0.02s | MAE  0.8302 | RMSE  1.0421 *
# * Iter 291   | Elapsed     0.03s | MAE  0.7745 | RMSE  0.9900 *
# * Iter 292   | Elapsed     0.03s | MAE  0.7883 | RMSE  0.9771 *
# * Iter 293   | Elapsed     0.02s | MAE  0.7842 | RMSE  0.9979 *
# * Iter 294   | Elapsed     0.02s | MAE  0.7702 | RMSE  0.9758 *
# * Iter 295   | Elapsed     0.02s | MAE  0.7993 | RMSE  0.9987 *
# * Iter 296   | Elapsed     0.02s | MAE  0.8148 | RMSE  1.0148 *
# * Iter 297   | Elapsed     0.03s | MAE  0.8216 | RMSE  1.0257 *
# * Iter 298   | Elapsed     0.03s | MAE  0.8276 | RMSE  1.0459 *
# * Iter 299   | Elapsed     0.02s | MAE  0.8229 | RMSE  1.0162 *
# * Iter 300   | Elapsed     0.02s | MAE  0.8203 | RMSE  1.0325 *
# * Iter 301   | Elapsed     0.02s | MAE  0.8329 | RMSE  1.0427 *
# * Iter 302   | Elapsed     0.02s | MAE  0.8495 | RMSE  1.0945 *
# * Iter 303   | Elapsed     0.03s | MAE  0.8305 | RMSE  1.0474 *
# * Iter 304   | Elapsed     0.02s | MAE  0.7824 | RMSE  0.9899 *
# * Iter 305   | Elapsed     0.02s | MAE  0.8062 | RMSE  1.0126 *
# * Iter 306   | Elapsed     0.02s | MAE  0.8294 | RMSE  1.0434 *
# * Iter 307   | Elapsed     0.03s | MAE  0.8443 | RMSE  1.0671 *
# * Iter 308   | Elapsed     0.02s | MAE  0.7946 | RMSE  1.0025 *
# * Iter 309   | Elapsed     0.03s | MAE  0.7939 | RMSE  0.9969 *
# * Iter 310   | Elapsed     0.02s | MAE  0.8346 | RMSE  1.0279 *
# * Iter 311   | Elapsed     0.03s | MAE  0.7935 | RMSE  0.9950 *
# * Iter 312   | Elapsed     0.02s | MAE  0.8066 | RMSE  1.0036 *
# * Iter 313   | Elapsed     0.03s | MAE  0.7692 | RMSE  0.9787 *
# * Iter 314   | Elapsed     0.02s | MAE  0.7847 | RMSE  0.9982 *
# * Iter 315   | Elapsed     0.02s | MAE  0.7923 | RMSE  1.0149 *
# * Iter 316   | Elapsed     0.04s | MAE  0.7953 | RMSE  0.9920 *
# * Iter 317   | Elapsed     0.02s | MAE  0.7720 | RMSE  0.9841 *
# * Iter 318   | Elapsed     0.02s | MAE  0.8474 | RMSE  1.0456 *
# * Iter 319   | Elapsed     0.02s | MAE  0.8273 | RMSE  1.0306 *
# * Iter 320   | Elapsed     0.02s | MAE  0.8114 | RMSE  1.0251 *
# * Iter 321   | Elapsed     0.02s | MAE  0.8554 | RMSE  1.0565 *
# * Iter 322   | Elapsed     0.03s | MAE  0.8165 | RMSE  1.0171 *
# * Iter 323   | Elapsed     0.03s | MAE  0.8141 | RMSE  1.0250 *
# * Iter 324   | Elapsed     0.03s | MAE  0.7809 | RMSE  0.9810 *
# * Iter 325   | Elapsed     0.02s | MAE  0.8170 | RMSE  1.0065 *
# * Iter 326   | Elapsed     0.02s | MAE  0.8075 | RMSE  1.0087 *
# * Iter 327   | Elapsed     0.02s | MAE  0.8157 | RMSE  1.0112 *
# * Iter 328   | Elapsed     0.02s | MAE  0.8367 | RMSE  1.0267 *
# * Iter 329   | Elapsed     0.03s | MAE  0.8075 | RMSE  1.0252 *
# * Iter 330   | Elapsed     0.02s | MAE  0.8135 | RMSE  1.0267 *
# * Iter 331   | Elapsed     0.03s | MAE  0.8008 | RMSE  1.0071 *
# * Iter 332   | Elapsed     0.02s | MAE  0.7793 | RMSE  0.9930 *
# * Iter 333   | Elapsed     0.02s | MAE  0.7659 | RMSE  0.9700 *
# * Iter 334   | Elapsed     0.02s | MAE  0.8359 | RMSE  1.0331 *
# * Iter 335   | Elapsed     0.02s | MAE  0.8085 | RMSE  1.0175 *
# * Iter 336   | Elapsed     0.03s | MAE  0.8236 | RMSE  1.0359 *
# * Iter 337   | Elapsed     0.02s | MAE  0.8191 | RMSE  1.0470 *
# * Iter 338   | Elapsed     0.02s | MAE  0.8561 | RMSE  1.0441 *
# * Iter 339   | Elapsed     0.03s | MAE  0.8125 | RMSE  1.0343 *
# * Iter 340   | Elapsed     0.03s | MAE  0.8103 | RMSE  1.0144 *
# * Iter 341   | Elapsed     0.02s | MAE  0.7600 | RMSE  0.9802 *
# * Iter 342   | Elapsed     0.02s | MAE  0.8052 | RMSE  1.0055 *
# * Iter 343   | Elapsed     0.02s | MAE  0.8121 | RMSE  1.0116 *
# * Iter 344   | Elapsed     0.02s | MAE  0.7889 | RMSE  1.0041 *
# * Iter 345   | Elapsed     0.03s | MAE  0.7542 | RMSE  0.9592 *
# * Iter 346   | Elapsed     0.03s | MAE  0.8002 | RMSE  0.9973 *
# * Iter 347   | Elapsed     0.03s | MAE  0.8020 | RMSE  0.9880 *
# * Iter 348   | Elapsed     0.03s | MAE  0.7825 | RMSE  0.9820 *
# * Iter 349   | Elapsed     0.02s | MAE  0.7875 | RMSE  0.9759 *
# * Iter 350   | Elapsed     0.02s | MAE  0.7792 | RMSE  0.9982 *
# * Iter 351   | Elapsed     0.02s | MAE  0.8056 | RMSE  1.0123 *
# * Iter 352   | Elapsed     0.03s | MAE  0.8309 | RMSE  1.0291 *
# * Iter 353   | Elapsed     0.02s | MAE  0.8280 | RMSE  1.0383 *
# * Iter 354   | Elapsed     0.04s | MAE  0.8097 | RMSE  1.0186 *
# * Iter 355   | Elapsed     0.02s | MAE  0.8336 | RMSE  1.0437 *
# * Iter 356   | Elapsed     0.02s | MAE  0.8079 | RMSE  1.0220 *
# * Iter 357   | Elapsed     0.02s | MAE  0.8120 | RMSE  1.0179 *
# * Iter 358   | Elapsed     0.02s | MAE  0.8162 | RMSE  0.9957 *
# * Iter 359   | Elapsed     0.02s | MAE  0.8185 | RMSE  1.0155 *
# * Iter 360   | Elapsed     0.03s | MAE  0.8470 | RMSE  1.0542 *
# * Iter 361   | Elapsed     0.04s | MAE  0.7993 | RMSE  1.0045 *
# * Iter 362   | Elapsed     0.03s | MAE  0.7861 | RMSE  0.9779 *
# * Iter 363   | Elapsed     0.04s | MAE  0.7834 | RMSE  0.9983 *
# * Iter 364   | Elapsed     0.03s | MAE  0.8041 | RMSE  1.0152 *
# * Iter 365   | Elapsed     0.02s | MAE  0.7926 | RMSE  0.9917 *
# * Iter 366   | Elapsed     0.03s | MAE  0.7820 | RMSE  0.9794 *
# * Iter 367   | Elapsed     0.03s | MAE  0.7568 | RMSE  0.9594 *
# * Iter 368   | Elapsed     0.02s | MAE  0.8412 | RMSE  1.0382 *
# * Iter 369   | Elapsed     0.03s | MAE  0.8052 | RMSE  1.0195 *
# * Iter 370   | Elapsed     0.03s | MAE  0.8174 | RMSE  1.0337 *
# * Iter 371   | Elapsed     0.04s | MAE  0.7848 | RMSE  0.9753 *
# * Iter 372   | Elapsed     0.03s | MAE  0.8070 | RMSE  1.0024 *
# * Iter 373   | Elapsed     0.02s | MAE  0.7762 | RMSE  0.9806 *
# * Iter 374   | Elapsed     0.02s | MAE  0.7649 | RMSE  0.9702 *
# * Iter 375   | Elapsed     0.03s | MAE  0.7832 | RMSE  0.9833 *
# * Iter 376   | Elapsed     0.03s | MAE  0.7852 | RMSE  0.9819 *
# * Iter 377   | Elapsed     0.02s | MAE  0.7917 | RMSE  1.0261 *
# * Iter 378   | Elapsed     0.02s | MAE  0.7785 | RMSE  0.9894 *
# * Iter 379   | Elapsed     0.02s | MAE  0.7713 | RMSE  0.9582 *
# * Iter 380   | Elapsed     0.02s | MAE  0.7667 | RMSE  0.9632 *
# * Iter 381   | Elapsed     0.02s | MAE  0.7544 | RMSE  0.9709 *
# * Iter 382   | Elapsed     0.03s | MAE  0.7854 | RMSE  1.0053 *
# * Iter 383   | Elapsed     0.02s | MAE  0.8191 | RMSE  1.0155 *
# * Iter 384   | Elapsed     0.03s | MAE  0.8284 | RMSE  1.0263 *
# * Iter 385   | Elapsed     0.02s | MAE  0.8285 | RMSE  1.0307 *
# * Iter 386   | Elapsed     0.03s | MAE  0.8522 | RMSE  1.0521 *
# * Iter 387   | Elapsed     0.02s | MAE  0.7800 | RMSE  0.9901 *
# * Iter 388   | Elapsed     0.01s | MAE  0.8001 | RMSE  1.0031 *
# * Iter 389   | Elapsed     0.02s | MAE  0.8173 | RMSE  1.0196 *
# * Iter 390   | Elapsed     0.02s | MAE  0.7886 | RMSE  0.9915 *
# * Iter 391   | Elapsed     0.03s | MAE  0.7959 | RMSE  1.0145 *
# * Iter 392   | Elapsed     0.02s | MAE  0.8077 | RMSE  1.0333 *
# * Iter 393   | Elapsed     0.02s | MAE  0.8389 | RMSE  1.0402 *
# * Iter 394   | Elapsed     0.02s | MAE  0.8148 | RMSE  1.0165 *
# * Iter 395   | Elapsed     0.02s | MAE  0.8032 | RMSE  1.0133 *
# * Iter 396   | Elapsed     0.02s | MAE  0.7831 | RMSE  0.9861 *
# * Iter 397   | Elapsed     0.03s | MAE  0.7627 | RMSE  0.9658 *
# * Iter 398   | Elapsed     0.02s | MAE  0.8301 | RMSE  1.0308 *
# * Iter 399   | Elapsed     0.03s | MAE  0.8144 | RMSE  1.0252 *
# * Iter 400   | Elapsed     0.02s | MAE  0.7796 | RMSE  0.9963 *
# * Iter 401   | Elapsed     0.02s | MAE  0.8406 | RMSE  1.0555 *
# * Iter 402   | Elapsed     0.02s | MAE  0.8285 | RMSE  1.0323 *
# * Iter 403   | Elapsed     0.03s | MAE  0.8074 | RMSE  1.0110 *
# * Iter 404   | Elapsed     0.03s | MAE  0.8003 | RMSE  1.0145 *
# * Iter 405   | Elapsed     0.02s | MAE  0.8261 | RMSE  1.0231 *
# * Iter 406   | Elapsed     0.02s | MAE  0.7882 | RMSE  0.9869 *
# * Iter 407   | Elapsed     0.03s | MAE  0.8028 | RMSE  1.0085 *
# * Iter 408   | Elapsed     0.02s | MAE  0.7760 | RMSE  0.9800 *
# * Iter 409   | Elapsed     0.02s | MAE  0.7894 | RMSE  0.9855 *
# * Iter 410   | Elapsed     0.02s | MAE  0.7713 | RMSE  0.9732 *
# * Iter 411   | Elapsed     0.02s | MAE  0.7795 | RMSE  0.9895 *
# * Iter 412   | Elapsed     0.02s | MAE  0.7878 | RMSE  0.9770 *
# * Iter 413   | Elapsed     0.01s | MAE  0.7998 | RMSE  1.0076 *
# * Iter 414   | Elapsed     0.02s | MAE  0.8097 | RMSE  1.0252 *
# * Iter 415   | Elapsed     0.03s | MAE  0.8129 | RMSE  1.0259 *
# * Iter 416   | Elapsed     0.03s | MAE  0.8039 | RMSE  1.0094 *
# * Iter 417   | Elapsed     0.02s | MAE  0.8093 | RMSE  1.0287 *
# * Iter 418   | Elapsed     0.02s | MAE  0.8361 | RMSE  1.0382 *
# * Iter 419   | Elapsed     0.02s | MAE  0.8190 | RMSE  1.0269 *
# * Iter 420   | Elapsed     0.02s | MAE  0.8093 | RMSE  1.0120 *
# * Iter 421   | Elapsed     0.02s | MAE  0.8421 | RMSE  1.0588 *
# * Iter 422   | Elapsed     0.02s | MAE  0.7859 | RMSE  0.9895 *
# * Iter 423   | Elapsed     0.01s | MAE  0.8060 | RMSE  1.0313 *
# * Iter 424   | Elapsed     0.03s | MAE  0.7500 | RMSE  0.9749 *
# * Iter 425   | Elapsed     0.03s | MAE  0.7708 | RMSE  0.9827 *
# * Iter 426   | Elapsed     0.03s | MAE  0.7818 | RMSE  0.9930 *
# * Iter 427   | Elapsed     0.03s | MAE  0.7870 | RMSE  1.0012 *
# * Iter 428   | Elapsed     0.03s | MAE  0.8263 | RMSE  1.0360 *
# * Iter 429   | Elapsed     0.03s | MAE  0.7554 | RMSE  0.9703 *
# * Iter 430   | Elapsed     0.04s | MAE  0.7899 | RMSE  0.9881 *
# * Iter 431   | Elapsed     0.02s | MAE  0.7731 | RMSE  0.9912 *
# * Iter 432   | Elapsed     0.04s | MAE  0.7785 | RMSE  0.9995 *
# * Iter 433   | Elapsed     0.02s | MAE  0.7892 | RMSE  0.9915 *
# * Iter 434   | Elapsed     0.03s | MAE  0.8101 | RMSE  1.0068 *
# * Iter 435   | Elapsed     0.03s | MAE  0.8062 | RMSE  1.0271 *
# * Iter 436   | Elapsed     0.04s | MAE  0.8214 | RMSE  1.0285 *
# * Iter 437   | Elapsed     0.02s | MAE  0.8336 | RMSE  1.0388 *
# * Iter 438   | Elapsed     0.02s | MAE  0.8520 | RMSE  1.0715 *
# * Iter 439   | Elapsed     0.03s | MAE  0.8315 | RMSE  1.0436 *
# * Iter 440   | Elapsed     0.03s | MAE  0.8293 | RMSE  1.0321 *
# * Iter 441   | Elapsed     0.02s | MAE  0.7834 | RMSE  0.9889 *
# * Iter 442   | Elapsed     0.02s | MAE  0.8030 | RMSE  1.0090 *
# * Iter 443   | Elapsed     0.03s | MAE  0.7914 | RMSE  0.9887 *
# * Iter 444   | Elapsed     0.03s | MAE  0.7886 | RMSE  0.9967 *
# * Iter 445   | Elapsed     0.03s | MAE  0.8176 | RMSE  1.0359 *
# * Iter 446   | Elapsed     0.02s | MAE  0.8176 | RMSE  1.0220 *
# * Iter 447   | Elapsed     0.03s | MAE  0.8097 | RMSE  1.0114 *
# * Iter 448   | Elapsed     0.03s | MAE  0.8084 | RMSE  0.9958 *
# * Iter 449   | Elapsed     0.03s | MAE  0.8030 | RMSE  1.0117 *
# * Iter 450   | Elapsed     0.02s | MAE  0.7782 | RMSE  0.9801 *
# * Iter 451   | Elapsed     0.02s | MAE  0.7926 | RMSE  0.9959 *
# * Iter 452   | Elapsed     0.03s | MAE  0.7861 | RMSE  0.9798 *
# * Iter 453   | Elapsed     0.03s | MAE  0.7955 | RMSE  0.9975 *
# * Iter 454   | Elapsed     0.02s | MAE  0.8210 | RMSE  1.0281 *
# * Iter 455   | Elapsed     0.02s | MAE  0.7819 | RMSE  0.9752 *
# * Iter 456   | Elapsed     0.03s | MAE  0.7984 | RMSE  1.0108 *
# * Iter 457   | Elapsed     0.03s | MAE  0.8025 | RMSE  0.9917 *
# * Iter 458   | Elapsed     0.02s | MAE  0.7941 | RMSE  1.0060 *
# * Iter 459   | Elapsed     0.02s | MAE  0.7672 | RMSE  0.9759 *
# * Iter 460   | Elapsed     0.03s | MAE  0.7664 | RMSE  0.9731 *
# * Iter 461   | Elapsed     0.03s | MAE  0.7744 | RMSE  0.9707 *
# * Iter 462   | Elapsed     0.04s | MAE  0.8173 | RMSE  1.0125 *
# * Iter 463   | Elapsed     0.02s | MAE  0.7998 | RMSE  1.0193 *
# * Iter 464   | Elapsed     0.03s | MAE  0.8097 | RMSE  1.0180 *
# * Iter 465   | Elapsed     0.03s | MAE  0.7884 | RMSE  0.9954 *
# * Iter 466   | Elapsed     0.01s | MAE  0.7918 | RMSE  1.0046 *
# * Iter 467   | Elapsed     0.03s | MAE  0.7920 | RMSE  1.0129 *
# * Iter 468   | Elapsed     0.04s | MAE  0.7842 | RMSE  0.9942 *
# * Iter 469   | Elapsed     0.03s | MAE  0.8134 | RMSE  1.0414 *
# * Iter 470   | Elapsed     0.02s | MAE  0.7944 | RMSE  1.0064 *
# * Iter 471   | Elapsed     0.02s | MAE  0.7676 | RMSE  0.9804 *
# * Iter 472   | Elapsed     0.02s | MAE  0.7885 | RMSE  0.9985 *
# * Iter 473   | Elapsed     0.03s | MAE  0.7916 | RMSE  1.0209 *
# * Iter 474   | Elapsed     0.02s | MAE  0.8202 | RMSE  1.0282 *
# * Iter 475   | Elapsed     0.02s | MAE  0.8381 | RMSE  1.0435 *
# * Iter 476   | Elapsed     0.03s | MAE  0.8087 | RMSE  1.0255 *
# * Iter 477   | Elapsed     0.02s | MAE  0.7608 | RMSE  0.9684 *
# * Iter 478   | Elapsed     0.03s | MAE  0.7663 | RMSE  0.9502 *
# * Iter 479   | Elapsed     0.03s | MAE  0.7970 | RMSE  0.9851 *
# * Iter 480   | Elapsed     0.03s | MAE  0.7691 | RMSE  0.9804 *
# * Iter 481   | Elapsed     0.03s | MAE  0.8148 | RMSE  1.0148 *
# * Iter 482   | Elapsed     0.02s | MAE  0.8299 | RMSE  1.0506 *
# * Iter 483   | Elapsed     0.03s | MAE  0.8235 | RMSE  1.0300 *
# * Iter 484   | Elapsed     0.03s | MAE  0.8259 | RMSE  1.0381 *
# * Iter 485   | Elapsed     0.02s | MAE  0.8063 | RMSE  1.0054 *
# * Iter 486   | Elapsed     0.03s | MAE  0.8180 | RMSE  1.0219 *
# * Iter 487   | Elapsed     0.02s | MAE  0.8166 | RMSE  1.0271 *
# * Iter 488   | Elapsed     0.03s | MAE  0.7973 | RMSE  1.0119 *
# * Iter 489   | Elapsed     0.03s | MAE  0.7900 | RMSE  1.0017 *
# * Iter 490   | Elapsed     0.02s | MAE  0.7953 | RMSE  1.0153 *
# * Iter 491   | Elapsed     0.02s | MAE  0.7847 | RMSE  0.9964 *
# * Iter 492   | Elapsed     0.03s | MAE  0.8247 | RMSE  1.0427 *
# * Iter 493   | Elapsed     0.03s | MAE  0.8003 | RMSE  1.0155 *
# * Iter 494   | Elapsed     0.03s | MAE  0.8732 | RMSE  1.0846 *
# * Iter 495   | Elapsed     0.04s | MAE  0.8374 | RMSE  1.0533 *
# * Iter 496   | Elapsed     0.03s | MAE  0.8078 | RMSE  1.0093 *
# * Iter 497   | Elapsed     0.02s | MAE  0.7644 | RMSE  0.9673 *
# * Iter 498   | Elapsed     0.03s | MAE  0.7876 | RMSE  0.9915 *
# * Iter 499   | Elapsed     0.03s | MAE  0.8143 | RMSE  1.0155 *
# * Iter 500   | Elapsed     0.02s | MAE  0.8154 | RMSE  1.0295 *
# * Iter 501   | Elapsed     0.02s | MAE  0.8029 | RMSE  1.0086 *
# * Iter 502   | Elapsed     0.02s | MAE  0.8116 | RMSE  1.0186 *
# * Iter 503   | Elapsed     0.03s | MAE  0.7778 | RMSE  0.9793 *
# * Iter 504   | Elapsed     0.02s | MAE  0.7968 | RMSE  0.9965 *
# * Iter 505   | Elapsed     0.03s | MAE  0.8279 | RMSE  1.0187 *
# * Iter 506   | Elapsed     0.02s | MAE  0.7870 | RMSE  1.0078 *
# * Iter 507   | Elapsed     0.03s | MAE  0.8166 | RMSE  1.0346 *
# * Iter 508   | Elapsed     0.03s | MAE  0.7999 | RMSE  1.0166 *
# * Iter 509   | Elapsed     0.02s | MAE  0.7807 | RMSE  1.0069 *
# * Iter 510   | Elapsed     0.04s | MAE  0.7742 | RMSE  0.9933 *
# * Iter 511   | Elapsed     0.03s | MAE  0.7861 | RMSE  0.9846 *
# * Iter 512   | Elapsed     0.02s | MAE  0.8017 | RMSE  1.0019 *
# * Iter 513   | Elapsed     0.04s | MAE  0.8051 | RMSE  1.0044 *
# * Iter 514   | Elapsed     0.02s | MAE  0.7884 | RMSE  0.9877 *
# * Iter 515   | Elapsed     0.03s | MAE  0.7829 | RMSE  1.0004 *
# * Iter 516   | Elapsed     0.03s | MAE  0.7784 | RMSE  0.9812 *
# * Iter 517   | Elapsed     0.02s | MAE  0.7870 | RMSE  1.0024 *
# * Iter 518   | Elapsed     0.02s | MAE  0.8120 | RMSE  0.9906 *
# * Iter 519   | Elapsed     0.03s | MAE  0.8262 | RMSE  1.0174 *
# * Iter 520   | Elapsed     0.02s | MAE  0.8098 | RMSE  1.0045 *
# * Iter 521   | Elapsed     0.02s | MAE  0.7838 | RMSE  0.9945 *
# * Iter 522   | Elapsed     0.03s | MAE  0.7881 | RMSE  1.0073 *
# * Iter 523   | Elapsed     0.02s | MAE  0.8222 | RMSE  1.0377 *
# * Iter 524   | Elapsed     0.02s | MAE  0.7867 | RMSE  1.0159 *
# * Iter 525   | Elapsed     0.04s | MAE  0.7910 | RMSE  0.9941 *
# * Iter 526   | Elapsed     0.02s | MAE  0.7922 | RMSE  1.0011 *
# * Iter 527   | Elapsed     0.02s | MAE  0.8225 | RMSE  1.0330 *
# * Iter 528   | Elapsed     0.02s | MAE  0.7882 | RMSE  0.9988 *
# * Iter 529   | Elapsed     0.03s | MAE  0.7611 | RMSE  0.9579 *
# * Iter 530   | Elapsed     0.02s | MAE  0.7460 | RMSE  0.9406 *
# * Iter 531   | Elapsed     0.02s | MAE  0.7826 | RMSE  0.9869 *
# * Iter 532   | Elapsed     0.02s | MAE  0.8007 | RMSE  1.0155 *
# * Iter 533   | Elapsed     0.02s | MAE  0.7966 | RMSE  1.0075 *
# * Iter 534   | Elapsed     0.03s | MAE  0.7673 | RMSE  0.9770 *
# * Iter 535   | Elapsed     0.02s | MAE  0.7859 | RMSE  0.9775 *
# * Iter 536   | Elapsed     0.03s | MAE  0.7851 | RMSE  0.9686 *
# * Iter 537   | Elapsed     0.03s | MAE  0.8166 | RMSE  1.0183 *
# * Iter 538   | Elapsed     0.03s | MAE  0.7932 | RMSE  0.9953 *
# * Iter 539   | Elapsed     0.03s | MAE  0.7627 | RMSE  0.9955 *
# * Iter 540   | Elapsed     0.03s | MAE  0.7805 | RMSE  1.0085 *
# * Iter 541   | Elapsed     0.02s | MAE  0.8352 | RMSE  1.0443 *
# * Iter 542   | Elapsed     0.04s | MAE  0.7925 | RMSE  0.9883 *
# * Iter 543   | Elapsed     0.01s | MAE  0.8060 | RMSE  1.0127 *
# * Iter 544   | Elapsed     0.03s | MAE  0.7949 | RMSE  0.9833 *
# * Iter 545   | Elapsed     0.02s | MAE  0.7912 | RMSE  0.9893 *
# * Iter 546   | Elapsed     0.02s | MAE  0.7924 | RMSE  0.9993 *
# * Iter 547   | Elapsed     0.02s | MAE  0.7859 | RMSE  0.9901 *
# * Iter 548   | Elapsed     0.02s | MAE  0.7841 | RMSE  0.9840 *
# * Iter 549   | Elapsed     0.02s | MAE  0.8267 | RMSE  1.0359 *
# * Iter 550   | Elapsed     0.03s | MAE  0.7916 | RMSE  1.0061 *
# * Iter 551   | Elapsed     0.03s | MAE  0.8018 | RMSE  1.0122 *
# * Iter 552   | Elapsed     0.03s | MAE  0.8142 | RMSE  1.0070 *
# * Iter 553   | Elapsed     0.02s | MAE  0.7478 | RMSE  0.9534 *
# * Iter 554   | Elapsed     0.03s | MAE  0.7785 | RMSE  0.9736 *
# * Iter 555   | Elapsed     0.04s | MAE  0.8138 | RMSE  1.0139 *
# * Iter 556   | Elapsed     0.02s | MAE  0.7965 | RMSE  0.9995 *
# * Iter 557   | Elapsed     0.03s | MAE  0.8263 | RMSE  1.0253 *
# * Iter 558   | Elapsed     0.02s | MAE  0.7838 | RMSE  0.9681 *
# * Iter 559   | Elapsed     0.03s | MAE  0.7691 | RMSE  0.9708 *
# * Iter 560   | Elapsed     0.02s | MAE  0.7883 | RMSE  0.9933 *
# * Iter 561   | Elapsed     0.02s | MAE  0.8009 | RMSE  1.0214 *
# * Iter 562   | Elapsed     0.03s | MAE  0.8098 | RMSE  1.0098 *
# * Iter 563   | Elapsed     0.02s | MAE  0.7676 | RMSE  0.9661 *
# * Iter 564   | Elapsed     0.02s | MAE  0.8143 | RMSE  1.0134 *
# * Iter 565   | Elapsed     0.04s | MAE  0.8357 | RMSE  1.0260 *
# * Iter 566   | Elapsed     0.03s | MAE  0.8028 | RMSE  1.0059 *
# * Iter 567   | Elapsed     0.03s | MAE  0.7894 | RMSE  1.0051 *
# * Iter 568   | Elapsed     0.02s | MAE  0.8074 | RMSE  1.0086 *
# * Iter 569   | Elapsed     0.02s | MAE  0.7964 | RMSE  0.9924 *
# * Iter 570   | Elapsed     0.03s | MAE  0.8005 | RMSE  1.0175 *
# * Iter 571   | Elapsed     0.03s | MAE  0.8034 | RMSE  1.0084 *
# * Iter 572   | Elapsed     0.03s | MAE  0.7927 | RMSE  1.0121 *
# * Iter 573   | Elapsed     0.03s | MAE  0.7907 | RMSE  1.0013 *
# * Iter 574   | Elapsed     0.02s | MAE  0.7956 | RMSE  0.9991 *
# * Iter 575   | Elapsed     0.02s | MAE  0.8120 | RMSE  1.0083 *
# * Iter 576   | Elapsed     0.03s | MAE  0.7901 | RMSE  0.9936 *
# * Iter 577   | Elapsed     0.03s | MAE  0.8021 | RMSE  1.0030 *
# * Iter 578   | Elapsed     0.02s | MAE  0.8140 | RMSE  1.0223 *
# * Iter 579   | Elapsed     0.02s | MAE  0.8125 | RMSE  1.0306 *
# * Iter 580   | Elapsed     0.03s | MAE  0.8212 | RMSE  1.0418 *
# * Iter 581   | Elapsed     0.02s | MAE  0.8183 | RMSE  1.0310 *
# * Iter 582   | Elapsed     0.02s | MAE  0.8028 | RMSE  1.0139 *
# * Iter 583   | Elapsed     0.03s | MAE  0.8029 | RMSE  1.0112 *
# * Iter 584   | Elapsed     0.02s | MAE  0.8220 | RMSE  1.0116 *
# * Iter 585   | Elapsed     0.03s | MAE  0.7875 | RMSE  0.9699 *
# * Iter 586   | Elapsed     0.02s | MAE  0.7962 | RMSE  0.9772 *
# * Iter 587   | Elapsed     0.03s | MAE  0.7923 | RMSE  1.0006 *
# * Iter 588   | Elapsed     0.03s | MAE  0.8108 | RMSE  1.0053 *
# * Iter 589   | Elapsed     0.03s | MAE  0.8020 | RMSE  1.0249 *
# * Iter 590   | Elapsed     0.02s | MAE  0.7884 | RMSE  0.9968 *
# * Iter 591   | Elapsed     0.02s | MAE  0.8421 | RMSE  1.0645 *
# * Iter 592   | Elapsed     0.02s | MAE  0.8425 | RMSE  1.0591 *
# * Iter 593   | Elapsed     0.02s | MAE  0.8452 | RMSE  1.0393 *
# * Iter 594   | Elapsed     0.02s | MAE  0.8070 | RMSE  1.0034 *
# * Iter 595   | Elapsed     0.03s | MAE  0.8009 | RMSE  1.0161 *
# * Iter 596   | Elapsed     0.03s | MAE  0.8148 | RMSE  1.0214 *
# * Iter 597   | Elapsed     0.03s | MAE  0.7588 | RMSE  0.9792 *
# * Iter 598   | Elapsed     0.01s | MAE  0.8016 | RMSE  1.0038 *
# * Iter 599   | Elapsed     0.02s | MAE  0.7973 | RMSE  0.9967 *
# * Iter 600   | Elapsed     0.02s | MAE  0.7812 | RMSE  0.9762 *
# * Iter 601   | Elapsed     0.02s | MAE  0.7833 | RMSE  0.9777 *
# * Iter 602   | Elapsed     0.03s | MAE  0.8085 | RMSE  0.9957 *
# * Iter 603   | Elapsed     0.02s | MAE  0.7707 | RMSE  0.9726 *
# * Iter 604   | Elapsed     0.03s | MAE  0.7970 | RMSE  0.9968 *
# * Iter 605   | Elapsed     0.03s | MAE  0.7823 | RMSE  0.9753 *
# * Iter 606   | Elapsed     0.04s | MAE  0.7608 | RMSE  0.9516 *
# * Iter 607   | Elapsed     0.03s | MAE  0.7710 | RMSE  0.9597 *
# * Iter 608   | Elapsed     0.04s | MAE  0.7722 | RMSE  0.9648 *
# * Iter 609   | Elapsed     0.03s | MAE  0.7662 | RMSE  0.9723 *
# * Iter 610   | Elapsed     0.02s | MAE  0.7832 | RMSE  0.9887 *
# * Iter 611   | Elapsed     0.01s | MAE  0.8034 | RMSE  1.0003 *
# * Iter 612   | Elapsed     0.02s | MAE  0.7860 | RMSE  0.9850 *
# * Iter 613   | Elapsed     0.02s | MAE  0.7933 | RMSE  0.9983 *
# * Iter 614   | Elapsed     0.02s | MAE  0.8146 | RMSE  1.0249 *
# * Iter 615   | Elapsed     0.03s | MAE  0.8655 | RMSE  1.0881 *
# * Iter 616   | Elapsed     0.03s | MAE  0.8531 | RMSE  1.0901 *
# * Iter 617   | Elapsed     0.02s | MAE  0.7932 | RMSE  1.0003 *
# * Iter 618   | Elapsed     0.02s | MAE  0.8075 | RMSE  1.0116 *
# * Iter 619   | Elapsed     0.03s | MAE  0.8217 | RMSE  1.0153 *
# * Iter 620   | Elapsed     0.01s | MAE  0.8361 | RMSE  1.0295 *
# * Iter 621   | Elapsed     0.02s | MAE  0.8004 | RMSE  1.0259 *
# * Iter 622   | Elapsed     0.03s | MAE  0.8096 | RMSE  1.0166 *
# * Iter 623   | Elapsed     0.03s | MAE  0.8159 | RMSE  1.0256 *
# * Iter 624   | Elapsed     0.03s | MAE  0.7973 | RMSE  0.9887 *
# * Iter 625   | Elapsed     0.02s | MAE  0.8077 | RMSE  1.0117 *
# * Iter 626   | Elapsed     0.03s | MAE  0.8119 | RMSE  1.0282 *
# * Iter 627   | Elapsed     0.02s | MAE  0.7954 | RMSE  0.9948 *
# * Iter 628   | Elapsed     0.02s | MAE  0.8291 | RMSE  1.0376 *
# * Iter 629   | Elapsed     0.02s | MAE  0.8063 | RMSE  1.0075 *
# * Iter 630   | Elapsed     0.03s | MAE  0.7844 | RMSE  0.9753 *
# * Iter 631   | Elapsed     0.03s | MAE  0.7909 | RMSE  1.0126 *
# * Iter 632   | Elapsed     0.02s | MAE  0.8107 | RMSE  1.0145 *
# * Iter 633   | Elapsed     0.02s | MAE  0.7657 | RMSE  0.9809 *
# * Iter 634   | Elapsed     0.04s | MAE  0.7906 | RMSE  0.9825 *
# * Iter 635   | Elapsed     0.03s | MAE  0.8163 | RMSE  1.0130 *
# * Iter 636   | Elapsed     0.02s | MAE  0.8163 | RMSE  1.0278 *
# * Iter 637   | Elapsed     0.02s | MAE  0.8031 | RMSE  1.0042 *
# * Iter 638   | Elapsed     0.04s | MAE  0.7912 | RMSE  0.9880 *
# * Iter 639   | Elapsed     0.04s | MAE  0.7586 | RMSE  0.9684 *
# * Iter 640   | Elapsed     0.02s | MAE  0.7852 | RMSE  0.9966 *
# * Iter 641   | Elapsed     0.03s | MAE  0.7986 | RMSE  0.9886 *
# * Iter 642   | Elapsed     0.03s | MAE  0.7783 | RMSE  0.9573 *
# * Iter 643   | Elapsed     0.03s | MAE  0.7664 | RMSE  0.9756 *
# * Iter 644   | Elapsed     0.03s | MAE  0.7866 | RMSE  1.0005 *
# * Iter 645   | Elapsed     0.02s | MAE  0.7723 | RMSE  0.9802 *
# * Iter 646   | Elapsed     0.03s | MAE  0.8122 | RMSE  1.0312 *
# * Iter 647   | Elapsed     0.02s | MAE  0.8113 | RMSE  1.0238 *
# * Iter 648   | Elapsed     0.02s | MAE  0.8335 | RMSE  1.0520 *
# * Iter 649   | Elapsed     0.02s | MAE  0.7999 | RMSE  1.0109 *
# * Iter 650   | Elapsed     0.03s | MAE  0.7913 | RMSE  0.9913 *
# * Iter 651   | Elapsed     0.03s | MAE  0.7790 | RMSE  0.9779 *
# * Iter 652   | Elapsed     0.01s | MAE  0.8038 | RMSE  1.0047 *
# * Iter 653   | Elapsed     0.02s | MAE  0.7799 | RMSE  0.9864 *
# * Iter 654   | Elapsed     0.04s | MAE  0.7901 | RMSE  0.9901 *
# * Iter 655   | Elapsed     0.02s | MAE  0.7873 | RMSE  0.9911 *
# * Iter 656   | Elapsed     0.03s | MAE  0.8210 | RMSE  1.0350 *
# * Iter 657   | Elapsed     0.03s | MAE  0.8705 | RMSE  1.0724 *
# * Iter 658   | Elapsed     0.02s | MAE  0.8025 | RMSE  0.9908 *
# * Iter 659   | Elapsed     0.02s | MAE  0.7931 | RMSE  0.9978 *
# * Iter 660   | Elapsed     0.02s | MAE  0.8245 | RMSE  1.0176 *
# * Iter 661   | Elapsed     0.03s | MAE  0.7921 | RMSE  0.9900 *
# * Iter 662   | Elapsed     0.02s | MAE  0.8310 | RMSE  1.0253 *
# * Iter 663   | Elapsed     0.02s | MAE  0.8288 | RMSE  1.0295 *
# * Iter 664   | Elapsed     0.02s | MAE  0.7788 | RMSE  0.9953 *
# * Iter 665   | Elapsed     0.02s | MAE  0.7833 | RMSE  0.9906 *
# * Iter 666   | Elapsed     0.02s | MAE  0.7807 | RMSE  0.9761 *
# * Iter 667   | Elapsed     0.03s | MAE  0.7964 | RMSE  0.9922 *
# * Iter 668   | Elapsed     0.02s | MAE  0.7930 | RMSE  0.9944 *
# * Iter 669   | Elapsed     0.03s | MAE  0.7938 | RMSE  0.9898 *
# * Iter 670   | Elapsed     0.01s | MAE  0.7786 | RMSE  0.9803 *
# * Iter 671   | Elapsed     0.02s | MAE  0.7888 | RMSE  0.9977 *
# * Iter 672   | Elapsed     0.02s | MAE  0.8182 | RMSE  1.0110 *
# * Iter 673   | Elapsed     0.03s | MAE  0.7898 | RMSE  1.0016 *
# * Iter 674   | Elapsed     0.02s | MAE  0.7736 | RMSE  0.9768 *
# * Iter 675   | Elapsed     0.02s | MAE  0.7788 | RMSE  0.9915 *
# * Iter 676   | Elapsed     0.02s | MAE  0.8111 | RMSE  1.0118 *
# * Iter 677   | Elapsed     0.04s | MAE  0.7799 | RMSE  0.9892 *
# * Iter 678   | Elapsed     0.02s | MAE  0.8098 | RMSE  1.0264 *
# * Iter 679   | Elapsed     0.02s | MAE  0.8172 | RMSE  1.0162 *
# * Iter 680   | Elapsed     0.02s | MAE  0.8092 | RMSE  1.0060 *
# * Iter 681   | Elapsed     0.03s | MAE  0.7983 | RMSE  0.9952 *
# * Iter 682   | Elapsed     0.02s | MAE  0.8145 | RMSE  1.0250 *
# * Iter 683   | Elapsed     0.02s | MAE  0.7578 | RMSE  0.9561 *
# * Iter 684   | Elapsed     0.03s | MAE  0.7942 | RMSE  0.9996 *
# * Iter 685   | Elapsed     0.02s | MAE  0.7950 | RMSE  0.9996 *
# * Iter 686   | Elapsed     0.02s | MAE  0.8244 | RMSE  1.0389 *
# * Iter 687   | Elapsed     0.02s | MAE  0.7951 | RMSE  0.9960 *
# * Iter 688   | Elapsed     0.03s | MAE  0.8298 | RMSE  1.0263 *
# * Iter 689   | Elapsed     0.03s | MAE  0.8029 | RMSE  1.0150 *
# * Iter 690   | Elapsed     0.02s | MAE  0.7936 | RMSE  0.9892 *
# * Iter 691   | Elapsed     0.02s | MAE  0.8166 | RMSE  1.0127 *
# * Iter 692   | Elapsed     0.04s | MAE  0.7877 | RMSE  0.9926 *
# * Iter 693   | Elapsed     0.03s | MAE  0.7730 | RMSE  0.9679 *
# * Iter 694   | Elapsed     0.02s | MAE  0.7725 | RMSE  0.9705 *
# * Iter 695   | Elapsed     0.03s | MAE  0.7564 | RMSE  0.9690 *
# * Iter 696   | Elapsed     0.04s | MAE  0.8077 | RMSE  1.0085 *
# * Iter 697   | Elapsed     0.02s | MAE  0.7963 | RMSE  0.9874 *
# * Iter 698   | Elapsed     0.01s | MAE  0.8137 | RMSE  1.0136 *
# * Iter 699   | Elapsed     0.02s | MAE  0.7997 | RMSE  1.0098 *
# * Iter 700   | Elapsed     0.02s | MAE  0.7949 | RMSE  0.9933 *
# * Iter 701   | Elapsed     0.03s | MAE  0.7985 | RMSE  1.0186 *
# * Iter 702   | Elapsed     0.03s | MAE  0.8113 | RMSE  1.0158 *
# * Iter 703   | Elapsed     0.03s | MAE  0.8256 | RMSE  1.0450 *
# * Iter 704   | Elapsed     0.03s | MAE  0.8248 | RMSE  1.0268 *
# * Iter 705   | Elapsed     0.02s | MAE  0.8282 | RMSE  1.0204 *
# * Iter 706   | Elapsed     0.02s | MAE  0.8073 | RMSE  1.0120 *
# * Iter 707   | Elapsed     0.03s | MAE  0.7979 | RMSE  0.9827 *
# * Iter 708   | Elapsed     0.03s | MAE  0.7589 | RMSE  0.9617 *
# * Iter 709   | Elapsed     0.03s | MAE  0.7761 | RMSE  0.9617 *
# * Iter 710   | Elapsed     0.04s | MAE  0.7743 | RMSE  0.9725 *
# * Iter 711   | Elapsed     0.03s | MAE  0.7986 | RMSE  1.0044 *
# * Iter 712   | Elapsed     0.03s | MAE  0.8115 | RMSE  1.0104 *
# * Iter 713   | Elapsed     0.03s | MAE  0.7995 | RMSE  1.0141 *
# * Iter 714   | Elapsed     0.03s | MAE  0.8106 | RMSE  1.0199 *
# * Iter 715   | Elapsed     0.02s | MAE  0.8184 | RMSE  1.0356 *
# * Iter 716   | Elapsed     0.04s | MAE  0.8217 | RMSE  1.0258 *
# * Iter 717   | Elapsed     0.03s | MAE  0.7993 | RMSE  0.9943 *
# * Iter 718   | Elapsed     0.03s | MAE  0.8006 | RMSE  1.0035 *
# * Iter 719   | Elapsed     0.03s | MAE  0.8093 | RMSE  1.0212 *
# * Iter 720   | Elapsed     0.02s | MAE  0.8093 | RMSE  1.0109 *
# * Iter 721   | Elapsed     0.03s | MAE  0.8136 | RMSE  1.0083 *
# * Iter 722   | Elapsed     0.03s | MAE  0.8111 | RMSE  1.0103 *
# * Iter 723   | Elapsed     0.02s | MAE  0.8118 | RMSE  1.0106 *
# * Iter 724   | Elapsed     0.03s | MAE  0.8030 | RMSE  1.0182 *
# * Iter 725   | Elapsed     0.02s | MAE  0.8143 | RMSE  1.0318 *
# * Iter 726   | Elapsed     0.02s | MAE  0.8195 | RMSE  1.0499 *
# * Iter 727   | Elapsed     0.03s | MAE  0.8416 | RMSE  1.0455 *
# * Iter 728   | Elapsed     0.04s | MAE  0.8272 | RMSE  1.0295 *
# * Iter 729   | Elapsed     0.02s | MAE  0.8040 | RMSE  1.0051 *
# * Iter 730   | Elapsed     0.03s | MAE  0.7598 | RMSE  0.9749 *
# * Iter 731   | Elapsed     0.02s | MAE  0.7847 | RMSE  0.9824 *
# * Iter 732   | Elapsed     0.03s | MAE  0.7904 | RMSE  0.9858 *
# * Iter 733   | Elapsed     0.02s | MAE  0.7727 | RMSE  0.9773 *
# * Iter 734   | Elapsed     0.02s | MAE  0.7797 | RMSE  0.9683 *
# * Iter 735   | Elapsed     0.03s | MAE  0.8242 | RMSE  1.0379 *
# * Iter 736   | Elapsed     0.02s | MAE  0.7925 | RMSE  0.9929 *
# * Iter 737   | Elapsed     0.02s | MAE  0.8170 | RMSE  1.0289 *
# * Iter 738   | Elapsed     0.02s | MAE  0.7986 | RMSE  0.9983 *
# * Iter 739   | Elapsed     0.03s | MAE  0.8085 | RMSE  1.0119 *
# * Iter 740   | Elapsed     0.02s | MAE  0.8078 | RMSE  1.0091 *
# * Iter 741   | Elapsed     0.02s | MAE  0.8067 | RMSE  1.0270 *
# * Iter 742   | Elapsed     0.03s | MAE  0.7985 | RMSE  1.0003 *
# * Iter 743   | Elapsed     0.02s | MAE  0.8138 | RMSE  1.0180 *
# * Iter 744   | Elapsed     0.03s | MAE  0.8039 | RMSE  0.9994 *
# * Iter 745   | Elapsed     0.02s | MAE  0.8164 | RMSE  1.0149 *
# * Iter 746   | Elapsed     0.02s | MAE  0.7983 | RMSE  0.9919 *
# * Iter 747   | Elapsed     0.03s | MAE  0.7826 | RMSE  0.9797 *
# ...
# * Iter 810   | Elapsed     0.09s | MAE  0.8087 | RMSE  1.0076 *
# * Iter 811   | Elapsed     0.05s | MAE  0.8071 | RMSE  1.0090 *
# * Iter 812   | Elapsed     0.09s | MAE  0.8079 | RMSE  1.0087 *
# * Iter 813   | Elapsed     0.05s | MAE  0.8092 | RMSE  1.0115 *
# * Iter 814   | Elapsed     0.08s | MAE  0.8089 | RMSE  1.0112 *
# * Iter 815   | Elapsed     0.06s | MAE  0.8117 | RMSE  1.0135 *
# * Iter 816   | Elapsed     0.07s | MAE  0.8095 | RMSE  1.0104 *
# * Iter 817   | Elapsed     0.08s | MAE  0.8109 | RMSE  1.0107 *
# * Iter 818   | Elapsed     0.07s | MAE  0.8090 | RMSE  1.0098 *
# * Iter 819   | Elapsed     0.08s | MAE  0.8097 | RMSE  1.0116 *
# * Iter 820   | Elapsed     0.06s | MAE  0.8100 | RMSE  1.0101 *
# * Iter 821   | Elapsed     0.07s | MAE  0.8095 | RMSE  1.0118 *
# * Iter 822   | Elapsed     0.06s | MAE  0.8110 | RMSE  1.0110 *
# * Iter 823   | Elapsed     0.07s | MAE  0.8079 | RMSE  1.0097 *
# * Iter 824   | Elapsed     0.08s | MAE  0.8093 | RMSE  1.0105 *
# * Iter 825   | Elapsed     0.07s | MAE  0.8088 | RMSE  1.0096 *
# * Iter 826   | Elapsed     0.07s | MAE  0.8102 | RMSE  1.0107 *
# * Iter 827   | Elapsed     0.05s | MAE  0.8099 | RMSE  1.0116 *
# * Iter 828   | Elapsed     0.06s | MAE  0.8096 | RMSE  1.0104 *
# * Iter 829   | Elapsed     0.05s | MAE  0.8076 | RMSE  1.0088 *
# * Iter 830   | Elapsed     0.09s | MAE  0.8096 | RMSE  1.0119 *
# * Iter 831   | Elapsed     0.07s | MAE  0.8099 | RMSE  1.0107 *
# * Iter 832   | Elapsed     0.08s | MAE  0.8092 | RMSE  1.0101 *
# * Iter 833   | Elapsed     0.07s | MAE  0.8086 | RMSE  1.0094 *
# * Iter 834   | Elapsed     0.04s | MAE  0.8083 | RMSE  1.0090 *
# * Iter 835   | Elapsed     0.07s | MAE  0.8089 | RMSE  1.0112 *
# * Iter 836   | Elapsed     0.05s | MAE  0.8084 | RMSE  1.0101 *
# * Iter 837   | Elapsed     0.05s | MAE  0.8104 | RMSE  1.0109 *
# * Iter 838   | Elapsed     0.06s | MAE  0.8103 | RMSE  1.0113 *
# * Iter 839   | Elapsed     0.10s | MAE  0.8107 | RMSE  1.0105 *
# * Iter 840   | Elapsed     0.07s | MAE  0.8102 | RMSE  1.0116 *
# * Iter 841   | Elapsed     0.05s | MAE  0.8094 | RMSE  1.0103 *
# * Iter 842   | Elapsed     0.07s | MAE  0.8105 | RMSE  1.0103 *
# * Iter 843   | Elapsed     0.10s | MAE  0.8091 | RMSE  1.0094 *
# * Iter 844   | Elapsed     0.05s | MAE  0.8091 | RMSE  1.0096 *
# * Iter 845   | Elapsed     0.07s | MAE  0.8084 | RMSE  1.0097 *
# * Iter 846   | Elapsed     0.08s | MAE  0.8072 | RMSE  1.0086 *
# * Iter 847   | Elapsed     0.08s | MAE  0.8102 | RMSE  1.0112 *
# * Iter 848   | Elapsed     0.05s | MAE  0.8100 | RMSE  1.0105 *
# * Iter 849   | Elapsed     0.06s | MAE  0.8073 | RMSE  1.0085 *
# * Iter 850   | Elapsed     0.06s | MAE  0.8084 | RMSE  1.0086 *
# * Iter 851   | Elapsed     0.08s | MAE  0.8118 | RMSE  1.0129 *
# * Iter 852   | Elapsed     0.04s | MAE  0.8101 | RMSE  1.0107 *
# * Iter 853   | Elapsed     0.05s | MAE  0.8082 | RMSE  1.0098 *
# * Iter 854   | Elapsed     0.07s | MAE  0.8099 | RMSE  1.0106 *
# * Iter 855   | Elapsed     0.07s | MAE  0.8126 | RMSE  1.0133 *
# * Iter 856   | Elapsed     0.08s | MAE  0.8095 | RMSE  1.0119 *
# * Iter 857   | Elapsed     0.06s | MAE  0.8099 | RMSE  1.0093 *
# * Iter 858   | Elapsed     0.10s | MAE  0.8089 | RMSE  1.0108 *
# * Iter 859   | Elapsed     0.06s | MAE  0.8084 | RMSE  1.0098 *
# * Iter 860   | Elapsed     0.06s | MAE  0.8087 | RMSE  1.0092 *
# * Iter 861   | Elapsed     0.08s | MAE  0.8091 | RMSE  1.0105 *
# * Iter 862   | Elapsed     0.08s | MAE  0.8110 | RMSE  1.0108 *
# * Iter 863   | Elapsed     0.11s | MAE  0.8102 | RMSE  1.0126 *
# * Iter 864   | Elapsed     0.06s | MAE  0.8104 | RMSE  1.0119 *
# * Iter 865   | Elapsed     0.08s | MAE  0.8113 | RMSE  1.0125 *
# * Iter 866   | Elapsed     0.06s | MAE  0.8092 | RMSE  1.0113 *
# * Iter 867   | Elapsed     0.06s | MAE  0.8102 | RMSE  1.0096 *
# * Iter 868   | Elapsed     0.06s | MAE  0.8098 | RMSE  1.0111 *
# * Iter 869   | Elapsed     0.06s | MAE  0.8114 | RMSE  1.0122 *
# * Iter 870   | Elapsed     0.08s | MAE  0.8082 | RMSE  1.0093 *
# * Iter 871   | Elapsed     0.07s | MAE  0.8086 | RMSE  1.0101 *
# * Iter 872   | Elapsed     0.08s | MAE  0.8107 | RMSE  1.0120 *
# * Iter 873   | Elapsed     0.05s | MAE  0.8095 | RMSE  1.0105 *
# * Iter 874   | Elapsed     0.06s | MAE  0.8103 | RMSE  1.0114 *
# * Iter 875   | Elapsed     0.08s | MAE  0.8092 | RMSE  1.0114 *
# * Iter 876   | Elapsed     0.07s | MAE  0.8096 | RMSE  1.0101 *
# * Iter 877   | Elapsed     0.09s | MAE  0.8094 | RMSE  1.0112 *
# * Iter 878   | Elapsed     0.08s | MAE  0.8089 | RMSE  1.0107 *
# * Iter 879   | Elapsed     0.09s | MAE  0.8094 | RMSE  1.0103 *
# * Iter 880   | Elapsed     0.07s | MAE  0.8094 | RMSE  1.0107 *
# * Iter 881   | Elapsed     0.06s | MAE  0.8093 | RMSE  1.0102 *
# * Iter 882   | Elapsed     0.09s | MAE  0.8088 | RMSE  1.0098 *
# * Iter 883   | Elapsed     0.08s | MAE  0.8094 | RMSE  1.0113 *
# * Iter 884   | Elapsed     0.09s | MAE  0.8094 | RMSE  1.0106 *
# * Iter 885   | Elapsed     0.06s | MAE  0.8107 | RMSE  1.0118 *
# * Iter 886   | Elapsed     0.08s | MAE  0.8095 | RMSE  1.0105 *
# * Iter 887   | Elapsed     0.08s | MAE  0.8090 | RMSE  1.0106 *
# * Iter 888   | Elapsed     0.05s | MAE  0.8068 | RMSE  1.0082 *
# * Iter 889   | Elapsed     0.10s | MAE  0.8096 | RMSE  1.0099 *
# * Iter 890   | Elapsed     0.04s | MAE  0.8117 | RMSE  1.0112 *
# * Iter 891   | Elapsed     0.07s | MAE  0.8095 | RMSE  1.0101 *
# * Iter 892   | Elapsed     0.07s | MAE  0.8112 | RMSE  1.0128 *
# * Iter 893   | Elapsed     0.08s | MAE  0.8084 | RMSE  1.0100 *
# * Iter 894   | Elapsed     0.06s | MAE  0.8094 | RMSE  1.0110 *
# * Iter 895   | Elapsed     0.07s | MAE  0.8089 | RMSE  1.0113 *
# * Iter 896   | Elapsed     0.07s | MAE  0.8092 | RMSE  1.0102 *
# * Iter 897   | Elapsed     0.07s | MAE  0.8118 | RMSE  1.0125 *
# * Iter 898   | Elapsed     0.06s | MAE  0.8095 | RMSE  1.0109 *
# * Iter 899   | Elapsed     0.08s | MAE  0.8079 | RMSE  1.0087 *
# * Iter 900   | Elapsed     0.07s | MAE  0.8078 | RMSE  1.0081 *
# * Iter 901   | Elapsed     0.08s | MAE  0.8091 | RMSE  1.0106 *
# * Iter 902   | Elapsed     0.08s | MAE  0.8081 | RMSE  1.0086 *
# * Iter 903   | Elapsed     0.06s | MAE  0.8078 | RMSE  1.0098 *
# * Iter 904   | Elapsed     0.06s | MAE  0.8065 | RMSE  1.0076 *
# * Iter 905   | Elapsed     0.05s | MAE  0.8100 | RMSE  1.0114 *
# * Iter 906   | Elapsed     0.10s | MAE  0.8077 | RMSE  1.0090 *
# * Iter 907   | Elapsed     0.05s | MAE  0.8096 | RMSE  1.0108 *
# * Iter 908   | Elapsed     0.09s | MAE  0.8095 | RMSE  1.0099 *
# * Iter 909   | Elapsed     0.07s | MAE  0.8093 | RMSE  1.0098 *
# * Iter 910   | Elapsed     0.07s | MAE  0.8076 | RMSE  1.0092 *
# * Iter 911   | Elapsed     0.07s | MAE  0.8082 | RMSE  1.0095 *
# * Iter 912   | Elapsed     0.10s | MAE  0.8098 | RMSE  1.0098 *
# * Iter 913   | Elapsed     0.08s | MAE  0.8097 | RMSE  1.0110 *
# * Iter 914   | Elapsed     0.09s | MAE  0.8087 | RMSE  1.0091 *
# * Iter 915   | Elapsed     0.06s | MAE  0.8100 | RMSE  1.0107 *
# * Iter 916   | Elapsed     0.09s | MAE  0.8093 | RMSE  1.0115 *
# * Iter 917   | Elapsed     0.08s | MAE  0.8117 | RMSE  1.0126 *
# * Iter 918   | Elapsed     0.05s | MAE  0.8098 | RMSE  1.0106 *
# * Iter 919   | Elapsed     0.05s | MAE  0.8062 | RMSE  1.0082 *
# * Iter 920   | Elapsed     0.04s | MAE  0.8095 | RMSE  1.0105 *
# * Iter 921   | Elapsed     0.04s | MAE  0.8107 | RMSE  1.0126 *
# * Iter 922   | Elapsed     0.07s | MAE  0.8092 | RMSE  1.0096 *
# * Iter 923   | Elapsed     0.08s | MAE  0.8100 | RMSE  1.0104 *
# * Iter 924   | Elapsed     0.03s | MAE  0.8096 | RMSE  1.0101 *
# * Iter 925   | Elapsed     0.07s | MAE  0.8097 | RMSE  1.0099 *
# * Iter 926   | Elapsed     0.08s | MAE  0.8094 | RMSE  1.0118 *
# * Iter 927   | Elapsed     0.13s | MAE  0.8094 | RMSE  1.0099 *
# * Iter 928   | Elapsed     0.07s | MAE  0.8088 | RMSE  1.0094 *
# * Iter 929   | Elapsed     0.03s | MAE  0.8086 | RMSE  1.0110 *
# * Iter 930   | Elapsed     0.06s | MAE  0.8082 | RMSE  1.0091 *
# * Iter 931   | Elapsed     0.07s | MAE  0.8112 | RMSE  1.0119 *
# * Iter 932   | Elapsed     0.10s | MAE  0.8101 | RMSE  1.0094 *
# * Iter 933   | Elapsed     0.06s | MAE  0.8088 | RMSE  1.0099 *
# * Iter 934   | Elapsed     0.04s | MAE  0.8111 | RMSE  1.0127 *
# * Iter 935   | Elapsed     0.06s | MAE  0.8093 | RMSE  1.0109 *
# * Iter 936   | Elapsed     0.06s | MAE  0.8091 | RMSE  1.0100 *
# * Iter 937   | Elapsed     0.08s | MAE  0.8079 | RMSE  1.0096 *
# * Iter 938   | Elapsed     0.05s | MAE  0.8091 | RMSE  1.0106 *
# * Iter 939   | Elapsed     0.08s | MAE  0.8081 | RMSE  1.0093 *
# * Iter 940   | Elapsed     0.06s | MAE  0.8113 | RMSE  1.0125 *
# * Iter 941   | Elapsed     0.06s | MAE  0.8099 | RMSE  1.0107 *
# * Iter 942   | Elapsed     0.07s | MAE  0.8093 | RMSE  1.0108 *
# * Iter 943   | Elapsed     0.12s | MAE  0.8108 | RMSE  1.0120 *
# * Iter 944   | Elapsed     0.08s | MAE  0.8094 | RMSE  1.0107 *
# * Iter 945   | Elapsed     0.04s | MAE  0.8094 | RMSE  1.0108 *
# * Iter 946   | Elapsed     0.06s | MAE  0.8099 | RMSE  1.0113 *
# * Iter 947   | Elapsed     0.06s | MAE  0.8076 | RMSE  1.0089 *
# * Iter 948   | Elapsed     0.06s | MAE  0.8085 | RMSE  1.0084 *
# * Iter 949   | Elapsed     0.10s | MAE  0.8094 | RMSE  1.0108 *
# * Iter 950   | Elapsed     0.06s | MAE  0.8108 | RMSE  1.0102 *
# * Iter 951   | Elapsed     0.06s | MAE  0.8105 | RMSE  1.0119 *
# * Iter 952   | Elapsed     0.09s | MAE  0.8094 | RMSE  1.0114 *
# * Iter 953   | Elapsed     0.06s | MAE  0.8100 | RMSE  1.0107 *
# * Iter 954   | Elapsed     0.06s | MAE  0.8109 | RMSE  1.0123 *
# * Iter 955   | Elapsed     0.08s | MAE  0.8102 | RMSE  1.0118 *
# * Iter 956   | Elapsed     0.08s | MAE  0.8084 | RMSE  1.0091 *
# * Iter 957   | Elapsed     0.07s | MAE  0.8123 | RMSE  1.0136 *
# * Iter 958   | Elapsed     0.06s | MAE  0.8106 | RMSE  1.0108 *
# * Iter 959   | Elapsed     0.11s | MAE  0.8090 | RMSE  1.0094 *
# * Iter 960   | Elapsed     0.06s | MAE  0.8085 | RMSE  1.0097 *
# * Iter 961   | Elapsed     0.08s | MAE  0.8083 | RMSE  1.0094 *
# * Iter 962   | Elapsed     0.04s | MAE  0.8081 | RMSE  1.0089 *
# * Iter 963   | Elapsed     0.10s | MAE  0.8094 | RMSE  1.0102 *
# * Iter 964   | Elapsed     0.09s | MAE  0.8094 | RMSE  1.0115 *
# * Iter 965   | Elapsed     0.06s | MAE  0.8102 | RMSE  1.0102 *
# * Iter 966   | Elapsed     0.10s | MAE  0.8109 | RMSE  1.0114 *
# * Iter 967   | Elapsed     0.07s | MAE  0.8086 | RMSE  1.0090 *
# * Iter 968   | Elapsed     0.07s | MAE  0.8079 | RMSE  1.0079 *
# * Iter 969   | Elapsed     0.04s | MAE  0.8076 | RMSE  1.0079 *
# * Iter 970   | Elapsed     0.07s | MAE  0.8064 | RMSE  1.0073 *
# * Iter 971   | Elapsed     0.05s | MAE  0.8091 | RMSE  1.0101 *
# * Iter 972   | Elapsed     0.09s | MAE  0.8094 | RMSE  1.0108 *
# * Iter 973   | Elapsed     0.08s | MAE  0.8100 | RMSE  1.0121 *
# * Iter 974   | Elapsed     0.08s | MAE  0.8095 | RMSE  1.0113 *
# * Iter 975   | Elapsed     0.06s | MAE  0.8093 | RMSE  1.0097 *
# * Iter 976   | Elapsed     0.08s | MAE  0.8118 | RMSE  1.0109 *
# * Iter 977   | Elapsed     0.06s | MAE  0.8109 | RMSE  1.0123 *
# * Iter 978   | Elapsed     0.05s | MAE  0.8090 | RMSE  1.0093 *
# * Iter 979   | Elapsed     0.06s | MAE  0.8085 | RMSE  1.0079 *
# * Iter 980   | Elapsed     0.08s | MAE  0.8105 | RMSE  1.0118 *
# * Iter 981   | Elapsed     0.05s | MAE  0.8104 | RMSE  1.0111 *
# * Iter 982   | Elapsed     0.07s | MAE  0.8099 | RMSE  1.0113 *
# * Iter 983   | Elapsed     0.05s | MAE  0.8095 | RMSE  1.0094 *
# * Iter 984   | Elapsed     0.07s | MAE  0.8107 | RMSE  1.0104 *
# * Iter 985   | Elapsed     0.09s | MAE  0.8108 | RMSE  1.0116 *
# * Iter 986   | Elapsed     0.09s | MAE  0.8096 | RMSE  1.0113 *
# * Iter 987   | Elapsed     0.07s | MAE  0.8086 | RMSE  1.0089 *
# * Iter 988   | Elapsed     0.06s | MAE  0.8105 | RMSE  1.0122 *
# * Iter 989   | Elapsed     0.06s | MAE  0.8098 | RMSE  1.0103 *
# * Iter 990   | Elapsed     0.04s | MAE  0.8090 | RMSE  1.0104 *
# * Iter 991   | Elapsed     0.06s | MAE  0.8108 | RMSE  1.0119 *
# * Iter 992   | Elapsed     0.04s | MAE  0.8101 | RMSE  1.0111 *
# * Iter 993   | Elapsed     0.06s | MAE  0.8096 | RMSE  1.0102 *
# * Iter 994   | Elapsed     0.03s | MAE  0.8082 | RMSE  1.0102 *
# * Iter 995   | Elapsed     0.08s | MAE  0.8097 | RMSE  1.0097 *
# * Iter 996   | Elapsed     0.08s | MAE  0.8094 | RMSE  1.0113 *
# * Iter 997   | Elapsed     0.04s | MAE  0.8110 | RMSE  1.0130 *
# * Iter 998   | Elapsed     0.05s | MAE  0.8094 | RMSE  1.0099 *
# * Iter 999   | Elapsed     0.04s | MAE  0.8098 | RMSE  1.0118 *
# * Iter 1000  | Elapsed     0.06s | MAE  0.8100 | RMSE  1.0108 *
# * Iter TOTAL | Elapsed    69.93s | MAE  0.7995 | RMSE  0.9972 *
# /usr/local/lib/python3.10/dist-packages/pyBKTR/bktr.py:856: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_index(inplace=True)
#    Dataset_Type  Lengthscale  Iter     B_MAE    B_RMSE     Y_MAE    Y_RMSE
# 0       Smaller            3     1  0.791410  1.001138  1.378541  1.782494
# 1       Smaller            3     2  0.453882  0.596162  1.505989  2.062713
# 2       Smaller            3     3  0.680061  0.890005  1.361288  1.778193
# 3       Smaller            3     4  0.525499  0.687352  1.131098  1.476524
# 4       Smaller            3     5  0.747671  0.993836  1.498948  1.996148
# 5       Smaller            3     6  0.825085  1.064435  1.372535  1.725401
# 6       Smaller            3     7  0.974488  1.436641  1.529864  2.126434
# 7       Smaller            3     8  0.719792  1.032030  1.932401  2.474643
# 8       Smaller            3     9  1.084566  1.425300  2.758249  4.654967
# 9       Smaller            3    10  0.819045  1.151139  2.299390  3.433995
# 10      Smaller            6     1  0.549024  0.685846  1.157535  1.520684
# 11      Smaller            6     2  0.395283  0.520298  0.918409  1.122545
# 12      Smaller            6     3  0.457156  0.656467  1.186992  1.718402
# 13      Smaller            6     4  0.459410  0.593339  0.928898  1.125479
# 14      Smaller            6     5  0.604084  0.875348  0.979155  1.251686
# 15      Smaller            6     6  0.676626  0.929274  1.151307  1.523635
# 16      Smaller            6     7  0.426265  0.582430  1.155952  1.459450
# 17      Smaller            6     8  0.544765  0.664668  1.246082  1.563944
# 18      Smaller            6     9  0.400783  0.523890  1.035317  1.265424
# 19      Smaller            6    10  0.628389  1.094826  1.294607  1.654980
# 20       Larger            3     1  0.888497  1.324170  2.959811  5.539562
# 21       Larger            3     2  1.489325  3.052130  3.160984  4.518689
# 22       Larger            3     3  2.472708  4.360654  5.075419  7.881421
# 23       Larger            3     4  1.723439  3.124540  2.133686  2.903264
# 24       Larger            3     5  1.152435  1.749139  3.102309  4.710675
# 25       Larger            3     6  0.743559  1.042065  1.566226  1.983906
# 26       Larger            3     7  0.761347  1.142118  1.405959  1.855604
# 27       Larger            3     8  1.998965  3.434396  3.736328  6.228773
# 28       Larger            3     9  0.537382  0.810299  1.358065  1.807288
# 29       Larger            3    10  0.833427  1.307217  1.516441  1.904508
# 30       Larger            6     1  0.172275  0.256330  0.849923  1.078862
# 31       Larger            6     2  0.174988  0.229334  0.890253  1.100439
# 32       Larger            6     3  0.286916  0.493915  1.007061  1.312708
# 33       Larger            6     4  0.184306  0.302747  0.836928  1.028051
# 34       Larger            6     5  0.453800  0.765235  1.446992  2.030340
# 35       Larger            6     6  0.258087  0.419924  0.912762  1.134281
# 36       Larger            6     7  0.235027  0.363326  0.931737  1.197960
# 37       Larger            6     8  0.279520  0.387816  0.892676  1.134332
# 38       Larger            6     9  0.279302  0.446174  0.922619  1.152341
# 39       Larger            6    10  0.191097  0.307652  0.895774  1.125158
# <ipython-input-6-c5019a6fb8f9>:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data_df.sort_index(inplace=True)

# %%
from google.colab import runtime
runtime.unassign()
