# %%
# !pip install pyBKTR
# Out:
# Collecting pyBKTR
#   Downloading pyBKTR-0.2.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (2.3.1+cu121)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (1.26.4)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (2.1.4)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (5.15.0)
# Collecting formulaic>=0.5.2 (from pyBKTR)
#   Downloading formulaic-1.0.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.5.2->pyBKTR)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->pyBKTR) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->pyBKTR) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.12.1->pyBKTR)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.12.1->pyBKTR)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.2->pyBKTR) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->pyBKTR) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.1->pyBKTR) (1.3.0)
# Downloading pyBKTR-0.2.0-py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.9/221.9 kB 5.7 MB/s eta 0:00:00
# Downloading formulaic-1.0.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 kB 6.0 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, interface-meta, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, formulaic, pyBKTR
# Successfully installed formulaic-1.0.2 interface-meta-1.3.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 pyBKTR-0.2.0

# %%
from pyBKTR.bktr import BKTRRegressor
from pyBKTR.examples.bixi import BixiData

bixi_data = BixiData(is_light=True)
bktr_regressor = BKTRRegressor(
    data_df=bixi_data.data_df,
    spatial_positions_df=bixi_data.spatial_positions_df,
    temporal_positions_df=bixi_data.temporal_positions_df,
    burn_in_iter=200,
    sampling_iter=200
)
bktr_regressor.mcmc_sampling()
print(bktr_regressor.summary)
# Out:
# * Iter 1     | Elapsed     0.22s | MAE  0.1013 | RMSE  0.1372 *
# * Iter 2     | Elapsed     0.04s | MAE  0.0768 | RMSE  0.0998 *
# * Iter 3     | Elapsed     0.07s | MAE  0.0662 | RMSE  0.0865 *
# * Iter 4     | Elapsed     0.05s | MAE  0.0632 | RMSE  0.0820 *
# * Iter 5     | Elapsed     0.07s | MAE  0.0605 | RMSE  0.0793 *
# * Iter 6     | Elapsed     0.08s | MAE  0.0570 | RMSE  0.0736 *
# * Iter 7     | Elapsed     0.08s | MAE  0.0547 | RMSE  0.0712 *
# * Iter 8     | Elapsed     0.06s | MAE  0.0556 | RMSE  0.0725 *
# * Iter 9     | Elapsed     0.09s | MAE  0.0563 | RMSE  0.0738 *
# * Iter 10    | Elapsed     0.08s | MAE  0.0559 | RMSE  0.0735 *
# * Iter 11    | Elapsed     0.06s | MAE  0.0544 | RMSE  0.0699 *
# * Iter 12    | Elapsed     0.08s | MAE  0.0540 | RMSE  0.0705 *
# * Iter 13    | Elapsed     0.11s | MAE  0.0537 | RMSE  0.0689 *
# * Iter 14    | Elapsed     0.11s | MAE  0.0523 | RMSE  0.0675 *
# * Iter 15    | Elapsed     0.07s | MAE  0.0528 | RMSE  0.0677 *
# * Iter 16    | Elapsed     0.06s | MAE  0.0518 | RMSE  0.0664 *
# * Iter 17    | Elapsed     0.09s | MAE  0.0526 | RMSE  0.0678 *
# * Iter 18    | Elapsed     0.10s | MAE  0.0517 | RMSE  0.0671 *
# * Iter 19    | Elapsed     0.09s | MAE  0.0529 | RMSE  0.0679 *
# * Iter 20    | Elapsed     0.07s | MAE  0.0521 | RMSE  0.0680 *
# * Iter 21    | Elapsed     0.07s | MAE  0.0505 | RMSE  0.0655 *
# * Iter 22    | Elapsed     0.10s | MAE  0.0518 | RMSE  0.0672 *
# * Iter 23    | Elapsed     0.09s | MAE  0.0505 | RMSE  0.0652 *
# * Iter 24    | Elapsed     0.05s | MAE  0.0503 | RMSE  0.0656 *
# * Iter 25    | Elapsed     0.04s | MAE  0.0526 | RMSE  0.0682 *
# * Iter 26    | Elapsed     0.06s | MAE  0.0510 | RMSE  0.0668 *
# * Iter 27    | Elapsed     0.06s | MAE  0.0523 | RMSE  0.0679 *
# * Iter 28    | Elapsed     0.07s | MAE  0.0539 | RMSE  0.0699 *
# * Iter 29    | Elapsed     0.08s | MAE  0.0548 | RMSE  0.0702 *
# * Iter 30    | Elapsed     0.04s | MAE  0.0529 | RMSE  0.0685 *
# * Iter 31    | Elapsed     0.06s | MAE  0.0544 | RMSE  0.0698 *
# * Iter 32    | Elapsed     0.06s | MAE  0.0537 | RMSE  0.0691 *
# * Iter 33    | Elapsed     0.06s | MAE  0.0534 | RMSE  0.0696 *
# * Iter 34    | Elapsed     0.05s | MAE  0.0528 | RMSE  0.0678 *
# * Iter 35    | Elapsed     0.06s | MAE  0.0538 | RMSE  0.0699 *
# * Iter 36    | Elapsed     0.10s | MAE  0.0535 | RMSE  0.0698 *
# * Iter 37    | Elapsed     0.08s | MAE  0.0536 | RMSE  0.0699 *
# * Iter 38    | Elapsed     0.06s | MAE  0.0530 | RMSE  0.0690 *
# * Iter 39    | Elapsed     0.12s | MAE  0.0530 | RMSE  0.0677 *
# * Iter 40    | Elapsed     0.06s | MAE  0.0516 | RMSE  0.0668 *
# * Iter 41    | Elapsed     0.06s | MAE  0.0522 | RMSE  0.0666 *
# * Iter 42    | Elapsed     0.06s | MAE  0.0518 | RMSE  0.0668 *
# * Iter 43    | Elapsed     0.06s | MAE  0.0516 | RMSE  0.0663 *
# * Iter 44    | Elapsed     0.08s | MAE  0.0522 | RMSE  0.0663 *
# * Iter 45    | Elapsed     0.07s | MAE  0.0517 | RMSE  0.0658 *
# * Iter 46    | Elapsed     0.08s | MAE  0.0508 | RMSE  0.0653 *
# * Iter 47    | Elapsed     0.08s | MAE  0.0505 | RMSE  0.0644 *
# * Iter 48    | Elapsed     0.12s | MAE  0.0492 | RMSE  0.0637 *
# * Iter 49    | Elapsed     0.10s | MAE  0.0501 | RMSE  0.0647 *
# * Iter 50    | Elapsed     0.09s | MAE  0.0498 | RMSE  0.0643 *
# * Iter 51    | Elapsed     0.07s | MAE  0.0513 | RMSE  0.0657 *
# * Iter 52    | Elapsed     0.09s | MAE  0.0511 | RMSE  0.0656 *
# * Iter 53    | Elapsed     0.09s | MAE  0.0507 | RMSE  0.0650 *
# * Iter 54    | Elapsed     0.05s | MAE  0.0518 | RMSE  0.0668 *
# * Iter 55    | Elapsed     0.07s | MAE  0.0515 | RMSE  0.0660 *
# * Iter 56    | Elapsed     0.07s | MAE  0.0504 | RMSE  0.0651 *
# * Iter 57    | Elapsed     0.08s | MAE  0.0500 | RMSE  0.0649 *
# * Iter 58    | Elapsed     0.09s | MAE  0.0520 | RMSE  0.0671 *
# * Iter 59    | Elapsed     0.05s | MAE  0.0535 | RMSE  0.0680 *
# * Iter 60    | Elapsed     0.07s | MAE  0.0501 | RMSE  0.0645 *
# * Iter 61    | Elapsed     0.08s | MAE  0.0494 | RMSE  0.0633 *
# * Iter 62    | Elapsed     0.10s | MAE  0.0517 | RMSE  0.0665 *
# * Iter 63    | Elapsed     0.06s | MAE  0.0531 | RMSE  0.0686 *
# * Iter 64    | Elapsed     0.05s | MAE  0.0506 | RMSE  0.0651 *
# * Iter 65    | Elapsed     0.05s | MAE  0.0500 | RMSE  0.0644 *
# * Iter 66    | Elapsed     0.08s | MAE  0.0500 | RMSE  0.0650 *
# * Iter 67    | Elapsed     0.06s | MAE  0.0509 | RMSE  0.0653 *
# * Iter 68    | Elapsed     0.07s | MAE  0.0507 | RMSE  0.0656 *
# * Iter 69    | Elapsed     0.15s | MAE  0.0518 | RMSE  0.0664 *
# * Iter 70    | Elapsed     0.08s | MAE  0.0502 | RMSE  0.0652 *
# * Iter 71    | Elapsed     0.09s | MAE  0.0518 | RMSE  0.0661 *
# * Iter 72    | Elapsed     0.08s | MAE  0.0501 | RMSE  0.0639 *
# * Iter 73    | Elapsed     0.16s | MAE  0.0523 | RMSE  0.0682 *
# * Iter 74    | Elapsed     0.10s | MAE  0.0491 | RMSE  0.0647 *
# * Iter 75    | Elapsed     0.09s | MAE  0.0494 | RMSE  0.0638 *
# * Iter 76    | Elapsed     0.10s | MAE  0.0488 | RMSE  0.0635 *
# * Iter 77    | Elapsed     0.11s | MAE  0.0511 | RMSE  0.0652 *
# * Iter 78    | Elapsed     0.14s | MAE  0.0505 | RMSE  0.0653 *
# * Iter 79    | Elapsed     0.09s | MAE  0.0502 | RMSE  0.0651 *
# * Iter 80    | Elapsed     0.10s | MAE  0.0503 | RMSE  0.0660 *
# * Iter 81    | Elapsed     0.07s | MAE  0.0511 | RMSE  0.0673 *
# * Iter 82    | Elapsed     0.12s | MAE  0.0509 | RMSE  0.0657 *
# * Iter 83    | Elapsed     0.10s | MAE  0.0509 | RMSE  0.0659 *
# * Iter 84    | Elapsed     0.10s | MAE  0.0513 | RMSE  0.0656 *
# * Iter 85    | Elapsed     0.14s | MAE  0.0512 | RMSE  0.0658 *
# * Iter 86    | Elapsed     0.09s | MAE  0.0502 | RMSE  0.0653 *
# * Iter 87    | Elapsed     0.19s | MAE  0.0509 | RMSE  0.0664 *
# * Iter 88    | Elapsed     0.12s | MAE  0.0507 | RMSE  0.0653 *
# * Iter 89    | Elapsed     0.15s | MAE  0.0494 | RMSE  0.0642 *
# * Iter 90    | Elapsed     0.10s | MAE  0.0504 | RMSE  0.0650 *
# * Iter 91    | Elapsed     0.09s | MAE  0.0527 | RMSE  0.0680 *
# * Iter 92    | Elapsed     0.06s | MAE  0.0521 | RMSE  0.0673 *
# * Iter 93    | Elapsed     0.11s | MAE  0.0524 | RMSE  0.0677 *
# * Iter 94    | Elapsed     0.10s | MAE  0.0503 | RMSE  0.0656 *
# * Iter 95    | Elapsed     0.12s | MAE  0.0520 | RMSE  0.0665 *
# * Iter 96    | Elapsed     0.10s | MAE  0.0512 | RMSE  0.0650 *
# * Iter 97    | Elapsed     0.04s | MAE  0.0520 | RMSE  0.0663 *
# * Iter 98    | Elapsed     0.08s | MAE  0.0503 | RMSE  0.0658 *
# * Iter 99    | Elapsed     0.07s | MAE  0.0506 | RMSE  0.0661 *
# * Iter 100   | Elapsed     0.06s | MAE  0.0540 | RMSE  0.0698 *
# * Iter 101   | Elapsed     0.05s | MAE  0.0527 | RMSE  0.0690 *
# * Iter 102   | Elapsed     0.09s | MAE  0.0523 | RMSE  0.0670 *
# * Iter 103   | Elapsed     0.05s | MAE  0.0518 | RMSE  0.0655 *
# * Iter 104   | Elapsed     0.07s | MAE  0.0503 | RMSE  0.0653 *
# * Iter 105   | Elapsed     0.10s | MAE  0.0506 | RMSE  0.0646 *
# * Iter 106   | Elapsed     0.04s | MAE  0.0507 | RMSE  0.0648 *
# * Iter 107   | Elapsed     0.07s | MAE  0.0498 | RMSE  0.0652 *
# * Iter 108   | Elapsed     0.06s | MAE  0.0501 | RMSE  0.0642 *
# * Iter 109   | Elapsed     0.07s | MAE  0.0503 | RMSE  0.0640 *
# * Iter 110   | Elapsed     0.05s | MAE  0.0497 | RMSE  0.0641 *
# * Iter 111   | Elapsed     0.06s | MAE  0.0500 | RMSE  0.0641 *
# * Iter 112   | Elapsed     0.05s | MAE  0.0490 | RMSE  0.0637 *
# * Iter 113   | Elapsed     0.07s | MAE  0.0493 | RMSE  0.0632 *
# * Iter 114   | Elapsed     0.06s | MAE  0.0502 | RMSE  0.0646 *
# * Iter 115   | Elapsed     0.07s | MAE  0.0505 | RMSE  0.0652 *
# * Iter 116   | Elapsed     0.05s | MAE  0.0519 | RMSE  0.0660 *
# * Iter 117   | Elapsed     0.10s | MAE  0.0501 | RMSE  0.0640 *
# * Iter 118   | Elapsed     0.07s | MAE  0.0495 | RMSE  0.0633 *
# * Iter 119   | Elapsed     0.06s | MAE  0.0507 | RMSE  0.0654 *
# * Iter 120   | Elapsed     0.10s | MAE  0.0509 | RMSE  0.0659 *
# * Iter 121   | Elapsed     0.09s | MAE  0.0510 | RMSE  0.0660 *
# * Iter 122   | Elapsed     0.06s | MAE  0.0510 | RMSE  0.0657 *
# * Iter 123   | Elapsed     0.08s | MAE  0.0509 | RMSE  0.0660 *
# * Iter 124   | Elapsed     0.06s | MAE  0.0507 | RMSE  0.0655 *
# * Iter 125   | Elapsed     0.11s | MAE  0.0510 | RMSE  0.0656 *
# * Iter 126   | Elapsed     0.06s | MAE  0.0514 | RMSE  0.0670 *
# * Iter 127   | Elapsed     0.08s | MAE  0.0532 | RMSE  0.0693 *
# * Iter 128   | Elapsed     0.07s | MAE  0.0537 | RMSE  0.0694 *
# * Iter 129   | Elapsed     0.05s | MAE  0.0540 | RMSE  0.0693 *
# * Iter 130   | Elapsed     0.06s | MAE  0.0516 | RMSE  0.0657 *
# * Iter 131   | Elapsed     0.04s | MAE  0.0516 | RMSE  0.0658 *
# * Iter 132   | Elapsed     0.06s | MAE  0.0511 | RMSE  0.0653 *
# * Iter 133   | Elapsed     0.06s | MAE  0.0501 | RMSE  0.0645 *
# * Iter 134   | Elapsed     0.04s | MAE  0.0494 | RMSE  0.0635 *
# * Iter 135   | Elapsed     0.08s | MAE  0.0501 | RMSE  0.0643 *
# * Iter 136   | Elapsed     0.07s | MAE  0.0515 | RMSE  0.0665 *
# * Iter 137   | Elapsed     0.06s | MAE  0.0503 | RMSE  0.0650 *
# * Iter 138   | Elapsed     0.07s | MAE  0.0501 | RMSE  0.0645 *
# * Iter 139   | Elapsed     0.05s | MAE  0.0519 | RMSE  0.0660 *
# * Iter 140   | Elapsed     0.07s | MAE  0.0518 | RMSE  0.0667 *
# * Iter 141   | Elapsed     0.11s | MAE  0.0519 | RMSE  0.0671 *
# * Iter 142   | Elapsed     0.08s | MAE  0.0522 | RMSE  0.0682 *
# * Iter 143   | Elapsed     0.07s | MAE  0.0514 | RMSE  0.0671 *
# * Iter 144   | Elapsed     0.07s | MAE  0.0534 | RMSE  0.0680 *
# * Iter 145   | Elapsed     0.07s | MAE  0.0519 | RMSE  0.0677 *
# * Iter 146   | Elapsed     0.09s | MAE  0.0511 | RMSE  0.0664 *
# * Iter 147   | Elapsed     0.15s | MAE  0.0506 | RMSE  0.0664 *
# * Iter 148   | Elapsed     0.07s | MAE  0.0512 | RMSE  0.0663 *
# * Iter 149   | Elapsed     0.05s | MAE  0.0509 | RMSE  0.0656 *
# * Iter 150   | Elapsed     0.05s | MAE  0.0507 | RMSE  0.0653 *
# * Iter 151   | Elapsed     0.05s | MAE  0.0499 | RMSE  0.0643 *
# * Iter 152   | Elapsed     0.07s | MAE  0.0518 | RMSE  0.0666 *
# * Iter 153   | Elapsed     0.08s | MAE  0.0510 | RMSE  0.0647 *
# * Iter 154   | Elapsed     0.05s | MAE  0.0507 | RMSE  0.0654 *
# * Iter 155   | Elapsed     0.08s | MAE  0.0514 | RMSE  0.0670 *
# * Iter 156   | Elapsed     0.09s | MAE  0.0525 | RMSE  0.0670 *
# * Iter 157   | Elapsed     0.08s | MAE  0.0511 | RMSE  0.0661 *
# * Iter 158   | Elapsed     0.06s | MAE  0.0525 | RMSE  0.0667 *
# * Iter 159   | Elapsed     0.07s | MAE  0.0505 | RMSE  0.0650 *
# * Iter 160   | Elapsed     0.07s | MAE  0.0549 | RMSE  0.0689 *
# * Iter 161   | Elapsed     0.08s | MAE  0.0523 | RMSE  0.0671 *
# * Iter 162   | Elapsed     0.11s | MAE  0.0514 | RMSE  0.0650 *
# * Iter 163   | Elapsed     0.08s | MAE  0.0526 | RMSE  0.0665 *
# * Iter 164   | Elapsed     0.12s | MAE  0.0507 | RMSE  0.0650 *
# * Iter 165   | Elapsed     0.10s | MAE  0.0525 | RMSE  0.0666 *
# * Iter 166   | Elapsed     0.08s | MAE  0.0521 | RMSE  0.0667 *
# * Iter 167   | Elapsed     0.05s | MAE  0.0530 | RMSE  0.0688 *
# * Iter 168   | Elapsed     0.07s | MAE  0.0529 | RMSE  0.0683 *
# * Iter 169   | Elapsed     0.05s | MAE  0.0526 | RMSE  0.0672 *
# * Iter 170   | Elapsed     0.08s | MAE  0.0517 | RMSE  0.0677 *
# * Iter 171   | Elapsed     0.08s | MAE  0.0529 | RMSE  0.0678 *
# * Iter 172   | Elapsed     0.07s | MAE  0.0532 | RMSE  0.0685 *
# * Iter 173   | Elapsed     0.07s | MAE  0.0532 | RMSE  0.0678 *
# * Iter 174   | Elapsed     0.06s | MAE  0.0512 | RMSE  0.0660 *
# * Iter 175   | Elapsed     0.07s | MAE  0.0511 | RMSE  0.0660 *
# * Iter 176   | Elapsed     0.06s | MAE  0.0524 | RMSE  0.0666 *
# * Iter 177   | Elapsed     0.06s | MAE  0.0519 | RMSE  0.0673 *
# * Iter 178   | Elapsed     0.06s | MAE  0.0518 | RMSE  0.0663 *
# * Iter 179   | Elapsed     0.06s | MAE  0.0516 | RMSE  0.0668 *
# * Iter 180   | Elapsed     0.07s | MAE  0.0512 | RMSE  0.0661 *
# * Iter 181   | Elapsed     0.05s | MAE  0.0501 | RMSE  0.0648 *
# * Iter 182   | Elapsed     0.05s | MAE  0.0508 | RMSE  0.0655 *
# * Iter 183   | Elapsed     0.07s | MAE  0.0494 | RMSE  0.0634 *
# * Iter 184   | Elapsed     0.07s | MAE  0.0491 | RMSE  0.0626 *
# * Iter 185   | Elapsed     0.10s | MAE  0.0494 | RMSE  0.0640 *
# * Iter 186   | Elapsed     0.07s | MAE  0.0497 | RMSE  0.0642 *
# * Iter 187   | Elapsed     0.09s | MAE  0.0496 | RMSE  0.0634 *
# * Iter 188   | Elapsed     0.08s | MAE  0.0493 | RMSE  0.0635 *
# * Iter 189   | Elapsed     0.07s | MAE  0.0499 | RMSE  0.0638 *
# * Iter 190   | Elapsed     0.04s | MAE  0.0502 | RMSE  0.0650 *
# * Iter 191   | Elapsed     0.05s | MAE  0.0516 | RMSE  0.0661 *
# * Iter 192   | Elapsed     0.05s | MAE  0.0508 | RMSE  0.0652 *
# * Iter 193   | Elapsed     0.08s | MAE  0.0503 | RMSE  0.0648 *
# * Iter 194   | Elapsed     0.07s | MAE  0.0505 | RMSE  0.0644 *
# * Iter 195   | Elapsed     0.07s | MAE  0.0512 | RMSE  0.0651 *
# * Iter 196   | Elapsed     0.05s | MAE  0.0495 | RMSE  0.0635 *
# * Iter 197   | Elapsed     0.08s | MAE  0.0487 | RMSE  0.0628 *
# * Iter 198   | Elapsed     0.06s | MAE  0.0514 | RMSE  0.0655 *
# * Iter 199   | Elapsed     0.05s | MAE  0.0508 | RMSE  0.0661 *
# * Iter 200   | Elapsed     0.10s | MAE  0.0531 | RMSE  0.0675 *
# * Iter 201   | Elapsed     0.09s | MAE  0.0521 | RMSE  0.0668 *
# * Iter 202   | Elapsed     0.07s | MAE  0.0519 | RMSE  0.0675 *
# * Iter 203   | Elapsed     0.10s | MAE  0.0510 | RMSE  0.0656 *
# * Iter 204   | Elapsed     0.05s | MAE  0.0524 | RMSE  0.0676 *
# * Iter 205   | Elapsed     0.12s | MAE  0.0517 | RMSE  0.0659 *
# * Iter 206   | Elapsed     0.11s | MAE  0.0511 | RMSE  0.0656 *
# * Iter 207   | Elapsed     0.07s | MAE  0.0511 | RMSE  0.0665 *
# * Iter 208   | Elapsed     0.08s | MAE  0.0513 | RMSE  0.0650 *
# * Iter 209   | Elapsed     0.14s | MAE  0.0503 | RMSE  0.0643 *
# * Iter 210   | Elapsed     0.11s | MAE  0.0516 | RMSE  0.0650 *
# * Iter 211   | Elapsed     0.08s | MAE  0.0510 | RMSE  0.0655 *
# * Iter 212   | Elapsed     0.09s | MAE  0.0507 | RMSE  0.0642 *
# * Iter 213   | Elapsed     0.12s | MAE  0.0507 | RMSE  0.0644 *
# * Iter 214   | Elapsed     0.06s | MAE  0.0501 | RMSE  0.0646 *
# * Iter 215   | Elapsed     0.10s | MAE  0.0501 | RMSE  0.0649 *
# * Iter 216   | Elapsed     0.07s | MAE  0.0503 | RMSE  0.0647 *
# * Iter 217   | Elapsed     0.03s | MAE  0.0512 | RMSE  0.0661 *
# * Iter 218   | Elapsed     0.05s | MAE  0.0522 | RMSE  0.0671 *
# * Iter 219   | Elapsed     0.06s | MAE  0.0531 | RMSE  0.0682 *
# * Iter 220   | Elapsed     0.04s | MAE  0.0517 | RMSE  0.0678 *
# * Iter 221   | Elapsed     0.07s | MAE  0.0525 | RMSE  0.0677 *
# * Iter 222   | Elapsed     0.07s | MAE  0.0528 | RMSE  0.0683 *
# * Iter 223   | Elapsed     0.06s | MAE  0.0525 | RMSE  0.0676 *
# * Iter 224   | Elapsed     0.08s | MAE  0.0517 | RMSE  0.0664 *
# * Iter 225   | Elapsed     0.06s | MAE  0.0525 | RMSE  0.0679 *
# * Iter 226   | Elapsed     0.07s | MAE  0.0509 | RMSE  0.0661 *
# * Iter 227   | Elapsed     0.09s | MAE  0.0515 | RMSE  0.0670 *
# * Iter 228   | Elapsed     0.05s | MAE  0.0516 | RMSE  0.0677 *
# * Iter 229   | Elapsed     0.05s | MAE  0.0523 | RMSE  0.0673 *
# * Iter 230   | Elapsed     0.10s | MAE  0.0521 | RMSE  0.0678 *
# * Iter 231   | Elapsed     0.12s | MAE  0.0528 | RMSE  0.0679 *
# * Iter 232   | Elapsed     0.05s | MAE  0.0519 | RMSE  0.0666 *
# * Iter 233   | Elapsed     0.08s | MAE  0.0509 | RMSE  0.0655 *
# * Iter 234   | Elapsed     0.09s | MAE  0.0519 | RMSE  0.0674 *
# * Iter 235   | Elapsed     0.24s | MAE  0.0515 | RMSE  0.0668 *
# * Iter 236   | Elapsed     0.11s | MAE  0.0518 | RMSE  0.0656 *
# * Iter 237   | Elapsed     0.08s | MAE  0.0512 | RMSE  0.0663 *
# * Iter 238   | Elapsed     0.14s | MAE  0.0510 | RMSE  0.0662 *
# * Iter 239   | Elapsed     0.13s | MAE  0.0507 | RMSE  0.0651 *
# * Iter 240   | Elapsed     0.07s | MAE  0.0513 | RMSE  0.0657 *
# * Iter 241   | Elapsed     0.10s | MAE  0.0499 | RMSE  0.0653 *
# * Iter 242   | Elapsed     0.09s | MAE  0.0506 | RMSE  0.0653 *
# * Iter 243   | Elapsed     0.10s | MAE  0.0504 | RMSE  0.0652 *
# * Iter 244   | Elapsed     0.13s | MAE  0.0500 | RMSE  0.0646 *
# * Iter 245   | Elapsed     0.11s | MAE  0.0495 | RMSE  0.0638 *
# * Iter 246   | Elapsed     0.10s | MAE  0.0510 | RMSE  0.0664 *
# * Iter 247   | Elapsed     0.21s | MAE  0.0505 | RMSE  0.0654 *
# * Iter 248   | Elapsed     0.13s | MAE  0.0521 | RMSE  0.0671 *
# * Iter 249   | Elapsed     0.09s | MAE  0.0493 | RMSE  0.0642 *
# * Iter 250   | Elapsed     0.09s | MAE  0.0500 | RMSE  0.0643 *
# * Iter 251   | Elapsed     0.14s | MAE  0.0504 | RMSE  0.0647 *
# * Iter 252   | Elapsed     0.05s | MAE  0.0492 | RMSE  0.0639 *
# * Iter 253   | Elapsed     0.13s | MAE  0.0500 | RMSE  0.0642 *
# * Iter 254   | Elapsed     0.15s | MAE  0.0506 | RMSE  0.0657 *
# * Iter 255   | Elapsed     0.11s | MAE  0.0498 | RMSE  0.0652 *
# * Iter 256   | Elapsed     0.14s | MAE  0.0513 | RMSE  0.0659 *
# * Iter 257   | Elapsed     0.11s | MAE  0.0494 | RMSE  0.0643 *
# * Iter 258   | Elapsed     0.08s | MAE  0.0512 | RMSE  0.0652 *
# * Iter 259   | Elapsed     0.14s | MAE  0.0516 | RMSE  0.0663 *
# * Iter 260   | Elapsed     0.09s | MAE  0.0519 | RMSE  0.0670 *
# * Iter 261   | Elapsed     0.09s | MAE  0.0532 | RMSE  0.0687 *
# * Iter 262   | Elapsed     0.07s | MAE  0.0528 | RMSE  0.0685 *
# * Iter 263   | Elapsed     0.07s | MAE  0.0517 | RMSE  0.0652 *
# * Iter 264   | Elapsed     0.08s | MAE  0.0499 | RMSE  0.0642 *
# * Iter 265   | Elapsed     0.07s | MAE  0.0497 | RMSE  0.0636 *
# * Iter 266   | Elapsed     0.05s | MAE  0.0490 | RMSE  0.0624 *
# * Iter 267   | Elapsed     0.10s | MAE  0.0493 | RMSE  0.0631 *
# * Iter 268   | Elapsed     0.05s | MAE  0.0500 | RMSE  0.0636 *
# * Iter 269   | Elapsed     0.10s | MAE  0.0503 | RMSE  0.0652 *
# * Iter 270   | Elapsed     0.12s | MAE  0.0497 | RMSE  0.0644 *
# * Iter 271   | Elapsed     0.10s | MAE  0.0507 | RMSE  0.0654 *
# * Iter 272   | Elapsed     0.06s | MAE  0.0505 | RMSE  0.0661 *
# * Iter 273   | Elapsed     0.11s | MAE  0.0514 | RMSE  0.0656 *
# * Iter 274   | Elapsed     0.05s | MAE  0.0519 | RMSE  0.0664 *
# * Iter 275   | Elapsed     0.07s | MAE  0.0514 | RMSE  0.0666 *
# * Iter 276   | Elapsed     0.05s | MAE  0.0510 | RMSE  0.0661 *
# * Iter 277   | Elapsed     0.09s | MAE  0.0516 | RMSE  0.0662 *
# * Iter 278   | Elapsed     0.08s | MAE  0.0523 | RMSE  0.0675 *
# * Iter 279   | Elapsed     0.09s | MAE  0.0505 | RMSE  0.0660 *
# * Iter 280   | Elapsed     0.08s | MAE  0.0518 | RMSE  0.0665 *
# * Iter 281   | Elapsed     0.12s | MAE  0.0518 | RMSE  0.0668 *
# * Iter 282   | Elapsed     0.06s | MAE  0.0506 | RMSE  0.0652 *
# * Iter 283   | Elapsed     0.10s | MAE  0.0504 | RMSE  0.0646 *
# * Iter 284   | Elapsed     0.08s | MAE  0.0516 | RMSE  0.0660 *
# * Iter 285   | Elapsed     0.06s | MAE  0.0509 | RMSE  0.0657 *
# * Iter 286   | Elapsed     0.07s | MAE  0.0497 | RMSE  0.0647 *
# * Iter 287   | Elapsed     0.07s | MAE  0.0514 | RMSE  0.0661 *
# * Iter 288   | Elapsed     0.07s | MAE  0.0530 | RMSE  0.0677 *
# * Iter 289   | Elapsed     0.09s | MAE  0.0517 | RMSE  0.0676 *
# * Iter 290   | Elapsed     0.06s | MAE  0.0506 | RMSE  0.0652 *
# * Iter 291   | Elapsed     0.06s | MAE  0.0518 | RMSE  0.0668 *
# * Iter 292   | Elapsed     0.07s | MAE  0.0504 | RMSE  0.0651 *
# * Iter 293   | Elapsed     0.08s | MAE  0.0508 | RMSE  0.0657 *
# * Iter 294   | Elapsed     0.07s | MAE  0.0509 | RMSE  0.0656 *
# * Iter 295   | Elapsed     0.05s | MAE  0.0529 | RMSE  0.0668 *
# * Iter 296   | Elapsed     0.06s | MAE  0.0521 | RMSE  0.0670 *
# * Iter 297   | Elapsed     0.08s | MAE  0.0506 | RMSE  0.0652 *
# * Iter 298   | Elapsed     0.08s | MAE  0.0503 | RMSE  0.0647 *
# * Iter 299   | Elapsed     0.09s | MAE  0.0490 | RMSE  0.0643 *
# * Iter 300   | Elapsed     0.08s | MAE  0.0513 | RMSE  0.0658 *
# * Iter 301   | Elapsed     0.07s | MAE  0.0501 | RMSE  0.0645 *
# * Iter 302   | Elapsed     0.10s | MAE  0.0503 | RMSE  0.0646 *
# * Iter 303   | Elapsed     0.08s | MAE  0.0507 | RMSE  0.0650 *
# * Iter 304   | Elapsed     0.05s | MAE  0.0499 | RMSE  0.0640 *
# * Iter 305   | Elapsed     0.05s | MAE  0.0491 | RMSE  0.0635 *
# * Iter 306   | Elapsed     0.08s | MAE  0.0486 | RMSE  0.0627 *
# * Iter 307   | Elapsed     0.07s | MAE  0.0495 | RMSE  0.0637 *
# * Iter 308   | Elapsed     0.13s | MAE  0.0488 | RMSE  0.0634 *
# * Iter 309   | Elapsed     0.07s | MAE  0.0502 | RMSE  0.0645 *
# * Iter 310   | Elapsed     0.06s | MAE  0.0520 | RMSE  0.0658 *
# * Iter 311   | Elapsed     0.05s | MAE  0.0496 | RMSE  0.0638 *
# * Iter 312   | Elapsed     0.07s | MAE  0.0484 | RMSE  0.0639 *
# * Iter 313   | Elapsed     0.07s | MAE  0.0529 | RMSE  0.0669 *
# * Iter 314   | Elapsed     0.09s | MAE  0.0510 | RMSE  0.0656 *
# * Iter 315   | Elapsed     0.10s | MAE  0.0507 | RMSE  0.0647 *
# * Iter 316   | Elapsed     0.07s | MAE  0.0515 | RMSE  0.0663 *
# * Iter 317   | Elapsed     0.10s | MAE  0.0529 | RMSE  0.0683 *
# * Iter 318   | Elapsed     0.06s | MAE  0.0529 | RMSE  0.0674 *
# * Iter 319   | Elapsed     0.05s | MAE  0.0511 | RMSE  0.0671 *
# * Iter 320   | Elapsed     0.06s | MAE  0.0503 | RMSE  0.0652 *
# * Iter 321   | Elapsed     0.07s | MAE  0.0524 | RMSE  0.0673 *
# * Iter 322   | Elapsed     0.06s | MAE  0.0510 | RMSE  0.0654 *
# * Iter 323   | Elapsed     0.13s | MAE  0.0512 | RMSE  0.0660 *
# * Iter 324   | Elapsed     0.07s | MAE  0.0514 | RMSE  0.0662 *
# * Iter 325   | Elapsed     0.08s | MAE  0.0504 | RMSE  0.0656 *
# * Iter 326   | Elapsed     0.08s | MAE  0.0499 | RMSE  0.0651 *
# * Iter 327   | Elapsed     0.08s | MAE  0.0491 | RMSE  0.0644 *
# * Iter 328   | Elapsed     0.08s | MAE  0.0507 | RMSE  0.0647 *
# * Iter 329   | Elapsed     0.08s | MAE  0.0524 | RMSE  0.0666 *
# * Iter 330   | Elapsed     0.10s | MAE  0.0508 | RMSE  0.0661 *
# * Iter 331   | Elapsed     0.07s | MAE  0.0532 | RMSE  0.0679 *
# * Iter 332   | Elapsed     0.05s | MAE  0.0526 | RMSE  0.0677 *
# * Iter 333   | Elapsed     0.07s | MAE  0.0507 | RMSE  0.0659 *
# * Iter 334   | Elapsed     0.04s | MAE  0.0507 | RMSE  0.0656 *
# * Iter 335   | Elapsed     0.09s | MAE  0.0510 | RMSE  0.0652 *
# * Iter 336   | Elapsed     0.08s | MAE  0.0510 | RMSE  0.0659 *
# * Iter 337   | Elapsed     0.06s | MAE  0.0523 | RMSE  0.0664 *
# * Iter 338   | Elapsed     0.08s | MAE  0.0508 | RMSE  0.0659 *
# * Iter 339   | Elapsed     0.06s | MAE  0.0509 | RMSE  0.0653 *
# * Iter 340   | Elapsed     0.11s | MAE  0.0516 | RMSE  0.0663 *
# * Iter 341   | Elapsed     0.11s | MAE  0.0510 | RMSE  0.0657 *
# * Iter 342   | Elapsed     0.12s | MAE  0.0500 | RMSE  0.0648 *
# * Iter 343   | Elapsed     0.09s | MAE  0.0511 | RMSE  0.0656 *
# * Iter 344   | Elapsed     0.10s | MAE  0.0515 | RMSE  0.0665 *
# * Iter 345   | Elapsed     0.08s | MAE  0.0508 | RMSE  0.0654 *
# * Iter 346   | Elapsed     0.10s | MAE  0.0516 | RMSE  0.0656 *
# * Iter 347   | Elapsed     0.06s | MAE  0.0501 | RMSE  0.0661 *
# * Iter 348   | Elapsed     0.07s | MAE  0.0504 | RMSE  0.0655 *
# * Iter 349   | Elapsed     0.04s | MAE  0.0502 | RMSE  0.0647 *
# * Iter 350   | Elapsed     0.07s | MAE  0.0511 | RMSE  0.0659 *
# * Iter 351   | Elapsed     0.05s | MAE  0.0513 | RMSE  0.0658 *
# * Iter 352   | Elapsed     0.07s | MAE  0.0511 | RMSE  0.0655 *
# * Iter 353   | Elapsed     0.06s | MAE  0.0521 | RMSE  0.0670 *
# * Iter 354   | Elapsed     0.06s | MAE  0.0526 | RMSE  0.0676 *
# * Iter 355   | Elapsed     0.05s | MAE  0.0524 | RMSE  0.0676 *
# * Iter 356   | Elapsed     0.09s | MAE  0.0520 | RMSE  0.0671 *
# * Iter 357   | Elapsed     0.07s | MAE  0.0525 | RMSE  0.0683 *
# * Iter 358   | Elapsed     0.07s | MAE  0.0517 | RMSE  0.0666 *
# * Iter 359   | Elapsed     0.07s | MAE  0.0521 | RMSE  0.0676 *
# * Iter 360   | Elapsed     0.05s | MAE  0.0526 | RMSE  0.0677 *
# * Iter 361   | Elapsed     0.05s | MAE  0.0536 | RMSE  0.0686 *
# * Iter 362   | Elapsed     0.11s | MAE  0.0527 | RMSE  0.0689 *
# * Iter 363   | Elapsed     0.10s | MAE  0.0533 | RMSE  0.0690 *
# * Iter 364   | Elapsed     0.05s | MAE  0.0522 | RMSE  0.0684 *
# * Iter 365   | Elapsed     0.05s | MAE  0.0522 | RMSE  0.0677 *
# * Iter 366   | Elapsed     0.05s | MAE  0.0520 | RMSE  0.0679 *
# * Iter 367   | Elapsed     0.08s | MAE  0.0515 | RMSE  0.0666 *
# * Iter 368   | Elapsed     0.08s | MAE  0.0522 | RMSE  0.0664 *
# * Iter 369   | Elapsed     0.11s | MAE  0.0506 | RMSE  0.0651 *
# * Iter 370   | Elapsed     0.07s | MAE  0.0526 | RMSE  0.0674 *
# * Iter 371   | Elapsed     0.15s | MAE  0.0531 | RMSE  0.0689 *
# * Iter 372   | Elapsed     0.07s | MAE  0.0516 | RMSE  0.0683 *
# * Iter 373   | Elapsed     0.05s | MAE  0.0526 | RMSE  0.0675 *
# * Iter 374   | Elapsed     0.08s | MAE  0.0515 | RMSE  0.0665 *
# * Iter 375   | Elapsed     0.05s | MAE  0.0527 | RMSE  0.0674 *
# * Iter 376   | Elapsed     0.08s | MAE  0.0501 | RMSE  0.0641 *
# * Iter 377   | Elapsed     0.06s | MAE  0.0526 | RMSE  0.0673 *
# * Iter 378   | Elapsed     0.08s | MAE  0.0523 | RMSE  0.0673 *
# * Iter 379   | Elapsed     0.06s | MAE  0.0503 | RMSE  0.0653 *
# * Iter 380   | Elapsed     0.05s | MAE  0.0536 | RMSE  0.0691 *
# * Iter 381   | Elapsed     0.05s | MAE  0.0525 | RMSE  0.0679 *
# * Iter 382   | Elapsed     0.08s | MAE  0.0510 | RMSE  0.0660 *
# * Iter 383   | Elapsed     0.06s | MAE  0.0517 | RMSE  0.0672 *
# * Iter 384   | Elapsed     0.07s | MAE  0.0502 | RMSE  0.0653 *
# * Iter 385   | Elapsed     0.06s | MAE  0.0508 | RMSE  0.0659 *
# * Iter 386   | Elapsed     0.07s | MAE  0.0513 | RMSE  0.0660 *
# * Iter 387   | Elapsed     0.05s | MAE  0.0505 | RMSE  0.0655 *
# * Iter 388   | Elapsed     0.07s | MAE  0.0508 | RMSE  0.0659 *
# * Iter 389   | Elapsed     0.09s | MAE  0.0510 | RMSE  0.0659 *
# * Iter 390   | Elapsed     0.09s | MAE  0.0513 | RMSE  0.0659 *
# * Iter 391   | Elapsed     0.07s | MAE  0.0502 | RMSE  0.0654 *
# * Iter 392   | Elapsed     0.10s | MAE  0.0517 | RMSE  0.0664 *
# * Iter 393   | Elapsed     0.09s | MAE  0.0515 | RMSE  0.0650 *
# * Iter 394   | Elapsed     0.14s | MAE  0.0518 | RMSE  0.0668 *
# * Iter 395   | Elapsed     0.08s | MAE  0.0505 | RMSE  0.0649 *
# * Iter 396   | Elapsed     0.11s | MAE  0.0506 | RMSE  0.0648 *
# * Iter 397   | Elapsed     0.09s | MAE  0.0503 | RMSE  0.0645 *
# * Iter 398   | Elapsed     0.10s | MAE  0.0507 | RMSE  0.0650 *
# * Iter 399   | Elapsed     0.06s | MAE  0.0506 | RMSE  0.0650 *
# * Iter 400   | Elapsed     0.11s | MAE  0.0474 | RMSE  0.0606 *
# * Iter TOTAL | Elapsed    31.78s | MAE  0.0417 | RMSE  0.0551 *
#
# ======================================================================
#                         BKTR Regressor Summary
# ======================================================================
# Formula: nb_departure ~ 1 + area_park + len_cycle_path +
#   len_major_road + len_minor_road + num_metro_stations +
#   num_other_commercial + num_restaurants + num_university + num_pop +
#   num_bus_stations + num_bus_routes + walkscore + capacity + humidity
#   + max_temp_f + mean_temp_c + total_precip_mm + holiday
#
# Burn-in iterations: 200
# Sampling iterations: 200
# Rank decomposition: 10
# Nb Spatial Locations: 25
# Nb Temporal Points: 50
# Nb Covariates: 19
# ======================================================================
# In Sample Errors:
#   RMSE: 0.055
#   MAE: 0.042
# Computation time: 31.78s.
# ======================================================================
# -- Spatial Kernel --
# Matern 3/2 Kernel
# Parameter(s):
#                        Mean   Median       SD  Low2.5p  Up97.5p
# lengthscale          20.544   20.448    1.832   16.964   23.727
#
# -- Temporal Kernel --
# SE Kernel
# Parameter(s):
#                        Mean   Median       SD  Low2.5p  Up97.5p
# lengthscale           1.090    1.087    0.057    0.987    1.204
# ======================================================================
# Beta Estimates Summary (Aggregated Per Covariates)
#
#                        Mean   Median       SD
# feature
# Intercept             0.078    0.069    0.058
# area_park             0.389    0.392    0.209
# len_cycle_path        0.135    0.137    0.102
# len_major_road       -0.025   -0.022    0.030
# len_minor_road       -0.009   -0.010    0.040
# num_metro_stations    1.273    1.350    0.730
# num_other_comme...   -0.503   -0.525    0.333
# num_restaurants       0.063    0.060    0.118
# num_university        0.078    0.069    0.071
# num_pop              -0.365   -0.390    0.199
# num_bus_stations      0.198    0.186    0.113
# num_bus_routes       -0.119   -0.109    0.126
# walkscore             0.372    0.395    0.208
# capacity             -0.095   -0.091    0.060
# humidity             -0.058   -0.052    0.054
# max_temp_f            0.036    0.024    0.082
# mean_temp_c           0.188    0.196    0.106
# total_precip_mm      -0.189   -0.170    0.147
# holiday               0.002    0.003    0.013
# ======================================================================
