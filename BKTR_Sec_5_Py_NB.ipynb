# %% [markdown]
# ## System Setup

# %%
# Find CPU info
# !grep -m1 'model name' /proc/cpuinfo | awk -F": " '{print $2}'
# !grep 'cpu cores' /proc/cpuinfo | awk -F": " '{a[cores]+=$2}END{print "CPU cores: " a[cores]}'
# Out:
# Intel(R) Xeon(R) CPU @ 2.00GHz
# CPU cores: 32

# %%
# Find Ram Info
# !grep MemTotal /proc/meminfo | awk '{printf "%.1fGB RAM", $2 / 1024 / 1024}'
# Out:
# 51.0GB RAM

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !nvidia-smi
# Out:
# Wed Oct 25 03:26:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    33W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install git+https://github.com/julien-hec/pyBKTR.git
# !pip install pyBKTR
# Out:
# Requirement already satisfied: pyBKTR in /usr/local/lib/python3.10/dist-packages (0.1.3)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (2.1.0+cu118)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (1.23.5)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (1.5.3)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (5.15.0)
# Requirement already satisfied: formulaic>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from pyBKTR) (0.6.6)
# Requirement already satisfied: astor>=0.8 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.3.0)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.11.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (4.5.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.5.2->pyBKTR) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->pyBKTR) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->pyBKTR) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->pyBKTR) (23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->pyBKTR) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4.2->pyBKTR) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->pyBKTR) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.1->pyBKTR) (1.3.0)

# %% [markdown]
# ## Library Setup

# %%
from pyBKTR.bktr import BKTRRegressor
from pyBKTR.examples.bixi import BixiData
from pyBKTR.kernels import KernelMatern, KernelParameter, KernelSE
from pyBKTR.tensor_ops import TSR
from pyBKTR.utils import simulate_spatiotemporal_data

# Following two librairies are for results manipulation
import numpy as np
import pandas as pd

# %% [markdown]
# ## Bixi Data Intro Example

# %%
TSR.set_params('float32', 'cuda', 1)

bixi_data = BixiData()

bktr_regressor = BKTRRegressor(
    data_df = bixi_data.data_df,
    spatial_positions_df = bixi_data.spatial_positions_df,
    temporal_positions_df = bixi_data.temporal_positions_df,
    burn_in_iter = 500,
    sampling_iter = 500,
)

bktr_regressor.mcmc_sampling()

print(bktr_regressor.summary)
# Out:
# * Iter 1     | Elapsed     0.34s | MAE  0.1027 | RMSE  0.1438 *
# * Iter 2     | Elapsed     0.12s | MAE  0.0675 | RMSE  0.0912 *
# * Iter 3     | Elapsed     0.14s | MAE  0.0587 | RMSE  0.0794 *
# * Iter 4     | Elapsed     0.09s | MAE  0.0564 | RMSE  0.0761 *
# * Iter 5     | Elapsed     0.19s | MAE  0.0557 | RMSE  0.0752 *
# * Iter 6     | Elapsed     0.22s | MAE  0.0554 | RMSE  0.0747 *
# * Iter 7     | Elapsed     0.18s | MAE  0.0553 | RMSE  0.0745 *
# * Iter 8     | Elapsed     0.16s | MAE  0.0553 | RMSE  0.0745 *
# * Iter 9     | Elapsed     0.16s | MAE  0.0552 | RMSE  0.0744 *
# * Iter 10    | Elapsed     0.19s | MAE  0.0550 | RMSE  0.0742 *
# * Iter 11    | Elapsed     0.33s | MAE  0.0550 | RMSE  0.0740 *
# * Iter 12    | Elapsed     0.29s | MAE  0.0547 | RMSE  0.0737 *
# * Iter 13    | Elapsed     0.29s | MAE  0.0546 | RMSE  0.0737 *
# * Iter 14    | Elapsed     0.27s | MAE  0.0545 | RMSE  0.0735 *
# * Iter 15    | Elapsed     0.13s | MAE  0.0545 | RMSE  0.0734 *
# * Iter 16    | Elapsed     0.24s | MAE  0.0544 | RMSE  0.0734 *
# * Iter 17    | Elapsed     0.15s | MAE  0.0543 | RMSE  0.0733 *
# * Iter 18    | Elapsed     0.93s | MAE  0.0543 | RMSE  0.0732 *
# * Iter 19    | Elapsed     0.14s | MAE  0.0543 | RMSE  0.0732 *
# * Iter 20    | Elapsed     0.20s | MAE  0.0542 | RMSE  0.0731 *
# * Iter 21    | Elapsed     0.92s | MAE  0.0541 | RMSE  0.0731 *
# * Iter 22    | Elapsed     0.38s | MAE  0.0541 | RMSE  0.0730 *
# * Iter 23    | Elapsed     0.35s | MAE  0.0541 | RMSE  0.0729 *
# * Iter 24    | Elapsed     0.16s | MAE  0.0541 | RMSE  0.0728 *
# * Iter 25    | Elapsed     0.35s | MAE  0.0540 | RMSE  0.0728 *
# * Iter 26    | Elapsed     0.52s | MAE  0.0541 | RMSE  0.0729 *
# * Iter 27    | Elapsed     0.63s | MAE  0.0539 | RMSE  0.0727 *
# * Iter 28    | Elapsed     0.28s | MAE  0.0540 | RMSE  0.0728 *
# * Iter 29    | Elapsed     0.85s | MAE  0.0540 | RMSE  0.0727 *
# * Iter 30    | Elapsed     0.12s | MAE  0.0538 | RMSE  0.0726 *
# * Iter 31    | Elapsed     0.37s | MAE  0.0540 | RMSE  0.0727 *
# * Iter 32    | Elapsed     0.25s | MAE  0.0540 | RMSE  0.0727 *
# * Iter 33    | Elapsed     0.36s | MAE  0.0538 | RMSE  0.0726 *
# * Iter 34    | Elapsed     0.34s | MAE  0.0538 | RMSE  0.0726 *
# * Iter 35    | Elapsed     0.18s | MAE  0.0539 | RMSE  0.0726 *
# * Iter 36    | Elapsed     0.32s | MAE  0.0538 | RMSE  0.0725 *
# * Iter 37    | Elapsed     0.42s | MAE  0.0538 | RMSE  0.0725 *
# * Iter 38    | Elapsed     0.28s | MAE  0.0537 | RMSE  0.0724 *
# * Iter 39    | Elapsed     0.39s | MAE  0.0538 | RMSE  0.0724 *
# * Iter 40    | Elapsed     0.29s | MAE  0.0537 | RMSE  0.0724 *
# * Iter 41    | Elapsed     0.25s | MAE  0.0538 | RMSE  0.0725 *
# * Iter 42    | Elapsed     0.57s | MAE  0.0537 | RMSE  0.0724 *
# * Iter 43    | Elapsed     0.40s | MAE  0.0538 | RMSE  0.0725 *
# * Iter 44    | Elapsed     0.29s | MAE  0.0538 | RMSE  0.0725 *
# * Iter 45    | Elapsed     0.29s | MAE  0.0538 | RMSE  0.0725 *
# * Iter 46    | Elapsed     0.18s | MAE  0.0538 | RMSE  0.0724 *
# * Iter 47    | Elapsed     0.22s | MAE  0.0538 | RMSE  0.0724 *
# * Iter 48    | Elapsed     0.57s | MAE  0.0537 | RMSE  0.0724 *
# * Iter 49    | Elapsed     0.66s | MAE  0.0537 | RMSE  0.0724 *
# * Iter 50    | Elapsed     0.30s | MAE  0.0536 | RMSE  0.0723 *
# * Iter 51    | Elapsed     0.51s | MAE  0.0536 | RMSE  0.0723 *
# * Iter 52    | Elapsed     0.59s | MAE  0.0536 | RMSE  0.0723 *
# * Iter 53    | Elapsed     0.59s | MAE  0.0537 | RMSE  0.0723 *
# * Iter 54    | Elapsed     0.86s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 55    | Elapsed     0.46s | MAE  0.0536 | RMSE  0.0723 *
# * Iter 56    | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0722 *
# * Iter 57    | Elapsed     0.27s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 58    | Elapsed     0.25s | MAE  0.0536 | RMSE  0.0723 *
# * Iter 59    | Elapsed     0.39s | MAE  0.0537 | RMSE  0.0724 *
# * Iter 60    | Elapsed     0.29s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 61    | Elapsed     0.77s | MAE  0.0537 | RMSE  0.0723 *
# * Iter 62    | Elapsed     0.22s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 63    | Elapsed     0.62s | MAE  0.0536 | RMSE  0.0723 *
# * Iter 64    | Elapsed     0.48s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 65    | Elapsed     0.50s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 66    | Elapsed     0.84s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 67    | Elapsed     0.83s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 68    | Elapsed     0.38s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 69    | Elapsed     0.57s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 70    | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 71    | Elapsed     0.42s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 72    | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 73    | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0722 *
# * Iter 74    | Elapsed     0.12s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 75    | Elapsed     0.25s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 76    | Elapsed     0.21s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 77    | Elapsed     0.18s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 78    | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 79    | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 80    | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 81    | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 82    | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 83    | Elapsed     0.37s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 84    | Elapsed     0.27s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 85    | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0722 *
# * Iter 86    | Elapsed     0.30s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 87    | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 88    | Elapsed     0.16s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 89    | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 90    | Elapsed     0.20s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 91    | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 92    | Elapsed     0.41s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 93    | Elapsed     0.41s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 94    | Elapsed     0.51s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 95    | Elapsed     0.46s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 96    | Elapsed     0.86s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 97    | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 98    | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 99    | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 100   | Elapsed     0.38s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 101   | Elapsed     0.32s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 102   | Elapsed     0.47s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 103   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 104   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 105   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 106   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 107   | Elapsed     0.28s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 108   | Elapsed     0.15s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 109   | Elapsed     0.19s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 110   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 111   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0721 *
# * Iter 112   | Elapsed     0.18s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 113   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 114   | Elapsed     0.36s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 115   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 116   | Elapsed     1.13s | MAE  0.0535 | RMSE  0.0722 *
# * Iter 117   | Elapsed     0.93s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 118   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 119   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 120   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 121   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 122   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 123   | Elapsed     0.43s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 124   | Elapsed     0.21s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 125   | Elapsed     0.23s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 126   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 127   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 128   | Elapsed     0.17s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 129   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 130   | Elapsed     0.60s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 131   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 132   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 133   | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 134   | Elapsed     0.88s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 135   | Elapsed     0.42s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 136   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 137   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0722 *
# * Iter 138   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 139   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 140   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 141   | Elapsed     0.26s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 142   | Elapsed     0.26s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 143   | Elapsed     0.73s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 144   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 145   | Elapsed     0.73s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 146   | Elapsed     0.88s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 147   | Elapsed     0.55s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 148   | Elapsed     0.53s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 149   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 150   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 151   | Elapsed     0.85s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 152   | Elapsed     0.83s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 153   | Elapsed     0.43s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 154   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 155   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 156   | Elapsed     0.73s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 157   | Elapsed     1.05s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 158   | Elapsed     0.41s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 159   | Elapsed     0.13s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 160   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 161   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 162   | Elapsed     0.45s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 163   | Elapsed     0.47s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 164   | Elapsed     0.60s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 165   | Elapsed     0.39s | MAE  0.0534 | RMSE  0.0721 *
# * Iter 166   | Elapsed     0.52s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 167   | Elapsed     0.69s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 168   | Elapsed     0.70s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 169   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 170   | Elapsed     0.30s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 171   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 172   | Elapsed     0.20s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 173   | Elapsed     0.09s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 174   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 175   | Elapsed     0.68s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 176   | Elapsed     0.20s | MAE  0.0536 | RMSE  0.0722 *
# * Iter 177   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 178   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 179   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 180   | Elapsed     0.22s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 181   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 182   | Elapsed     0.47s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 183   | Elapsed     0.48s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 184   | Elapsed     0.14s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 185   | Elapsed     0.39s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 186   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 187   | Elapsed     0.13s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 188   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 189   | Elapsed     0.38s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 190   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 191   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 192   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 193   | Elapsed     0.33s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 194   | Elapsed     0.67s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 195   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 196   | Elapsed     0.89s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 197   | Elapsed     1.08s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 198   | Elapsed     0.92s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 199   | Elapsed     1.02s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 200   | Elapsed     0.74s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 201   | Elapsed     0.83s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 202   | Elapsed     0.79s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 203   | Elapsed     1.10s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 204   | Elapsed     1.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 205   | Elapsed     0.70s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 206   | Elapsed     0.98s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 207   | Elapsed     0.77s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 208   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 209   | Elapsed     0.35s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 210   | Elapsed     0.32s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 211   | Elapsed     0.49s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 212   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 213   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 214   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 215   | Elapsed     0.38s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 216   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 217   | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 218   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 219   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 220   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 221   | Elapsed     0.40s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 222   | Elapsed     0.36s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 223   | Elapsed     0.49s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 224   | Elapsed     0.30s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 225   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 226   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 227   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 228   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 229   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 230   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 231   | Elapsed     0.46s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 232   | Elapsed     0.20s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 233   | Elapsed     0.36s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 234   | Elapsed     0.32s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 235   | Elapsed     0.32s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 236   | Elapsed     0.54s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 237   | Elapsed     0.29s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 238   | Elapsed     0.56s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 239   | Elapsed     0.59s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 240   | Elapsed     0.83s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 241   | Elapsed     0.87s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 242   | Elapsed     0.40s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 243   | Elapsed     0.31s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 244   | Elapsed     0.15s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 245   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 246   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 247   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 248   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 249   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 250   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 251   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 252   | Elapsed     0.85s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 253   | Elapsed     0.49s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 254   | Elapsed     0.57s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 255   | Elapsed     1.08s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 256   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 257   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 258   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 259   | Elapsed     0.22s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 260   | Elapsed     0.36s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 261   | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 262   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 263   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 264   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 265   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 266   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 267   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 268   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 269   | Elapsed     0.98s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 270   | Elapsed     0.46s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 271   | Elapsed     0.14s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 272   | Elapsed     0.31s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 273   | Elapsed     0.17s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 274   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 275   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 276   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 277   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 278   | Elapsed     0.39s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 279   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 280   | Elapsed     0.17s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 281   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 282   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 283   | Elapsed     0.52s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 284   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 285   | Elapsed     0.34s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 286   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 287   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 288   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 289   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 290   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 291   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 292   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 293   | Elapsed     0.58s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 294   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 295   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 296   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 297   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 298   | Elapsed     0.56s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 299   | Elapsed     0.31s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 300   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 301   | Elapsed     0.58s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 302   | Elapsed     0.50s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 303   | Elapsed     0.97s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 304   | Elapsed     0.97s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 305   | Elapsed     1.08s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 306   | Elapsed     0.74s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 307   | Elapsed     0.92s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 308   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 309   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 310   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 311   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 312   | Elapsed     0.76s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 313   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 314   | Elapsed     0.12s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 315   | Elapsed     0.45s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 316   | Elapsed     0.36s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 317   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 318   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 319   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 320   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 321   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 322   | Elapsed     0.80s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 323   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 324   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 325   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 326   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 327   | Elapsed     0.79s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 328   | Elapsed     0.72s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 329   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 330   | Elapsed     0.70s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 331   | Elapsed     0.64s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 332   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 333   | Elapsed     0.70s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 334   | Elapsed     1.08s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 335   | Elapsed     0.97s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 336   | Elapsed     0.70s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 337   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 338   | Elapsed     0.56s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 339   | Elapsed     0.81s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 340   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 341   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 342   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 343   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 344   | Elapsed     0.31s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 345   | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 346   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 347   | Elapsed     0.43s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 348   | Elapsed     0.38s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 349   | Elapsed     0.51s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 350   | Elapsed     0.79s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 351   | Elapsed     0.71s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 352   | Elapsed     0.61s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 353   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 354   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 355   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 356   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 357   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 358   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 359   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 360   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 361   | Elapsed     0.76s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 362   | Elapsed     0.38s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 363   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 364   | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 365   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 366   | Elapsed     0.19s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 367   | Elapsed     0.09s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 368   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 369   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 370   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 371   | Elapsed     0.36s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 372   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 373   | Elapsed     0.34s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 374   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 375   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 376   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 377   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 378   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 379   | Elapsed     0.13s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 380   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 381   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 382   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 383   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 384   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 385   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 386   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 387   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 388   | Elapsed     0.88s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 389   | Elapsed     0.89s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 390   | Elapsed     0.46s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 391   | Elapsed     1.12s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 392   | Elapsed     0.92s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 393   | Elapsed     0.73s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 394   | Elapsed     0.38s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 395   | Elapsed     0.77s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 396   | Elapsed     0.61s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 397   | Elapsed     0.68s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 398   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 399   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 400   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 401   | Elapsed     0.62s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 402   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 403   | Elapsed     0.86s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 404   | Elapsed     1.06s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 405   | Elapsed     1.12s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 406   | Elapsed     0.14s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 407   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 408   | Elapsed     0.52s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 409   | Elapsed     0.39s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 410   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 411   | Elapsed     0.60s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 412   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 413   | Elapsed     0.14s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 414   | Elapsed     0.38s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 415   | Elapsed     0.16s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 416   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 417   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 418   | Elapsed     0.29s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 419   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 420   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 421   | Elapsed     0.12s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 422   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 423   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 424   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 425   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 426   | Elapsed     0.21s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 427   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 428   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 429   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 430   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 431   | Elapsed     0.80s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 432   | Elapsed     0.39s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 433   | Elapsed     0.45s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 434   | Elapsed     0.40s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 435   | Elapsed     0.81s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 436   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 437   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 438   | Elapsed     0.36s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 439   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 440   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 441   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 442   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 443   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 444   | Elapsed     0.18s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 445   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 446   | Elapsed     0.92s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 447   | Elapsed     0.88s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 448   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 449   | Elapsed     0.26s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 450   | Elapsed     0.55s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 451   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 452   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 453   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 454   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 455   | Elapsed     0.72s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 456   | Elapsed     0.56s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 457   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 458   | Elapsed     0.10s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 459   | Elapsed     0.47s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 460   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 461   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 462   | Elapsed     0.41s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 463   | Elapsed     0.86s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 464   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 465   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 466   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 467   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 468   | Elapsed     0.12s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 469   | Elapsed     0.23s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 470   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 471   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 472   | Elapsed     0.24s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 473   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 474   | Elapsed     0.29s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 475   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 476   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 477   | Elapsed     0.09s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 478   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 479   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 480   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 481   | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 482   | Elapsed     0.32s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 483   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 484   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 485   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 486   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 487   | Elapsed     0.43s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 488   | Elapsed     0.22s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 489   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 490   | Elapsed     0.33s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 491   | Elapsed     0.28s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 492   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 493   | Elapsed     0.14s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 494   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 495   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 496   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 497   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 498   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 499   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 500   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 501   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 502   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 503   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 504   | Elapsed     0.13s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 505   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 506   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 507   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 508   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 509   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 510   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 511   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 512   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 513   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 514   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 515   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 516   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 517   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 518   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 519   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 520   | Elapsed     1.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 521   | Elapsed     0.86s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 522   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 523   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 524   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 525   | Elapsed     0.36s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 526   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 527   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 528   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 529   | Elapsed     0.39s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 530   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 531   | Elapsed     0.35s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 532   | Elapsed     0.89s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 533   | Elapsed     0.55s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 534   | Elapsed     0.54s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 535   | Elapsed     1.27s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 536   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 537   | Elapsed     0.66s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 538   | Elapsed     1.05s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 539   | Elapsed     0.88s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 540   | Elapsed     0.85s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 541   | Elapsed     1.18s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 542   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 543   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 544   | Elapsed     0.17s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 545   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 546   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 547   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 548   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 549   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 550   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 551   | Elapsed     0.14s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 552   | Elapsed     0.14s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 553   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 554   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 555   | Elapsed     0.11s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 556   | Elapsed     0.75s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 557   | Elapsed     0.38s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 558   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 559   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 560   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 561   | Elapsed     0.69s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 562   | Elapsed     0.55s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 563   | Elapsed     0.83s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 564   | Elapsed     1.10s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 565   | Elapsed     0.55s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 566   | Elapsed     0.83s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 567   | Elapsed     1.11s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 568   | Elapsed     0.83s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 569   | Elapsed     0.85s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 570   | Elapsed     0.88s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 571   | Elapsed     0.42s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 572   | Elapsed     0.17s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 573   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 574   | Elapsed     0.15s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 575   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 576   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 577   | Elapsed     0.33s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 578   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 579   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 580   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 581   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 582   | Elapsed     0.90s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 583   | Elapsed     1.13s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 584   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 585   | Elapsed     0.63s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 586   | Elapsed     0.47s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 587   | Elapsed     0.72s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 588   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 589   | Elapsed     0.95s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 590   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 591   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 592   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 593   | Elapsed     0.34s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 594   | Elapsed     1.11s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 595   | Elapsed     0.89s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 596   | Elapsed     0.78s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 597   | Elapsed     0.62s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 598   | Elapsed     0.48s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 599   | Elapsed     0.55s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 600   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 601   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 602   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 603   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 604   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 605   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 606   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 607   | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 608   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 609   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 610   | Elapsed     0.48s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 611   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 612   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 613   | Elapsed     0.34s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 614   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 615   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 616   | Elapsed     0.11s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 617   | Elapsed     0.10s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 618   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 619   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 620   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 621   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 622   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 623   | Elapsed     0.61s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 624   | Elapsed     0.52s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 625   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 626   | Elapsed     0.36s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 627   | Elapsed     0.36s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 628   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 629   | Elapsed     0.18s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 630   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 631   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 632   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 633   | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 634   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 635   | Elapsed     0.34s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 636   | Elapsed     0.42s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 637   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 638   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 639   | Elapsed     0.36s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 640   | Elapsed     0.40s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 641   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 642   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 643   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 644   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 645   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 646   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 647   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 648   | Elapsed     0.12s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 649   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 650   | Elapsed     0.36s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 651   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 652   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 653   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 654   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 655   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 656   | Elapsed     0.85s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 657   | Elapsed     0.66s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 658   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 659   | Elapsed     0.88s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 660   | Elapsed     0.32s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 661   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 662   | Elapsed     0.85s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 663   | Elapsed     0.12s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 664   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 665   | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 666   | Elapsed     0.13s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 667   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 668   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 669   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 670   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 671   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 672   | Elapsed     0.10s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 673   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 674   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 675   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 676   | Elapsed     0.42s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 677   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 678   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 679   | Elapsed     0.11s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 680   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 681   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 682   | Elapsed     0.29s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 683   | Elapsed     0.23s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 684   | Elapsed     0.77s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 685   | Elapsed     0.46s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 686   | Elapsed     0.58s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 687   | Elapsed     0.36s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 688   | Elapsed     0.17s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 689   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 690   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 691   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 692   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 693   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 694   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 695   | Elapsed     0.11s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 696   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 697   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 698   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 699   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 700   | Elapsed     0.34s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 701   | Elapsed     0.88s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 702   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 703   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 704   | Elapsed     0.30s | MAE  0.0536 | RMSE  0.0721 *
# * Iter 705   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 706   | Elapsed     0.26s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 707   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 708   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 709   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 710   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 711   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0721 *
# * Iter 712   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 713   | Elapsed     0.48s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 714   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 715   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 716   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 717   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 718   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 719   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 720   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 721   | Elapsed     0.50s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 722   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 723   | Elapsed     0.84s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 724   | Elapsed     1.12s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 725   | Elapsed     0.34s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 726   | Elapsed     0.52s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 727   | Elapsed     0.09s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 728   | Elapsed     0.93s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 729   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 730   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 731   | Elapsed     0.17s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 732   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 733   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 734   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 735   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 736   | Elapsed     0.40s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 737   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 738   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 739   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 740   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 741   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 742   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 743   | Elapsed     0.12s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 744   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 745   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 746   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 747   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 748   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 749   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 750   | Elapsed     0.37s | MAE  0.0534 | RMSE  0.0718 *
# ...
# * Iter 790   | Elapsed     0.66s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 791   | Elapsed     0.50s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 792   | Elapsed     0.49s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 793   | Elapsed     0.41s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 794   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 795   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 796   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 797   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 798   | Elapsed     0.38s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 799   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 800   | Elapsed     0.64s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 801   | Elapsed     0.71s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 802   | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 803   | Elapsed     0.83s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 804   | Elapsed     0.69s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 805   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 806   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 807   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 808   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 809   | Elapsed     0.89s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 810   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 811   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 812   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 813   | Elapsed     0.41s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 814   | Elapsed     0.37s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 815   | Elapsed     0.39s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 816   | Elapsed     0.46s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 817   | Elapsed     0.47s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 818   | Elapsed     0.61s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 819   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 820   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 821   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 822   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 823   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 824   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 825   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 826   | Elapsed     0.35s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 827   | Elapsed     0.32s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 828   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 829   | Elapsed     0.26s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 830   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 831   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 832   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 833   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 834   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 835   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 836   | Elapsed     0.57s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 837   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 838   | Elapsed     0.57s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 839   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 840   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 841   | Elapsed     0.67s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 842   | Elapsed     0.37s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 843   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 844   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 845   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 846   | Elapsed     0.30s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 847   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 848   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 849   | Elapsed     0.45s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 850   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 851   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 852   | Elapsed     0.28s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 853   | Elapsed     0.30s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 854   | Elapsed     0.17s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 855   | Elapsed     0.20s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 856   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 857   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 858   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 859   | Elapsed     0.29s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 860   | Elapsed     0.81s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 861   | Elapsed     0.93s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 862   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 863   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 864   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 865   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 866   | Elapsed     0.47s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 867   | Elapsed     0.35s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 868   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 869   | Elapsed     0.25s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 870   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 871   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 872   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 873   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 874   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 875   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 876   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 877   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 878   | Elapsed     0.14s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 879   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 880   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 881   | Elapsed     0.23s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 882   | Elapsed     0.17s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 883   | Elapsed     0.23s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 884   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 885   | Elapsed     0.63s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 886   | Elapsed     0.29s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 887   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 888   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 889   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 890   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 891   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 892   | Elapsed     0.14s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 893   | Elapsed     0.19s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 894   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 895   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 896   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 897   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 898   | Elapsed     0.24s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 899   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 900   | Elapsed     0.18s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 901   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 902   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 903   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 904   | Elapsed     0.22s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 905   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 906   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 907   | Elapsed     0.17s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 908   | Elapsed     0.16s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 909   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 910   | Elapsed     0.24s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 911   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 912   | Elapsed     0.15s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 913   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 914   | Elapsed     0.18s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 915   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 916   | Elapsed     0.31s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 917   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 918   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 919   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 920   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 921   | Elapsed     0.33s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 922   | Elapsed     0.26s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 923   | Elapsed     0.27s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 924   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 925   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 926   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 927   | Elapsed     0.42s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 928   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 929   | Elapsed     0.60s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 930   | Elapsed     0.39s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 931   | Elapsed     0.41s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 932   | Elapsed     0.35s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 933   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 934   | Elapsed     0.44s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 935   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 936   | Elapsed     0.14s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 937   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 938   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 939   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 940   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 941   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 942   | Elapsed     0.68s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 943   | Elapsed     0.45s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 944   | Elapsed     1.06s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 945   | Elapsed     0.72s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 946   | Elapsed     0.51s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 947   | Elapsed     0.76s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 948   | Elapsed     0.41s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 949   | Elapsed     0.84s | MAE  0.0536 | RMSE  0.0720 *
# * Iter 950   | Elapsed     0.41s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 951   | Elapsed     0.52s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 952   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 953   | Elapsed     0.28s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 954   | Elapsed     0.28s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 955   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 956   | Elapsed     0.31s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 957   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 958   | Elapsed     0.44s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 959   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 960   | Elapsed     0.27s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 961   | Elapsed     0.23s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 962   | Elapsed     0.23s | MAE  0.0533 | RMSE  0.0718 *
# * Iter 963   | Elapsed     0.19s | MAE  0.0533 | RMSE  0.0719 *
# * Iter 964   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 965   | Elapsed     0.39s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 966   | Elapsed     0.78s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 967   | Elapsed     0.81s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 968   | Elapsed     0.91s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 969   | Elapsed     0.87s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 970   | Elapsed     1.14s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 971   | Elapsed     0.19s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 972   | Elapsed     0.39s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 973   | Elapsed     0.35s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 974   | Elapsed     0.76s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 975   | Elapsed     0.95s | MAE  0.0534 | RMSE  0.0718 *
# * Iter 976   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 977   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 978   | Elapsed     1.04s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 979   | Elapsed     0.60s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 980   | Elapsed     0.33s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 981   | Elapsed     0.15s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 982   | Elapsed     0.26s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 983   | Elapsed     0.32s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 984   | Elapsed     0.40s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 985   | Elapsed     0.34s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 986   | Elapsed     0.25s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 987   | Elapsed     0.21s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 988   | Elapsed     0.40s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 989   | Elapsed     0.29s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 990   | Elapsed     0.29s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 991   | Elapsed     0.30s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 992   | Elapsed     0.22s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 993   | Elapsed     0.20s | MAE  0.0535 | RMSE  0.0719 *
# * Iter 994   | Elapsed     0.12s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 995   | Elapsed     0.18s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 996   | Elapsed     0.21s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 997   | Elapsed     0.13s | MAE  0.0534 | RMSE  0.0719 *
# * Iter 998   | Elapsed     0.16s | MAE  0.0534 | RMSE  0.0720 *
# * Iter 999   | Elapsed     0.23s | MAE  0.0535 | RMSE  0.0720 *
# * Iter 1000  | Elapsed     0.13s | MAE  0.0535 | RMSE  0.0720 *
# * Iter TOTAL | Elapsed   360.99s | MAE  0.0513 | RMSE  0.0694 *
#
# ======================================================================
#                         BKTR Regressor Summary
# ======================================================================
# Formula: nb_departure ~ 1 + area_park + len_cycle_path +
#   len_major_road + len_minor_road + num_metro_stations +
#   num_other_commercial + num_restaurants + num_university + num_pop +
#   num_bus_stations + num_bus_routes + walkscore + capacity + humidity
#   + max_temp_f + mean_temp_c + total_precip_mm + holiday
#
# Burn-in iterations: 500
# Sampling iterations: 500
# Rank decomposition: 10
# Nb Spatial Locations: 587
# Nb Temporal Points: 196
# Nb Covariates: 19
# ======================================================================
# In Sample Errors:
#   RMSE: 0.069
#   MAE: 0.051
# Computation time: 360.99s.
# ======================================================================
# -- Spatial Kernel --
# Matern 3/2 Kernel
# Parameter(s):
#                        Mean   Median       SD  Low2.5p  Up97.5p
# lengthscale          57.023   57.414    3.330   49.660   63.865
#
# -- Temporal Kernel --
# SE Kernel
# Parameter(s):
#                        Mean   Median       SD  Low2.5p  Up97.5p
# lengthscale           1.028    1.028    0.012    1.004    1.052
# ======================================================================
# Beta Estimates Summary (Aggregated Per Covariates)
#
#                        Mean   Median       SD
# feature
# Intercept             0.196    0.175    0.124
# area_park             0.201    0.166    0.183
# len_cycle_path        0.126    0.108    0.091
# len_major_road       -0.069   -0.059    0.059
# len_minor_road       -0.176   -0.155    0.122
# num_metro_stations    0.303    0.264    0.227
# num_other_comme...    0.186    0.167    0.119
# num_restaurants       0.086    0.063    0.097
# num_university        0.082    0.062    0.099
# num_pop               0.045    0.035    0.074
# num_bus_stations     -0.037   -0.032    0.037
# num_bus_routes        0.098    0.074    0.111
# walkscore             0.181    0.159    0.130
# capacity              0.592    0.545    0.358
# humidity             -0.044   -0.040    0.041
# max_temp_f            0.028    0.026    0.028
# mean_temp_c          -0.035   -0.036    0.071
# total_precip_mm      -0.078   -0.072    0.047
# holiday              -0.005   -0.007    0.029
# ======================================================================

# %%
from pyBKTR.plots import plot_y_estimates

plot_y_estimates(bktr_regressor)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="689d3a48-143e-4c34-b40a-10ab5c3015eb" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("689d3a48-143e-4c34-b40a-10ab5c3015eb")) {                    Plotly.newPlot(                        "689d3a48-143e-4c34-b40a-10ab5c3015eb",                        [{"mode":"markers","x":[0.3366336524486542,0.6237623691558838,0.7425742745399475,0.5742574334144592,0.24752475321292877,0.15841583907604218,0.3663366436958313,0.6435643434524536,0.41584157943725586,0.7722772359848022,0.31683167815208435,0.10891088843345642,0.3366336524486542,0.7821782231330872,0.7326732873916626,0.7326732873916626,0.7920792102813721,0.6138613820075989,0.6831682920455933,0.9702970385551453,0.8514851331710815,0.9405940771102905,0.9108911156654358,0.5049505233764648,0.6930692791938782,0.7623762488365173,0.9603960514068604,0.6435643434524536,0.9702970385551453,0.8712871074676514,0.4752475321292877,0.6138613820075989,0.6831682920455933,0.9009901285171509,0.5841584205627441,0.9405940771102905,0.9702970385551453,0.9405940771102905,0.9108911156654358,0.3861386179924011,0.9603960514068604,0.9207921028137207,0.9108911156654358,0.5643564462661743,1.0,0.8613861203193665,0.801980197429657,0.7722772359848022,0.8811880946159363,0.8613861203193665,0.8910890817642212,0.7524752616882324,0.9801980257034302,0.603960394859314,0.2673267424106598,0.9801980257034302,0.9603960514068604,0.7425742745399475,0.9603960514068604,0.8910890817642212,0.5247524976730347,0.7128713130950928,0.8712871074676514,0.9603960514068604,0.9504950642585754,0.9702970385551453,0.8910890817642212,0.48514851927757263,0.9900990128517151,0.7227723002433777,0.9009901285171509,0.603960394859314,0.7524752616882324,0.7821782231330872,0.7425742745399475,0.8316831588745117,0.31683167815208435,0.3663366436958313,0.42574256658554077,0.9009901285171509,0.5148515105247498,0.3762376308441162,0.8712871074676514,0.7227723002433777,0.8118811845779419,0.9405940771102905,0.3663366436958313,0.6435643434524536,0.6732673048973083,0.6732673048973083,0.9405940771102905,0.594059407711029,0.3762376308441162,0.7029703259468079,0.3762376308441162,0.3663366436958313,0.39603960514068604,0.8316831588745117,0.24752475321292877,0.7821782231330872,0.4455445408821106,0.4356435537338257,0.9306930899620056,0.7623762488365173,0.801980197429657,0.9801980257034302,0.801980197429657,0.40594059228897095,0.09900990128517151,0.14851485192775726,0.21782177686691284,0.30693069100379944,0.1683168262243271,0.06930693238973618,0.1683168262243271,0.19801980257034302,0.3861386179924011,0.2970297038555145,0.10891088843345642,0.3465346395969391,0.15841583907604218,0.1881188154220581,0.32673266530036926,0.21782177686691284,0.32673266530036926,0.20792078971862793,0.23762376606464386,0.1881188154220581,0.5346534848213196,0.39603960514068604,0.5346534848213196,0.6534653306007385,0.3861386179924011,0.4752475321292877,0.22772277891635895,0.3564356565475464,0.3465346395969391,0.4653465449810028,0.30693069100379944,0.48514851927757263,0.4554455578327179,0.40594059228897095,0.41584157943725586,0.2970297038555145,0.41584157943725586,0.4653465449810028,0.5643564462661743,0.3861386179924011,0.603960394859314,0.2673267424106598,0.4356435537338257,0.41584157943725586,0.5148515105247498,0.49504950642585754,0.5841584205627441,0.6534653306007385,0.30693069100379944,0.48514851927757263,0.5148515105247498,0.5049505233764648,0.6138613820075989,0.6336633563041687,0.5346534848213196,0.5049505233764648,0.5544554591178894,0.49504950642585754,0.7029703259468079,0.5841584205627441,0.4356435537338257,0.24752475321292877,0.4554455578327179,0.4653465449810028,0.603960394859314,0.7029703259468079,0.3465346395969391,0.7425742745399475,0.5247524976730347,0.6237623691558838,0.43564355373382 ...

# %% [markdown]
# ## Imputation Analysis (Section 5.2)

# %%
# %%capture

df_res_arr = []
TSR.set_params('float32', 'cuda', 2023)
BURN_IN_ITER = 500
SAMPLING_ITER = 500

for len_scale in [3, 6]:
    for miss_perc in [0.1, 0.5, 0.9]:
        for i in range(1, 11):
            spatial_kernel = KernelMatern(
                smoothness_factor = 5,
                lengthscale = KernelParameter(value = len_scale)
            )
            temporal_kernel = KernelSE(
                lengthscale = KernelParameter(value = len_scale)
            )

            simu_data = simulate_spatiotemporal_data(
                nb_locations=100,
                nb_time_points=150,
                nb_spatial_dimensions=2,
                spatial_scale=10,
                time_scale=10,
                spatial_covariates_means=[0, 2, 4],
                temporal_covariates_means=[1, 3],
                spatial_kernel=spatial_kernel,
                temporal_kernel=temporal_kernel,
                noise_variance_scale=1
            )

            data_df = simu_data['data_df'].copy()
            spatial_positions_df = simu_data['spatial_positions_df']
            temporal_positions_df = simu_data['temporal_positions_df']
            index_choices_tsr = TSR.tensor(list(range(len(data_df))))
            nb_miss_index = round(miss_perc * len(data_df))
            na_index = TSR.rand_choice(
                index_choices_tsr, nb_miss_index, use_replace=False
            ).cpu().numpy().astype(int)
            data_df.iloc[na_index, 0] = pd.NA

            bktr_regressor = BKTRRegressor(
                data_df = data_df,
                rank_decomp = 10,
                burn_in_iter = BURN_IN_ITER,
                sampling_iter = SAMPLING_ITER,
                spatial_kernel = KernelMatern(smoothness_factor = 5),
                spatial_positions_df = simu_data['spatial_positions_df'],
                temporal_kernel = KernelSE(),
                temporal_positions_df = simu_data['temporal_positions_df'],
                has_geo_coords = False
            )
            bktr_regressor.mcmc_sampling()

            y_err = (
                bktr_regressor.imputed_y_estimates.iloc[
                    na_index
                ][['y']].to_numpy()
                - simu_data['data_df'].iloc[na_index][['y']].to_numpy()
            )
            beta_err = (
                np.abs(bktr_regressor.beta_estimates.to_numpy()
                - simu_data['beta_df'].to_numpy())
            )
            y_rmse = float(np.sqrt(np.mean(y_err**2)))
            y_mae = float(np.mean(abs(y_err)))
            beta_rmse = float(np.sqrt(np.mean(beta_err**2)))
            beta_mae = float(np.mean(abs(beta_err)))

            df_res_arr.append([
                len_scale,
                miss_perc,
                i,
                beta_mae,
                beta_rmse,
                y_mae,
                y_rmse,
                bktr_regressor.result_logger.total_elapsed_time
            ])

# %%
print('## Iterations dataframe ##')
df = pd.DataFrame(df_res_arr, columns=[
    'Lengthscale', 'Missing', 'Iter', 'B_MAE',
    'B_RMSE', 'Y_MAE', 'Y_RMSE', 'Time'
])
print(df)

print('## Aggregated dataframe ##')
agg_df = df.groupby(['Lengthscale', 'Missing'])[[
    'B_MAE', 'B_RMSE', 'Y_MAE', 'Y_RMSE', 'Time'
]].agg(['mean', 'std']).reset_index()
print(agg_df)
# Out:
# ## Iterations dataframe ##
#     Lengthscale  Missing  Iter     B_MAE    B_RMSE     Y_MAE    Y_RMSE  \
# 0             3      0.1     1  0.456836  0.646745  0.899862  1.139481
# 1             3      0.1     2  1.803280  3.278733  0.902540  1.121975
# 2             3      0.1     3  1.087550  1.876726  0.895373  1.126965
# 3             3      0.1     4  0.756219  1.218265  0.847705  1.067894
# 4             3      0.1     5  1.070130  1.796503  0.882446  1.110933
# 5             3      0.1     6  1.040516  1.580049  0.853942  1.086386
# 6             3      0.1     7  0.712554  1.032774  0.906656  1.124438
# 7             3      0.1     8  0.577121  0.953384  0.875244  1.093974
# 8             3      0.1     9  0.468574  0.753467  0.861979  1.066301
# 9             3      0.1    10  0.471016  0.773561  0.873121  1.093671
# 10            3      0.5     1  1.215339  1.953418  0.963654  1.221397
# 11            3      0.5     2  0.863352  1.359332  0.923672  1.171887
# 12            3      0.5     3  0.697520  1.097123  0.911814  1.148729
# 13            3      0.5     4  1.049673  1.722042  0.950280  1.206165
# 14            3      0.5     5  0.631652  0.961943  0.911129  1.163308
# 15            3      0.5     6  0.482491  0.669279  0.909779  1.150142
# 16            3      0.5     7  0.734747  1.170650  0.889368  1.119587
# 17            3      0.5     8  0.713060  1.065131  0.873310  1.104518
# 18            3      0.5     9  0.541954  0.783287  0.922728  1.166093
# 19            3      0.5    10  0.667784  1.040252  0.914173  1.157562
# 20            3      0.9     1  0.544782  0.731466  1.132297  1.467843
# 21            3      0.9     2  0.597523  0.813327  1.205426  1.565562
# 22            3      0.9     3  0.803752  1.324746  1.110640  1.457341
# 23            3      0.9     4  0.723932  1.065704  1.182932  1.538214
# 24            3      0.9     5  0.606338  0.879380  1.137247  1.462551
# 25            3      0.9     6  0.577579  0.805479  1.138664  1.475679
# 26            3      0.9     7  0.482864  0.669789  1.027475  1.301496
# 27            3      0.9     8  0.700722  1.057913  1.164243  1.525940
# 28            3      0.9     9  0.554838  0.756372  1.074257  1.370187
# 29            3      0.9    10  0.408205  0.583763  1.003760  1.283213
# 30            6      0.1     1  0.166717  0.284523  0.842992  1.044989
# 31            6      0.1     2  0.161247  0.233292  0.823537  1.034583
# 32            6      0.1     3  0.166331  0.284165  0.824172  1.030962
# 33            6      0.1     4  0.199508  0.350985  0.814658  1.024334
# 34            6      0.1     5  0.206757  0.344443  0.778992  0.977326
# 35            6      0.1     6  0.223803  0.379823  0.809899  1.009898
# 36            6      0.1     7  0.170600  0.291676  0.798210  1.012636
# 37            6      0.1     8  0.143045  0.216656  0.821618  1.025126
# 38            6      0.1     9  0.144485  0.231885  0.801742  1.001145
# 39            6      0.1    10  0.131937  0.208306  0.819416  1.031216
# 40            6      0.5     1  0.179263  0.294381  0.822803  1.031582
# 41            6      0.5     2  0.159797  0.245656  0.824521  1.030248
# 42            6      0.5     3  0.142556  0.201413  0.832687  1.043368
# 43            6      0.5     4  0.285192  0.468610  0.820783  1.033255
# 44            6      0.5     5  0.150620  0.238470  0.821076  1.034172
# 45            6      0.5     6  0.148005  0.209653  0.828242  1.041430
# 46            6      0.5     7  0.179376  0.327857  0.817875  1.023921
# 47            6      0.5     8  0.129927  0.202809  0.810294  1.015622
# 48            6      0.5     9  0.211798  0.363959  0.813995  1.020395
# 49            6      0.5    10  0.120065  0.171149  0.827776  1.036906
# 50            6      0.9     1  0.266196  0.422890  0.879195  1.103707
# 51            6      0.9     2  0.229921  0.345170  0.892033  1.114560
# 52            6      0.9     3  0.280478  0.447448  0.889115  1.120837
# 53            6      0.9     4  0.280031  0.437620  0.880072  1.102863
# 54            6      0.9     5  0.227994  0.329982  0.879281  1.106143
# 55            6      0.9     6  0.242241  0.373234  0.865865  1.086930
# 56            6      0.9     7  0.252387  0.412744  0.870257  1.091745
# 57            6      0.9     8  0.309300  0.466849  0.881956  1.109214
# 58            6      0.9     9  0.275233  0.394851  0.897856  1.127153
# 59            6      0.9    10  0.217697  0.332410  0.877024  1.104524
#
#          Time
# 0   82.090083
# 1   80.947209
# 2   80.342829
# 3   79.026290
# 4   79.540330
# 5   79.724351
# 6   78.598716
# 7   79.933563
# 8   78.956983
# 9   80.079769
# 10  79.159932
# 11  78.086264
# 12  78.030838
# 13  78.726879
# 14  77.865242
# 15  80.000288
# 16  75.906138
# 17  80.658394
# 18  78.055592
# 19  77.971528
# 20  72.012464
# 21  72.036831
# 22  75.697180
# 23  73.739785
# 24  74.922894
# 25  73.875975
# 26  71.635905
# 27  71.858909
# 28  75.171008
# 29  72.403388
# 30  73.070371
# 31  73.538653
# 32  72.748583
# 33  73.953467
# 34  73.681735
# 35  72.171705
# 36  74.144117
# 37  73.845025
# 38  72.213369
# 39  72.212636
# 40  70.015859
# 41  68.840168
# 42  71.538286
# 43  72.917547
# 44  70.884688
# 45  68.693047
# 46  72.114115
# 47  72.012935
# 48  72.747463
# 49  69.067209
# 50  64.205437
# 51  66.378107
# 52  67.047815
# 53  68.292089
# 54  65.103883
# 55  65.485942
# 56  67.391168
# 57  66.449357
# 58  66.073608
# 59  65.758041
# ## Aggregated dataframe ##
#   Lengthscale Missing     B_MAE              B_RMSE               Y_MAE  \
#                            mean       std      mean       std      mean
# 0           3     0.1  0.844380  0.421037  1.391021  0.795187  0.879887
# 1           3     0.5  0.759757  0.225635  1.182246  0.398545  0.916991
# 2           3     0.9  0.600054  0.116982  0.868794  0.221603  1.117694
# 3           6     0.1  0.171443  0.029858  0.282576  0.060474  0.813524
# 4           6     0.5  0.170660  0.048306  0.272396  0.092122  0.822005
# 5           6     0.9  0.258148  0.029020  0.396320  0.049336  0.881265
#
#                Y_RMSE                 Time
#         std      mean       std       mean       std
# 0  0.021008  1.103202  0.025410  79.924012  1.034037
# 1  0.026152  1.160939  0.034997  78.446109  1.306674
# 2  0.065160  1.444803  0.096646  73.335434  1.538280
# 3  0.017520  1.019222  0.019593  73.157966  0.776782
# 4  0.006783  1.031090  0.008892  70.883132  1.628070
# 5  0.009657  1.106768  0.012154  66.218545  1.178790

# %% [markdown]
# ## Interpolation Analysis (Section 5.3)

# %%
# %%capture

TSR.set_params('float32', 'cuda', 3)

BURN_IN_ITER = 500
SAMPLING_ITER = 500

nb_aside_locs = 4
nb_aside_times = 6

df_res_arr = []

for ds_type in ['Smaller', 'Larger']:
    for len_scale in [3, 6]:
        for i in range(1, 11):
            matern_lengthscale = KernelParameter(value = len_scale)
            se_lengthscale = KernelParameter(value = len_scale)
            spatial_kernel = KernelMatern(
                lengthscale = matern_lengthscale, smoothness_factor = 5
            )
            temporal_kernel = KernelSE(lengthscale = se_lengthscale)

            nb_locs = 20 if ds_type == 'Smaller' else 100
            nb_times = 30 if ds_type == 'Smaller' else 150
            spa_cov_means = [0, 2] if ds_type == 'Smaller' else [0, 2, 4]
            tem_cov_means = [1] if ds_type == 'Smaller' else [1, 3]

            simu_data = simulate_spatiotemporal_data(
                nb_locations=nb_locs,
                nb_time_points=nb_times,
                nb_spatial_dimensions=2,
                spatial_scale=10,
                time_scale=10,
                spatial_covariates_means=spa_cov_means,
                temporal_covariates_means=tem_cov_means,
                spatial_kernel=spatial_kernel,
                temporal_kernel=temporal_kernel,
                noise_variance_scale=1
            )

            data_df = simu_data['data_df'].copy()
            spatial_positions_df = simu_data['spatial_positions_df']
            temporal_positions_df = simu_data['temporal_positions_df']

            obs_nb_locs = nb_locs - nb_aside_locs
            obs_nb_times = nb_times - nb_aside_times

            all_locs = data_df.index.get_level_values(0).unique().to_list()
            all_times = data_df.index.get_level_values(1).unique().to_list()

            locs_indx_sample = list(TSR.rand_choice(
                TSR.tensor(range(1, len(all_locs) + 1)),
                obs_nb_locs
            ).cpu().numpy())
            obs_locs = [all_locs[int(i) - 1] for i in locs_indx_sample]
            new_locs = list(set(all_locs) - set(obs_locs))

            times_indx_sample = list(TSR.rand_choice(TSR.tensor(
                range(1, len(all_times) + 1)),
                obs_nb_times
            ).cpu().numpy())
            obs_times = [all_times[int(i) - 1] for i in times_indx_sample]
            new_times = list(set(all_times) - set(obs_times))

            obs_data_df = data_df.drop(index=new_locs, level='location')
            obs_data_df = obs_data_df.drop(index=new_times, level='time')
            obs_spatial_pos_df = spatial_positions_df.drop(index=new_locs,)
            obs_temporal_pos_df = temporal_positions_df.drop(index=new_times,)

            new_data_df = data_df[
                (data_df.index.get_level_values(0).isin(new_locs)) |
                (data_df.index.get_level_values(1).isin(new_times))
            ].copy()
            new_beta_data_df = simu_data['beta_df'][
                simu_data['beta_df'].index.get_level_values(0).isin(new_locs) |
                simu_data['beta_df'].index.get_level_values(1).isin(new_times)
            ].copy()
            new_spatial_pos_df = spatial_positions_df[
                spatial_positions_df.index.isin(new_locs)
            ].copy()
            new_temporal_pos_df = temporal_positions_df[
                temporal_positions_df.index.isin(new_times)
            ].copy()


            bktr_regressor = BKTRRegressor(
                data_df = obs_data_df,
                rank_decomp = 10,
                burn_in_iter = BURN_IN_ITER,
                sampling_iter = SAMPLING_ITER,
                spatial_kernel = KernelMatern(smoothness_factor = 5),
                spatial_positions_df = obs_spatial_pos_df,
                temporal_kernel = KernelSE(),
                temporal_positions_df = obs_temporal_pos_df,
                has_geo_coords = False
            )
            bktr_regressor.mcmc_sampling()

            preds_y_df, preds_beta_df = bktr_regressor.predict(
                new_data_df,
                new_spatial_pos_df,
                new_temporal_pos_df
            )

            preds_y_df.sort_index(inplace=True)
            new_data_df.sort_index(inplace=True)
            preds_beta_df.sort_index(inplace=True)
            new_beta_data_df.sort_index(inplace=True)
            preds_y_err = (
                new_data_df['y'].to_numpy() - preds_y_df['y'].to_numpy()
            )
            preds_beta_err = (
                new_beta_data_df.to_numpy() - preds_beta_df.to_numpy()
            )
            df_res_arr.append([
                ds_type,
                len_scale,
                i,
                np.mean(np.abs(preds_beta_err)),
                np.sqrt(np.mean(np.square(preds_beta_err))),
                np.mean(np.abs(preds_y_err)),
                np.sqrt(np.mean(np.square(preds_y_err))),
            ])

# %%
print('## Iterations dataframe ##')
df = pd.DataFrame(df_res_arr, columns=[
    'Dataset_Type', 'Lengthscale', 'Iter',
    'B_MAE', 'B_RMSE', 'Y_MAE', 'Y_RMSE'
])
print(df)

print('## Aggregated dataframe ##')
agg_df = df.groupby(['Dataset_Type', 'Lengthscale'])[[
    'B_MAE', 'B_RMSE', 'Y_MAE', 'Y_RMSE'
]].agg(['mean', 'std']).reset_index()
print(agg_df)
# Out:
# ## Iterations dataframe ##
#    Dataset_Type  Lengthscale  Iter     B_MAE    B_RMSE     Y_MAE     Y_RMSE
# 0       Smaller            3     1  0.868864  1.183598  1.551411   2.058035
# 1       Smaller            3     2  0.948494  1.441087  1.847889   2.608730
# 2       Smaller            3     3  0.483438  0.622200  1.436089   1.831888
# 3       Smaller            3     4  0.749204  1.002860  1.274208   1.650741
# 4       Smaller            3     5  0.995754  1.360431  1.269009   1.657968
# 5       Smaller            3     6  0.848008  1.207954  1.389270   1.963238
# 6       Smaller            3     7  0.639127  0.817665  1.137642   1.445038
# 7       Smaller            3     8  0.430833  0.589409  1.234845   1.664905
# 8       Smaller            3     9  0.550359  0.761297  1.737363   2.262836
# 9       Smaller            3    10  0.953655  1.332466  1.997401   2.755547
# 10      Smaller            6     1  0.427266  0.604590  1.025018   1.304990
# 11      Smaller            6     2  0.426282  0.551310  1.079009   1.369351
# 12      Smaller            6     3  0.454029  0.664822  1.196764   1.514527
# 13      Smaller            6     4  0.346092  0.442685  0.995223   1.316699
# 14      Smaller            6     5  0.703062  0.977522  1.024997   1.322139
# 15      Smaller            6     6  0.414579  0.552146  1.227152   1.522909
# 16      Smaller            6     7  0.321475  0.431340  0.891142   1.101158
# 17      Smaller            6     8  0.492780  0.658485  1.123314   1.447836
# 18      Smaller            6     9  0.464617  0.613861  1.172456   1.486531
# 19      Smaller            6    10  0.311943  0.438596  0.857633   1.059014
# 20       Larger            3     1  1.041546  1.724393  2.125056   3.359183
# 21       Larger            3     2  0.700551  1.044652  2.296482   3.653659
# 22       Larger            3     3  0.675521  1.053473  2.328733   3.421427
# 23       Larger            3     4  2.666245  5.311288  6.393568  11.269808
# 24       Larger            3     5  0.612731  0.966408  1.151518   1.575186
# 25       Larger            3     6  1.749092  2.944816  2.080765   3.240235
# 26       Larger            3     7  3.105395  6.007730  4.964048   8.069632
# 27       Larger            3     8  0.697815  1.048588  1.457959   1.930276
# 28       Larger            3     9  1.119408  1.995637  1.679346   2.577094
# 29       Larger            3    10  1.280304  1.985196  3.502741   5.773226
# 30       Larger            6     1  0.202654  0.290723  0.883825   1.105239
# 31       Larger            6     2  0.148507  0.227441  0.894502   1.116158
# 32       Larger            6     3  0.245057  0.384648  0.917701   1.146244
# 33       Larger            6     4  0.164754  0.249527  0.837192   1.053116
# 34       Larger            6     5  0.259145  0.386112  0.862560   1.081988
# 35       Larger            6     6  0.222790  0.320474  0.982961   1.263265
# 36       Larger            6     7  0.229526  0.411427  0.864073   1.083272
# 37       Larger            6     8  0.182070  0.296238  0.894919   1.137319
# 38       Larger            6     9  0.222043  0.346141  0.867338   1.096879
# 39       Larger            6    10  0.218451  0.364720  0.830604   1.046205
# ## Aggregated dataframe ##
#   Dataset_Type Lengthscale     B_MAE              B_RMSE               Y_MAE  \
#                                 mean       std      mean       std      mean
# 0       Larger           3  1.364861  0.880011  2.408218  1.829119  2.798022
# 1       Larger           6  0.209500  0.035065  0.327745  0.061417  0.883567
# 2      Smaller           3  0.746774  0.208160  1.031897  0.316813  1.487513
# 3      Smaller           6  0.436212  0.112006  0.593536  0.161193  1.059271
#
#                Y_RMSE
#         std      mean       std
# 0  1.677086  4.486973  3.051696
# 1  0.043885  1.112968  0.061913
# 2  0.288320  1.989893  0.434829
# 3  0.124617  1.344515  0.161850

# %% [markdown]
# ## Mercator Projection (Appendix E)

# %%
import plotly.express as px

bixi_data = BixiData()

bktr_regressor = BKTRRegressor(
    data_df = bixi_data.data_df,
    spatial_positions_df = bixi_data.spatial_positions_df,
    temporal_positions_df = bixi_data.temporal_positions_df
)

print('# Initial dataframe (longitude, latitude) #')
print(bktr_regressor.geo_coords_projector.ini_df.head())
print()
print('# Mercator Projection dataframe ([-5, 5] scaled) #')
print(bktr_regressor.geo_coords_projector.scaled_ini_df.head())
# Out:
# # Initial dataframe (longitude, latitude) #
#                                                      latitude  longitude
# location
# 10002 - Métro Charlevoix (Centre / Charlevoix)      45.478228 -73.569651
# 4000 - Jeanne-d'Arc / Ontario                       45.549598 -73.541874
# 4001 - Graham / Brookfield                          45.520075 -73.629776
# 4002 - Graham / Wicksteed                           45.516937 -73.640483
# 5006 - Collège Édouard-Montpetit (de Gentilly /...  45.537226 -73.495067
#
# # Mercator Projection dataframe ([-5, 5] scaled) #
#                                                        lon_x     lat_y
# location
# 10002 - Métro Charlevoix (Centre / Charlevoix)      1.035426 -1.583683
# 4000 - Jeanne-d'Arc / Ontario                       2.094213  2.298574
# 4001 - Graham / Brookfield                         -1.256364  0.692039
# 4002 - Graham / Wicksteed                          -1.664503  0.521317
# 5006 - Collège Édouard-Montpetit (de Gentilly /...  3.878387  1.625249

# %%
FIG_WIDTH = 550

fig_scale = px.scatter(
    bktr_regressor.geo_coords_projector.scaled_ini_df.reset_index(),
    x='lon_x', y='lat_y', hover_name='location',
    width = FIG_WIDTH
)
fig_scale.update_xaxes(range=[-5.5, 5.5])
fig_scale.update_yaxes(range=[-5.5, 5.5])
fig_scale.show()

fig_map = px.scatter_mapbox(
    bktr_regressor.geo_coords_projector.ini_df,
    lat='latitude', lon='longitude', zoom=9.9,
    mapbox_style='carto-positron',
    width = FIG_WIDTH
)
fig_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70bd1c60-e5b7-4ff5-9f7b-22108cb1ab62" class="plotly-graph-div" style="height:525px; width:550px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70bd1c60-e5b7-4ff5-9f7b-22108cb1ab62")) {                    Plotly.newPlot(                        "70bd1c60-e5b7-4ff5-9f7b-22108cb1ab62",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elon_x=%{x}\u003cbr\u003elat_y=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["10002 - M\u00e9tro Charlevoix (Centre \u002f Charlevoix)","4000 - Jeanne-d'Arc \u002f Ontario","4001 - Graham \u002f Brookfield","4002 - Graham \u002f Wicksteed","5006 - Coll\u00e8ge \u00c9douard-Montpetit (de Gentilly \u002f de Normandie)","5007 - M\u00e9tro Longueuil - Universit\u00e9 de Sherbrooke","6001 - M\u00e9tro Champ-de-Mars (Viger \u002f Sanguinet)","6002 - Ste-Catherine \u002f Dezery","6003 - Clark \u002f Evans","6004 - du Champ-de-Mars \u002f Gosford","6005 - Metcalfe \u002f du Square-Dorchester","6006 - 18e avenue \u002f Rosemont","6007 - de l'H\u00f4tel-de-Ville \u002f Ste-Catherine","6008 - Sanguinet \u002f Ste-Catherine","6009 - Crescent \u002f de Maisonneuve","6011 - St-Andr\u00e9 \u002f St-Antoine","6012 - M\u00e9tro St-Laurent (de Maisonneuve \u002f St-Laurent)","6013 - Sanguinet \u002f de Maisonneuve","6014 - St-Denis \u002f Ren\u00e9-L\u00e9vesque","6015 - BAnQ (Berri \u002f de Maisonneuve)","6016 - Jacques-Le Ber \u002f de la Pointe Nord","6017 - Atateken \u002f du Square Amherst","6018 - St-Andr\u00e9 \u002f Ontario","6019 - M\u00e9tro Sherbrooke (de Rigaud \u002f Berri)","6020 - Sanguinet \u002f Ontario","6021 - de l'H\u00f4tel-de-Ville \u002f Sherbrooke","6022 - William-Tremblay \u002f Molson","6023 - de la Commune \u002f Berri","6025 - Notre-Dame \u002f St-Gabriel","6026 - de la Commune \u002f Place Jacques-Cartier","6027 - de Maisonneuve \u002f Mansfield (sud)","6029 - Bourget \u002f St-Jacques","6031 - de Maisonneuve \u002f Robert-Bourassa","6032 - M\u00e9tro Place-d'Armes (Viger \u002f St-Urbain)","6033 - 16e avenue \u002f Beaubien","6035 - Viger \u002f Chenneville","6036 - de la Commune \u002f St-Sulpice","6037 - St-Nicolas \u002f Place d'Youville","6038 - McGill \u002f Place d'Youville","6039 - McGill \u002f des R\u00e9collets","6040 - St-Jacques \u002f St-Pierre","6041 - St-Jacques \u002f McGill","6042 - de la Gaucheti\u00e8re \u002f Robert-Bourassa","6043 - Square Victoria (Viger \u002f du Square-Victoria)","6044 - Roy \u002f St-Andr\u00e9","6046 - M\u00e9tro Bonaventure (de la Gaucheti\u00e8re \u002f de la Cath\u00e9drale)","6047 - University \u002f Prince-Arthur","6048 - William \u002f St-Henri","6049 - Queen \u002f Wellington","6050 - St-Maurice \u002f Robert-Bourassa","6051 - de Gasp\u00e9 \u002f Marmier","6052 - de la Commune \u002f King","6053 - du Pr\u00e9sident-Kennedy \u002f Jeanne-Mance","6057 - Peel \u002f de la Gauchetiere","6058 - Cypress \u002f Peel","6059 - de la Cath\u00e9drale \u002f Ren\u00e9-L\u00e9vesque","6060 - Belmont \u002f Robert-Bourassa","6061 - Mansfield \u002f Ste-Catherine","6062 - Drummond \u002f Ste-Catherine","6063 - Drummond \u002f de Maisonneuve","6064 - M\u00e9tro Peel (de Maisonneuve \u002f Stanley)","6065 - de la Montagne \u002f Sherbrooke","6066 - McTavish \u002f des Pins","6067 - Porte-de-Qu\u00e9bec \u002f St-Hubert","6068 - 2e avenue \u002f Jean-Rivard","6070 - Milton \u002f University","6072 - Metcalfe \u002f de Maisonneuve","6073 - de Maisonneuve \u002f Aylmer (ouest)","6075 - University \u002f des Pins","6076 - de Ville-Marie \u002f Ste-Catherine","6078 - St-Alexandre \u002f Ste-Catherine","6079 - Hutchison \u002f Prince-Arthur","6080 - M\u00e9tro Vend\u00f4me (de Marlowe \u002f de Maisonneuve)","6081 - Mackay \u002f St ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f816c36e-3b14-447d-9d09-20f228b1180b" class="plotly-graph-div" style="height:525px; width:550px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f816c36e-3b14-447d-9d09-20f228b1180b")) {                    Plotly.newPlot(                        "f816c36e-3b14-447d-9d09-20f228b1180b",                        [{"hovertemplate":"latitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[45.47822787309145,45.54959767887176,45.52007477080967,45.5169365471281,45.53722603812578,45.52331869398737,45.51035067563653,45.53938508196168,45.51100666600306,45.50965520472071,45.500208064155046,45.55789545752947,45.51166045593874,45.512796855823325,45.49811161443597,45.51411452790017,45.51066,45.51340553558378,45.51287121578035,45.515299,45.472503,45.52063377251984,45.51889,45.51799893773692,45.51476724402057,45.5145646696576,45.5417198089013,45.51086,45.5071439192841,45.50761009451047,45.502053864057466,45.48084576334506,45.504262928300726,45.50623,45.55828063767653,45.50531166520915,45.50424245563397,45.50196685910157,45.49975,45.500779,45.50278649802565,45.50144108135568,45.50060578095098,45.50206,45.52156427090662,45.49831217703312,45.507401678946415,45.49891911390353,45.497605276991,45.49857779102015,45.529686,45.49751503379366,45.50820461505136,45.4977183451679,45.49932551028458,45.499191207076606,45.501366848348894,45.50139870932151,45.49863930330429,45.49947,45.50038,45.49974475043378,45.50530549708951,45.51249475526989,45.56250903804892,45.5064484,45.50171494932854,45.50501,45.50829509569767,45.55792114867546,45.50538225593995,45.50975858607626,45.47393028235147,45.49570931691902,45.54990048023633,45.50373771539476,45.49558135053393,45.4952,45.49045242854756,45.49302901258371,45.4891601257399,45.527839413108,45.49487159597494,45.49168652100804,45.49709201687824,45.491225854759705,45.52564776553033,45.49180027678722,45.49356916133978,45.49289739717746,45.49658329569871,45.51506508398211,45.49659000000001,45.479483,45.493034,45.535753085274585,45.51681750463149,45.51937252291976,45.52114,45.49367956421703,45.52836601591233,45.513741443172,45.52900206660642,45.52600589494234,45.519139183741046,45.52123044585842,45.52353,45.46685123845205,45.52349210923463,45.50526304478132,45.52510954917077,45.52773089755533,45.53370598779896,45.5345625650145,45.53057,45.52327641182772,45.53193889278052,45.499757,45.53213680524969,45.53658244795977,45.53529548038031,45.52997069129103,45.5367,45.533924,45.5291345371163,45.53673838509649,45.53840340979245,45.52761627,45.53034708827074,45.53167355364312,45.53292625574653,45.5298015824607,45.53354753725336,45.5277947855251,45.52689,45.52451761488783,45.523170471388255,45.52479,45.52720058937288,45.53867,45.53711414,45.53646917409483,45.53418509490266,45.532674,45.53229,45.53092,45.52775814390426,45.52940777616882,45.530816227815954,45.49452705626516,45.53297745535149,45.53582823686429,45.54612387708119,45.53543,45.5333136054992,45.53251395631143,45.5337352275406,45.53703,45.530871318676006,45.527432126380575,45.53045006508681,45.51958082831579,45.51908844137639,45.51908,45.52027785033668,45.52496323980324,45.52242565278864,45.5222776,45.52060423232697,45.5094183667176,45.5173538,45.521751208485135,45.5223645775784,45.524673,45.54912085535069,45.52931012171625,45.52562819123256,45.52602656522141,45.55072306022627,45.52700933427065,45.531401,45.52996959525514,45.521495,45.48947622882085,45.5240365462478,45.52134173413233,45.538984395523,45.52974,45.525930730227095,45.52462848559264,45.523544198302034,45.51007154847701,45.50658668914343,45.508140959417744,45.50936142835129,45.51059,45.51283174510449,45.51069,45.51254135285248,45.55069206841976,45.515616239398405,45.51509198406273,45.51687640567004,45.516090801970655,45.5008323 ...
